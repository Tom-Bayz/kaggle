# %%
import os
import pandas as pd
import numpy as np
import plotly_express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt
import seaborn as sns
import gc
import copy
import warnings
warnings.filterwarnings('ignore')
import xgboost as xgb
from sklearn.metrics import mean_squared_error
import joblib
import optuna
from tqdm import tqdm
import time
import codecs
import pickle

# %% [markdown]
# # Configuration

# %%
rawdata_dir = 'rawdata'
data_dir = 'data'

# lags = [1,2,3,6,12,24,36]
lags = [28, 35, 42, 49, 56]

# NUM_FOLD_DAYS = 28
NUM_FOLD_DAYS = 56
VALID_FIRST_DAY = 1914
VALID_LAST_DAY = 1941
NUM_USE_DAY = 365
# TRAIN_FIRST_DAY = max(lags)
TRAIN_FIRST_DAY = VALID_FIRST_DAY - NUM_USE_DAY + 1

OPTUNA_TRIAL = 70

# %% [markdown]
# # Read data

# %%
sales = pd.read_csv(os.path.join(rawdata_dir, 'sales_train_evaluation.csv'))
sales.name = 'sales'
calendar = pd.read_csv(os.path.join(rawdata_dir, 'calendar.csv'))
calendar.name = 'calendar'
prices = pd.read_csv(os.path.join(rawdata_dir, 'sell_prices.csv'))
prices.name = 'prices'

# %% [markdown]
# Since, the validation data is now available for the days 1914-1941, Adding zero sales for days: d_1942 - d_1969(Test)

# %%
#Add zero sales for the remaining days 1942-1969
for d in range(1942,1970):
    col = 'd_' + str(d)
    sales[col] = 0
    sales[col] = sales[col].astype(np.int16)

# %% [markdown]
# # Downcast

# %%
#Downcast in order to save memory
def downcast(df):
    cols = df.dtypes.index.tolist()
    types = df.dtypes.values.tolist()
    for i,t in enumerate(types):
        if 'int' in str(t):
            if df[cols[i]].min() > np.iinfo(np.int8).min and df[cols[i]].max() < np.iinfo(np.int8).max:
                df[cols[i]] = df[cols[i]].astype(np.int8)
            elif df[cols[i]].min() > np.iinfo(np.int16).min and df[cols[i]].max() < np.iinfo(np.int16).max:
                df[cols[i]] = df[cols[i]].astype(np.int16)
            elif df[cols[i]].min() > np.iinfo(np.int32).min and df[cols[i]].max() < np.iinfo(np.int32).max:
                df[cols[i]] = df[cols[i]].astype(np.int32)
            else:
                df[cols[i]] = df[cols[i]].astype(np.int64)
        elif 'float' in str(t):
            if df[cols[i]].min() > np.finfo(np.float16).min and df[cols[i]].max() < np.finfo(np.float16).max:
                df[cols[i]] = df[cols[i]].astype(np.float16)
            elif df[cols[i]].min() > np.finfo(np.float32).min and df[cols[i]].max() < np.finfo(np.float32).max:
                df[cols[i]] = df[cols[i]].astype(np.float32)
            else:
                df[cols[i]] = df[cols[i]].astype(np.float64)
        elif t == np.object:
            if cols[i] == 'date':
                df[cols[i]] = pd.to_datetime(df[cols[i]], format='%Y-%m-%d')
            else:
                df[cols[i]] = df[cols[i]].astype('category')
    return df

sales = downcast(sales)
prices = downcast(prices)
calendar = downcast(calendar)

# %% [markdown]
# # Melt data

# %%
df = pd.melt(sales, id_vars=['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'], var_name='d', value_name='sold').dropna()

# %% [markdown]
# ## Combine data
# Combine price data from prices dataframe and days data from calendar dataset.

# %%
df = pd.merge(df, calendar, on='d', how='left')
df = pd.merge(df, prices, on=['store_id','item_id','wm_yr_wk'], how='left')

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Label Encoding

# %%
#Store the categories along with their codes
d_id = dict(zip(df.id.cat.codes, df.id))
d_item_id = dict(zip(df.item_id.cat.codes, df.item_id))
d_dept_id = dict(zip(df.dept_id.cat.codes, df.dept_id))
d_cat_id = dict(zip(df.cat_id.cat.codes, df.cat_id))
d_store_id = dict(zip(df.store_id.cat.codes, df.store_id))
d_state_id = dict(zip(df.state_id.cat.codes, df.state_id))

# %%
df.d = df['d'].apply(lambda x: x.split('_')[1]).astype(np.int16)
cols = df.dtypes.index.tolist()
types = df.dtypes.values.tolist()
for i,type in enumerate(types):
    if type.name == 'category':
        df[cols[i]] = df[cols[i]].cat.codes
        
df.drop('date',axis=1,inplace=True)

# %% [markdown]
# ## Introduce lags

# %%
#Introduce lags
def make_lags(df, lags):
    for lag in lags:
        df['sold_lag_'+str(lag)] = df.groupby(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'],as_index=False)['sold'].shift(lag).astype(np.float16)
        
    return df

# %%
df = make_lags(df, lags)

# %% [markdown]
# ## make new features

# %%
def make_new_feature(df, d_last = df['d'].max()):
    # copy sold
    sold_tmp = copy.copy(df['sold'])
    
    # embed NaN
    df['sold'][df['d'] > d_last] = np.nan
    
    # make feature using sold
    df['item_sold_avg'] = df.groupby('item_id')['sold'].transform('mean').astype(np.float16)
    df['state_sold_avg'] = df.groupby('state_id')['sold'].transform('mean').astype(np.float16)
    df['store_sold_avg'] = df.groupby('store_id')['sold'].transform('mean').astype(np.float16)
    df['cat_sold_avg'] = df.groupby('cat_id')['sold'].transform('mean').astype(np.float16)
    df['dept_sold_avg'] = df.groupby('dept_id')['sold'].transform('mean').astype(np.float16)
    df['cat_dept_sold_avg'] = df.groupby(['cat_id','dept_id'])['sold'].transform('mean').astype(np.float16)
    df['store_item_sold_avg'] = df.groupby(['store_id','item_id'])['sold'].transform('mean').astype(np.float16)
    df['cat_item_sold_avg'] = df.groupby(['cat_id','item_id'])['sold'].transform('mean').astype(np.float16)
    df['dept_item_sold_avg'] = df.groupby(['dept_id','item_id'])['sold'].transform('mean').astype(np.float16)
    df['state_store_sold_avg'] = df.groupby(['state_id','store_id'])['sold'].transform('mean').astype(np.float16)
    df['state_store_cat_sold_avg'] = df.groupby(['state_id','store_id','cat_id'])['sold'].transform('mean').astype(np.float16)
    df['store_cat_dept_sold_avg'] = df.groupby(['store_id','cat_id','dept_id'])['sold'].transform('mean').astype(np.float16)
    
    df['rolling_sold_mean'] = df.groupby(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'])['sold'].transform(lambda x: x.rolling(window=7).mean()).astype(np.float16)
    df['expanding_sold_mean'] = df.groupby(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'])['sold'].transform(lambda x: x.expanding(2).mean()).astype(np.float16)
    
    df['daily_avg_sold'] = df.groupby(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id','d'])['sold'].transform('mean').astype(np.float16)
    df['avg_sold'] = df.groupby(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'])['sold'].transform('mean').astype(np.float16)
    df['selling_trend'] = (df['daily_avg_sold'] - df['avg_sold']).astype(np.float16)
    df.drop(['daily_avg_sold','avg_sold'],axis=1,inplace=True)
    
    # restore sold
    df['sold'] = sold_tmp
    
    return df

# %%
df_all = copy.copy(df)
df_all = make_new_feature(df_all)
df_all = df_all[df_all['d'] > max(lags)]
df_all.info()

# df_all.to_pickle(os.path.join(data_dir, 'data_all.pkl'))   # save df_all (use this after CV)
df_all.to_pickle(os.path.join(data_dir, 'data_all_lagOlder28Modified.pkl'))   # save df_all (use this after CV)
del df_all
gc.collect()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58327370 entries, 1707440 to 60034809
# Data columns (total 41 columns):
# id                          int16
# item_id                     int16
# dept_id                     int8
# cat_id                      int8
# store_id                    int8
# state_id                    int8
# d                           int16
# sold                        int16
# wm_yr_wk                    int16
# weekday                     int8
# wday                        int8
# month                       int8
# year                        int16
# event_name_1                int8
# event_type_1                int8
# event_name_2                int8
# event_type_2                int8
# snap_CA                     int8
# snap_TX                     int8
# snap_WI                     int8
# sell_price                  float16
# sold_lag_28                 float16
# sold_lag_35                 float16
# sold_lag_42                 float16
# sold_lag_49                 float16
# sold_lag_56                 float16
# item_sold_avg               float16
# state_sold_avg              float16
# store_sold_avg              float16
# cat_sold_avg                float16
# dept_sold_avg               float16
# cat_dept_sold_avg           float16
# store_item_sold_avg         float16
# cat_item_sold_avg           float16
# dept_item_sold_avg          float16
# state_store_sold_avg        float16
# state_store_cat_sold_avg    float16
# store_cat_dept_sold_avg     float16
# rolling_sold_mean           float16
# expanding_sold_mean         float16
# selling_trend               float16
# dtypes: float16(21), int16(6), int8(14)
# memory usage: 4.1 GB
# 0

# %% [markdown]
# # Cross Validation

# %% [markdown]
# ## Cross Validation for each store (function)

# %%
def xgboost_cv_store(df, store):
    def objective(trial):
        # param space
        param = {
            'objective': 'reg:squarederror',
            'n_estimators': 1000,
            'learning_rate': 0.1,
            'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 0.95, 0.05),
            'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.6, 0.95, 0.05),
            'max_depth':  trial.suggest_int('max_depth', 3, 9),
            'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
            'min_child_weight': trial.suggest_loguniform('min_child_weight', 0.1, 10.0),
            'tree_method': 'gpu_hist'
        }
        
        ### START: CV Loop ###
        isBreakCV = False
        fold_iter = 0
        rmse_mean = 0.
        while not(isBreakCV):
            start = time.time()   # start timer
            
            d_valid_last = VALID_LAST_DAY - NUM_FOLD_DAYS * fold_iter
            d_train_last = VALID_LAST_DAY - NUM_FOLD_DAYS * (fold_iter + 1)
            if d_train_last < TRAIN_FIRST_DAY + NUM_FOLD_DAYS * 2:
                isBreakCV = True
            
            # make_new_feature
#             df_fold_file = os.path.join(data_dir, 'data_foldday'+str(NUM_FOLD_DAYS)+'_fold'+str(fold_iter + 1)+'.pkl')
            df_fold_file = os.path.join(data_dir, 'data_foldday'+str(NUM_FOLD_DAYS)+'_fold'+str(fold_iter + 1)+'_lagOlder28Modified.pkl')
            
            if os.path.isfile(df_fold_file):   # make_new_feature 適用後のファイルがあればそれを使う
                df_fold = pd.read_pickle(df_fold_file)
            else:
                df_fold = df[df['d'] <= d_valid_last]
                df_fold = make_new_feature(df_fold, d_train_last)   # train の情報だけを使って特徴量を作成
                df_fold.to_pickle(df_fold_file)   # pickleとして保存しておく

            # Extract store
            df_fold = df_fold[df_fold['store_id'] == store]
                        
            # Split data
            X_train = df_fold[(df_fold['d'] >= TRAIN_FIRST_DAY) & (df_fold['d'] <= d_train_last)].drop('sold', axis=1)
            y_train = df_fold[(df_fold['d'] >= TRAIN_FIRST_DAY) & (df_fold['d'] <= d_train_last)]['sold']
            X_valid = df_fold[(df_fold['d'] > d_train_last) & (df_fold['d'] <= d_valid_last)].drop('sold', axis=1)
            y_valid = df_fold[(df_fold['d'] > d_train_last) & (df_fold['d'] <= d_valid_last)]['sold']
            
            # Train XGBoost model
            model = xgb.XGBRegressor(**param)
#             model.fit(X_train, y_train, eval_set=[(X_train,y_train), (X_valid, y_valid)],
#                  eval_metric='rmse', verbose=10, early_stopping_rounds=100)
            model.fit(X_train, y_train, eval_set=[(X_valid, y_valid)],
                  eval_metric='rmse', verbose=10, early_stopping_rounds=50)
            y_pred = model.predict(X_valid)
            rmse_mean += np.sqrt(mean_squared_error(y_valid.values, y_pred))
            
            fold_iter += 1
            elapsed_time = time.time() - start   # stop timer
            print("[{0}] Fold{1}: {2} [sec]".format(d_store_id[store], fold_iter, elapsed_time))
        ### END: CV Loop ###
        
        del df_fold, model, X_train, y_train, X_valid, y_valid, y_pred
        gc.collect()
        
        rmse_mean /= fold_iter
        return rmse_mean
    return objective

# %% [markdown]
# ## Execute CV

# %%
stores = sales.store_id.cat.codes.unique().tolist()

# find best params by doing CV (optuna)
for store in tqdm(stores[5:]):
    print('##################### CV START: {0} #####################'.format(d_store_id[store]))
    study = optuna.create_study()
    study.optimize(xgboost_cv_store(df, store), n_trials=OPTUNA_TRIAL)
    
    # save optuna log
    df_trial = study.trials_dataframe()
#     df_trial.to_pickle(os.path.join('report', 'OptunaTrials_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.pkl'))
    df_trial.to_pickle(os.path.join('report', 'OptunaTrials_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'_lagOlder28Modified.pkl'))
    
    del df_trial
    gc.collect()
    
    # savae best params found by CV
#     bestparam_filename = 'BestParamsSelectedByCV_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.pkl'
    bestparam_filename = 'BestParamsSelectedByCV_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'_lagOlder28Modified.pkl'
    with open(os.path.join('result', 'best_param_cv', bestparam_filename), 'wb') as f:
        pickle.dump(study.best_params, f)
# Out:
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# ##################### CV START: TX_2 #####################
# [0]	validation_0-rmse:3.60495
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.76390
# [20]	validation_0-rmse:2.61986
# [30]	validation_0-rmse:2.56457
# [40]	validation_0-rmse:2.58455
# [50]	validation_0-rmse:2.58544
# [60]	validation_0-rmse:2.56771
# [70]	validation_0-rmse:2.55816
# [80]	validation_0-rmse:2.56009
# Stopping. Best iteration:
# [39]	validation_0-rmse:2.54629
#
# [TX_2] Fold1: 14.465291738510132 [sec]
# [0]	validation_0-rmse:3.95979
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.17383
# [20]	validation_0-rmse:3.03018
# [30]	validation_0-rmse:2.95976
# [40]	validation_0-rmse:2.94666
# [50]	validation_0-rmse:3.04966
# [60]	validation_0-rmse:3.03805
# [70]	validation_0-rmse:3.03242
# [80]	validation_0-rmse:3.03992
# Stopping. Best iteration:
# [39]	validation_0-rmse:2.93812
#
# [TX_2] Fold2: 13.590155124664307 [sec]
# [0]	validation_0-rmse:3.59203
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.85570
# [20]	validation_0-rmse:2.75478
# [30]	validation_0-rmse:2.71991
# [40]	validation_0-rmse:2.76716
# [50]	validation_0-rmse:2.77751
# [60]	validation_0-rmse:2.77861
# [70]	validation_0-rmse:2.77982
# [80]	validation_0-rmse:2.77361
# Stopping. Best iteration:
# [39]	validation_0-rmse:2.71054
#
# [TX_2] Fold3: 12.561830997467041 [sec]
# [0]	validation_0-rmse:3.70441
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.96604
# [20]	validation_0-rmse:2.88225
# [30]	validation_0-rmse:2.83906
# [40]	validation_0-rmse:2.82135
# [50]	validation_0-rmse:2.81093
# [60]	validation_0-rmse:2.82196
# [70]	validation_0-rmse:2.82533
# [80]	validation_0-rmse:2.82377
# [90]	validation_0-rmse:2.82210
# [100]	validation_0-rmse:2.82293
# Stopping. Best iteration:
# [50]	validation_0-rmse:2.81093
#
# [TX_2] Fold4: 11.964693784713745 [sec]
# [0]	validation_0-rmse:3.75960
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.88022
# [20]	validation_0-rmse:2.77593
# [30]	validation_0-rmse:2.73702
# [40]	validation_0-rmse:2.74150
# [50]	validation_0-rmse:2.73989
# [60]	validation_0-rmse:2.74413
# [70]	validation_0-rmse:2.73733
# [80]	validation_0-rmse:2.75958
# Stopping. Best iteration:
# [39]	validation_0-rmse:2.72221
#
# [TX_2] Fold5: 10.53469204902649 [sec]
# [I 2020-06-30 21:09:47,257] Finished trial#0 with value: 2.7456154823303223 with parameters: {'subsample': 0.85, 'colsample_bytree': 0.85, 'max_depth': 9, 'gamma': 1.225405273875263e-07, 'min_child_weight': 0.1938952836239413}. Best is trial#0 with value: 2.7456154823303223.
# [0]	validation_0-rmse:3.46890
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.79489
# [20]	validation_0-rmse:2.73769
# [30]	validation_0-rmse:2.70635
# [40]	validation_0-rmse:2.66744
# [50]	validation_0-rmse:2.64374
# [60]	validation_0-rmse:2.61368
# [70]	validation_0-rmse:2.60024
# [80]	validation_0-rmse:2.59886
# [90]	validation_0-rmse:2.60682
# [100]	validation_0-rmse:2.60342
# [110]	validation_0-rmse:2.61031
# [120]	validation_0-rmse:2.58673
# [130]	validation_0-rmse:2.58351
# [140]	validation_0-rmse:2.58453
# [150]	validation_0-rmse:2.57717
# [160]	validation_0-rmse:2.57194
# [170]	validation_0-rmse:2.56920
# [180]	validation_0-rmse:2.56975
# [190]	validation_0-rmse:2.57091
# [200]	validation_0-rmse:2.56667
# [210]	validation_0-rmse:2.56603
# [220]	validation_0-rmse:2.56651
# [230]	validation_0-rmse:2.56963
# [240]	validation_0-rmse:2.56794
# [250]	validation_0-rmse:2.56447
# [260]	validation_0-rmse:2.56236
# [270]	validation_0-rmse:2.56452
# [280]	validation_0-rmse:2.56199
# [290]	validation_0-rmse:2.55463
# [300]	validation_0-rmse:2.55401
# [310]	validation_0-rmse:2.55488
# [320]	validation_0-rmse:2.54725
# [330]	validation_0-rmse:2.54502
# [340]	validation_0-rmse:2.54396
# [350]	validation_0-rmse:2.54548
# [360]	validation_0-rmse:2.56118
# [370]	validation_0-rmse:2.56173
# [380]	validation_0-rmse:2.56296
# [390]	validation_0-rmse:2.56326
# Stopping. Best iteration:
# [344]	validation_0-rmse:2.54176
#
# [TX_2] Fold1: 14.901947498321533 [sec]
# [0]	validation_0-rmse:3.84016
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.16692
# [20]	validation_0-rmse:3.03639
# [30]	validation_0-rmse:3.01131
# [40]	validation_0-rmse:2.95022
# [50]	validation_0-rmse:2.92635
# [60]	validation_0-rmse:2.89836
# [70]	validation_0-rmse:2.92401
# [80]	validation_0-rmse:2.92621
# [90]	validation_0-rmse:2.93198
# [100]	validation_0-rmse:2.93097
# Stopping. Best iteration:
# [59]	validation_0-rmse:2.89640
#
# [TX_2] Fold2: 8.452237844467163 [sec]
# [0]	validation_0-rmse:3.49102
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.94436
# [20]	validation_0-rmse:2.88051
# [30]	validation_0-rmse:2.82315
# [40]	validation_0-rmse:2.77151
# [50]	validation_0-rmse:2.76180
# [60]	validation_0-rmse:2.75123
# [70]	validation_0-rmse:2.76281
# [80]	validation_0-rmse:2.76627
# [90]	validation_0-rmse:2.77420
# [100]	validation_0-rmse:2.77736
# Stopping. Best iteration:
# [57]	validation_0-rmse:2.74711
#
# [TX_2] Fold3: 7.886567115783691 [sec]
# [0]	validation_0-rmse:3.59167
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.93991
# [20]	validation_0-rmse:2.87238
# [30]	validation_0-rmse:2.82546
# [40]	validation_0-rmse:2.78673
# [50]	validation_0-rmse:2.77962
# [60]	validation_0-rmse:2.78151
# [70]	validation_0-rmse:2.76798
# [80]	validation_0-rmse:2.78985
# [90]	validation_0-rmse:2.79869
# [100]	validation_0-rmse:2.80022
# [110]	validation_0-rmse:2.80966
# [120]	validation_0-rmse:2.81877
# Stopping. Best iteration:
# [71]	validation_0-rmse:2.76790
#
# [TX_2] Fold4: 7.370474815368652 [sec]
# [0]	validation_0-rmse:3.60984
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.85778
# [20]	validation_0-rmse:2.86197
# [30]	validation_0-rmse:2.82687
# [40]	validation_0-rmse:2.76111
# [50]	validation_0-rmse:2.74572
# [60]	validation_0-rmse:2.74348
# [70]	validation_0-rmse:2.72771
# [80]	validation_0-rmse:2.73138
# [90]	validation_0-rmse:2.73388
# [100]	validation_0-rmse:2.73196
# [110]	validation_0-rmse:2.72718
# [120]	validation_0-rmse:2.71844
# [130]	validation_0-rmse:2.72155
# [140]	validation_0-rmse:2.72643
# [150]	validation_0-rmse:2.72727
# [160]	validation_0-rmse:2.71775
# [170]	validation_0-rmse:2.71357
# [180]	validation_0-rmse:2.71684
# [190]	validation_0-rmse:2.71790
# [200]	validation_0-rmse:2.71359
# [210]	validation_0-rmse:2.71805
# Stopping. Best iteration:
# [166]	validation_0-rmse:2.71295
#
# [TX_2] Fold5: 7.766991138458252 [sec]
# [I 2020-06-30 21:10:33,813] Finished trial#1 with value: 2.7332220554351805 with parameters: {'subsample': 0.9, 'colsample_bytree': 0.65, 'max_depth': 4, 'gamma': 0.00040720358754261723, 'min_child_weight': 1.0070213226690587}. Best is trial#1 with value: 2.7332220554351805.
# [0]	validation_0-rmse:3.47118
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.78490
# [20]	validation_0-rmse:2.65720
# [30]	validation_0-rmse:2.60263
# [40]	validation_0-rmse:2.57012
# [50]	validation_0-rmse:2.53651
# [60]	validation_0-rmse:2.55128
# [70]	validation_0-rmse:2.52430
# [80]	validation_0-rmse:2.52908
# [90]	validation_0-rmse:2.53666
# [100]	validation_0-rmse:2.53038
# [110]	validation_0-rmse:2.53330
# [120]	validation_0-rmse:2.53513
# Stopping. Best iteration:
# [71]	validation_0-rmse:2.52395
#
# [TX_2] Fold1: 9.270452737808228 [sec]
# [0]	validation_0-rmse:3.84264
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.21326
# [20]	validation_0-rmse:3.10122
# [30]	validation_0-rmse:3.02887
# [40]	validation_0-rmse:2.95341
# [50]	validation_0-rmse:2.93111
# [60]	validation_0-rmse:2.93014
# [70]	validation_0-rmse:2.91094
# [80]	validation_0-rmse:2.90461
# [90]	validation_0-rmse:2.89833
# [100]	validation_0-rmse:2.89566
# [110]	validation_0-rmse:2.88917
# [120]	validation_0-rmse:2.88699
# [130]	validation_0-rmse:2.86759
# [140]	validation_0-rmse:2.86328
# [150]	validation_0-rmse:2.86011
# [160]	validation_0-rmse:2.86863
# [170]	validation_0-rmse:2.86001
# [180]	validation_0-rmse:2.86035
# [190]	validation_0-rmse:2.85890
# [200]	validation_0-rmse:2.85865
# [210]	validation_0-rmse:2.86288
# [220]	validation_0-rmse:2.86155
# [230]	validation_0-rmse:2.85777
# [240]	validation_0-rmse:2.84855
# [250]	validation_0-rmse:2.84772
# [260]	validation_0-rmse:2.85806
# [270]	validation_0-rmse:2.85339
# [280]	validation_0-rmse:2.85435
# [290]	validation_0-rmse:2.85534
# [300]	validation_0-rmse:2.85621
# Stopping. Best iteration:
# [252]	validation_0-rmse:2.84196
#
# [TX_2] Fold2: 12.103272676467896 [sec]
# [0]	validation_0-rmse:3.48956
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.91670
# [20]	validation_0-rmse:2.84428
# [30]	validation_0-rmse:2.79949
# [40]	validation_0-rmse:2.74294
# [50]	validation_0-rmse:2.73570
# [60]	validation_0-rmse:2.73743
# [70]	validation_0-rmse:2.73009
# [80]	validation_0-rmse:2.73301
# [90]	validation_0-rmse:2.73986
# Stopping. Best iteration:
# [46]	validation_0-rmse:2.72934
#
# [TX_2] Fold3: 7.729506969451904 [sec]
# [0]	validation_0-rmse:3.59427
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.95875
# [20]	validation_0-rmse:2.86387
# [30]	validation_0-rmse:2.83666
# [40]	validation_0-rmse:2.79132
# [50]	validation_0-rmse:2.79298
# [60]	validation_0-rmse:2.79869
# [70]	validation_0-rmse:2.80556
# [80]	validation_0-rmse:2.81850
# [90]	validation_0-rmse:2.82449
# Stopping. Best iteration:
# [45]	validation_0-rmse:2.78665
#
# [TX_2] Fold4: 7.065265417098999 [sec]
# [0]	validation_0-rmse:3.60938
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.86670
# [20]	validation_0-rmse:2.77455
# [30]	validation_0-rmse:2.70518
# [40]	validation_0-rmse:2.63092
# [50]	validation_0-rmse:2.61730
# [60]	validation_0-rmse:2.62278
# [70]	validation_0-rmse:2.61366
# [80]	validation_0-rmse:2.61040
# [90]	validation_0-rmse:2.60617
# [100]	validation_0-rmse:2.60435
# [110]	validation_0-rmse:2.60886
# [120]	validation_0-rmse:2.60768
# [130]	validation_0-rmse:2.60716
# [140]	validation_0-rmse:2.60296
# [150]	validation_0-rmse:2.59973
# [160]	validation_0-rmse:2.59924
# [170]	validation_0-rmse:2.59710
# [180]	validation_0-rmse:2.59814
# [190]	validation_0-rmse:2.59156
# [200]	validation_0-rmse:2.59360
# [210]	validation_0-rmse:2.59682
# [220]	validation_0-rmse:2.59882
# [230]	validation_0-rmse:2.60107
# [240]	validation_0-rmse:2.60442
# Stopping. Best iteration:
# [190]	validation_0-rmse:2.59156
#
# [TX_2] Fold5: 7.850543260574341 [sec]
# [I 2020-06-30 21:11:17,990] Finished trial#2 with value: 2.6946929454803468 with parameters: {'subsample': 0.7, 'colsample_bytree': 0.65, 'max_depth': 4, 'gamma': 1.6818407250916347e-06, 'min_child_weight': 0.4118247608158735}. Best is trial#2 with value: 2.6946929454803468.
# [0]	validation_0-rmse:3.59709
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.69028
# [20]	validation_0-rmse:2.58746
# [30]	validation_0-rmse:2.55494
# [40]	validation_0-rmse:2.51674
# [50]	validation_0-rmse:2.49953
# [60]	validation_0-rmse:2.49636
# [70]	validation_0-rmse:2.49632
# [80]	validation_0-rmse:2.48298
# [90]	validation_0-rmse:2.46450
# [100]	validation_0-rmse:2.44907
# [110]	validation_0-rmse:2.45278
# [120]	validation_0-rmse:2.43933
# [130]	validation_0-rmse:2.44029
# [140]	validation_0-rmse:2.43858
# [150]	validation_0-rmse:2.44316
# [160]	validation_0-rmse:2.44210
# [170]	validation_0-rmse:2.44331
# [180]	validation_0-rmse:2.43531
# [190]	validation_0-rmse:2.44902
# [200]	validation_0-rmse:2.44689
# [210]	validation_0-rmse:2.44402
# [220]	validation_0-rmse:2.44145
# Stopping. Best iteration:
# [178]	validation_0-rmse:2.43506
#
# [TX_2] Fold1: 13.850354194641113 [sec]
# [0]	validation_0-rmse:3.94932
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.96522
# [20]	validation_0-rmse:2.88680
# [30]	validation_0-rmse:2.84323
# [40]	validation_0-rmse:2.81362
# [50]	validation_0-rmse:2.79153
# [60]	validation_0-rmse:2.78632
# [70]	validation_0-rmse:2.78361
# [80]	validation_0-rmse:2.76596
# [90]	validation_0-rmse:2.76531
# [100]	validation_0-rmse:2.76000
# [110]	validation_0-rmse:2.74786
# [120]	validation_0-rmse:2.74881
# [130]	validation_0-rmse:2.74766
# [140]	validation_0-rmse:2.74188
# [150]	validation_0-rmse:2.73515
# [160]	validation_0-rmse:2.73560
# [170]	validation_0-rmse:2.73550
# [180]	validation_0-rmse:2.72821
# [190]	validation_0-rmse:2.73285
# [200]	validation_0-rmse:2.73043
# [210]	validation_0-rmse:2.73111
# [220]	validation_0-rmse:2.74277
# [230]	validation_0-rmse:2.75400
# Stopping. Best iteration:
# [185]	validation_0-rmse:2.72329
#
# [TX_2] Fold2: 13.174957275390625 [sec]
# [0]	validation_0-rmse:3.59302
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.82146
# [20]	validation_0-rmse:2.74309
# [30]	validation_0-rmse:2.70097
# [40]	validation_0-rmse:2.68061
# [50]	validation_0-rmse:2.67749
# [60]	validation_0-rmse:2.68124
# [70]	validation_0-rmse:2.68328
# [80]	validation_0-rmse:2.67847
# [90]	validation_0-rmse:2.67712
# [100]	validation_0-rmse:2.67555
# [110]	validation_0-rmse:2.67930
# [120]	validation_0-rmse:2.67451
# [130]	validation_0-rmse:2.67576
# [140]	validation_0-rmse:2.67603
# [150]	validation_0-rmse:2.67763
# [160]	validation_0-rmse:2.67633
# [170]	validation_0-rmse:2.68004
# Stopping. Best iteration:
# [127]	validation_0-rmse:2.67171
#
# [TX_2] Fold3: 10.802994966506958 [sec]
# [0]	validation_0-rmse:3.69401
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.86751
# [20]	validation_0-rmse:2.79671
# [30]	validation_0-rmse:2.77939
# [40]	validation_0-rmse:2.76679
# [50]	validation_0-rmse:2.76062
# [60]	validation_0-rmse:2.75156
# [70]	validation_0-rmse:2.74159
# [80]	validation_0-rmse:2.73916
# [90]	validation_0-rmse:2.73929
# [100]	validation_0-rmse:2.73590
# [110]	validation_0-rmse:2.73263
# [120]	validation_0-rmse:2.73491
# [130]	validation_0-rmse:2.73347
# [140]	validation_0-rmse:2.73320
# [150]	validation_0-rmse:2.73497
# Stopping. Best iteration:
# [106]	validation_0-rmse:2.73233
#
# [TX_2] Fold4: 8.911272525787354 [sec]
# [0]	validation_0-rmse:3.74176
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.91133
# [20]	validation_0-rmse:2.81763
# [30]	validation_0-rmse:2.75350
# [40]	validation_0-rmse:2.71310
# [50]	validation_0-rmse:2.68104
# [60]	validation_0-rmse:2.67462
# [70]	validation_0-rmse:2.66406
# [80]	validation_0-rmse:2.66375
# [90]	validation_0-rmse:2.66030
# [100]	validation_0-rmse:2.65604
# [110]	validation_0-rmse:2.65898
# [120]	validation_0-rmse:2.64841
# [130]	validation_0-rmse:2.66279
# [140]	validation_0-rmse:2.66120
# [150]	validation_0-rmse:2.66334
# [160]	validation_0-rmse:2.66289
# Stopping. Best iteration:
# [119]	validation_0-rmse:2.64819
#
# [TX_2] Fold5: 8.402895450592041 [sec]
# [I 2020-06-30 21:12:13,305] Finished trial#3 with value: 2.642116832733154 with parameters: {'subsample': 0.85, 'colsample_bytree': 0.75, 'max_depth': 6, 'gamma': 0.04981085863799335, 'min_child_weight': 0.4511100872353685}. Best is trial#3 with value: 2.642116832733154.
# [0]	validation_0-rmse:3.59473
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.11553
# [20]	validation_0-rmse:3.15188
# [30]	validation_0-rmse:3.17598
# [40]	validation_0-rmse:3.18982
# [50]	validation_0-rmse:3.16174
# [60]	validation_0-rmse:3.13536
# Stopping. Best iteration:
# [15]	validation_0-rmse:3.10310
#
# [TX_2] Fold1: 7.998403310775757 [sec]
# [0]	validation_0-rmse:3.94770
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.49144
# [20]	validation_0-rmse:3.50918
# [30]	validation_0-rmse:3.46969
# [40]	validation_0-rmse:3.38612
# [50]	validation_0-rmse:3.33611
# [60]	validation_0-rmse:3.32779
# [70]	validation_0-rmse:3.29830
# [80]	validation_0-rmse:3.26899
# [90]	validation_0-rmse:3.26669
# [100]	validation_0-rmse:3.24029
# [110]	validation_0-rmse:3.22614
# [120]	validation_0-rmse:3.22176
# [130]	validation_0-rmse:3.21473
# [140]	validation_0-rmse:3.20996
# [150]	validation_0-rmse:3.20243
# [160]	validation_0-rmse:3.19478
# [170]	validation_0-rmse:3.18488
# [180]	validation_0-rmse:3.17916
# [190]	validation_0-rmse:3.17908
# [200]	validation_0-rmse:3.17579
# [210]	validation_0-rmse:3.16253
# [220]	validation_0-rmse:3.16213
# [230]	validation_0-rmse:3.16124
# [240]	validation_0-rmse:3.14789
# [250]	validation_0-rmse:3.13015
# [260]	validation_0-rmse:3.13019
# [270]	validation_0-rmse:3.12916
# [280]	validation_0-rmse:3.13221
# [290]	validation_0-rmse:3.13121
# [300]	validation_0-rmse:3.13106
# [310]	validation_0-rmse:3.12656
# [320]	validation_0-rmse:3.11972
# [330]	validation_0-rmse:3.11989
# [340]	validation_0-rmse:3.11859
# [350]	validation_0-rmse:3.11844
# [360]	validation_0-rmse:3.11482
# [370]	validation_0-rmse:3.10684
# [380]	validation_0-rmse:3.10260
# [390]	validation_0-rmse:3.09900
# [400]	validation_0-rmse:3.09643
# [410]	validation_0-rmse:3.08817
# [420]	validation_0-rmse:3.07865
# [430]	validation_0-rmse:3.07656
# [440]	validation_0-rmse:3.07383
# [450]	validation_0-rmse:3.07217
# [460]	validation_0-rmse:3.07096
# [470]	validation_0-rmse:3.07272
# [480]	validation_0-rmse:3.06734
# [490]	validation_0-rmse:3.06127
# [500]	validation_0-rmse:3.05616
# [510]	validation_0-rmse:3.05924
# [520]	validation_0-rmse:3.06243
# [530]	validation_0-rmse:3.05930
# [540]	validation_0-rmse:3.06627
# [550]	validation_0-rmse:3.06817
# Stopping. Best iteration:
# [504]	validation_0-rmse:3.05560
#
# [TX_2] Fold2: 15.939695596694946 [sec]
# [0]	validation_0-rmse:3.59919
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.13628
# [20]	validation_0-rmse:3.15100
# [30]	validation_0-rmse:3.12660
# [40]	validation_0-rmse:3.12944
# [50]	validation_0-rmse:3.08926
# [60]	validation_0-rmse:3.08223
# [70]	validation_0-rmse:3.06263
# [80]	validation_0-rmse:3.03058
# [90]	validation_0-rmse:3.01822
# [100]	validation_0-rmse:3.00627
# [110]	validation_0-rmse:3.00360
# [120]	validation_0-rmse:2.99703
# [130]	validation_0-rmse:2.98491
# [140]	validation_0-rmse:2.98124
# [150]	validation_0-rmse:2.97507
# [160]	validation_0-rmse:2.97058
# [170]	validation_0-rmse:2.96746
# [180]	validation_0-rmse:2.96359
# [190]	validation_0-rmse:2.96333
# [200]	validation_0-rmse:2.97457
# [210]	validation_0-rmse:2.97708
# [220]	validation_0-rmse:2.97093
# [230]	validation_0-rmse:2.96459
# Stopping. Best iteration:
# [188]	validation_0-rmse:2.96219
#
# [TX_2] Fold3: 9.890716075897217 [sec]
# [0]	validation_0-rmse:3.70972
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.24914
# [20]	validation_0-rmse:3.26977
# [30]	validation_0-rmse:3.26174
# [40]	validation_0-rmse:3.21664
# [50]	validation_0-rmse:3.19866
# [60]	validation_0-rmse:3.20380
# [70]	validation_0-rmse:3.18542
# [80]	validation_0-rmse:3.17160
# [90]	validation_0-rmse:3.17841
# [100]	validation_0-rmse:3.17597
# [110]	validation_0-rmse:3.17627
# [120]	validation_0-rmse:3.16940
# [130]	validation_0-rmse:3.16224
# [140]	validation_0-rmse:3.15731
# [150]	validation_0-rmse:3.14914
# [160]	validation_0-rmse:3.14895
# [170]	validation_0-rmse:3.14712
# [180]	validation_0-rmse:3.14827
# [190]	validation_0-rmse:3.15462
# [200]	validation_0-rmse:3.15166
# [210]	validation_0-rmse:3.14776
# [220]	validation_0-rmse:3.14007
# [230]	validation_0-rmse:3.13552
# [240]	validation_0-rmse:3.13703
# [250]	validation_0-rmse:3.13494
# [260]	validation_0-rmse:3.13744
# [270]	validation_0-rmse:3.13419
# [280]	validation_0-rmse:3.13157
# [290]	validation_0-rmse:3.13039
# [300]	validation_0-rmse:3.11858
# [310]	validation_0-rmse:3.12075
# [320]	validation_0-rmse:3.11939
# [330]	validation_0-rmse:3.11793
# [340]	validation_0-rmse:3.12561
# [350]	validation_0-rmse:3.12457
# [360]	validation_0-rmse:3.11951
# [370]	validation_0-rmse:3.11634
# [380]	validation_0-rmse:3.12096
# [390]	validation_0-rmse:3.12004
# [400]	validation_0-rmse:3.11359
# [410]	validation_0-rmse:3.11248
# [420]	validation_0-rmse:3.11402
# [430]	validation_0-rmse:3.11249
# [440]	validation_0-rmse:3.11118
# [450]	validation_0-rmse:3.10861
# [460]	validation_0-rmse:3.10741
# [470]	validation_0-rmse:3.10751
# [480]	validation_0-rmse:3.10985
# [490]	validation_0-rmse:3.10966
# [500]	validation_0-rmse:3.11077
# [510]	validation_0-rmse:3.11117
# Stopping. Best iteration:
# [467]	validation_0-rmse:3.10656
#
# [TX_2] Fold4: 11.792002201080322 [sec]
# [0]	validation_0-rmse:3.74975
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.18944
# [20]	validation_0-rmse:3.22212
# [30]	validation_0-rmse:3.19247
# [40]	validation_0-rmse:3.19214
# [50]	validation_0-rmse:3.14894
# [60]	validation_0-rmse:3.13722
# [70]	validation_0-rmse:3.15280
# [80]	validation_0-rmse:3.15194
# [90]	validation_0-rmse:3.15272
# [100]	validation_0-rmse:3.14303
# Stopping. Best iteration:
# [57]	validation_0-rmse:3.12736
#
# [TX_2] Fold5: 6.255491733551025 [sec]
# [I 2020-06-30 21:13:05,348] Finished trial#4 with value: 3.0709649085998536 with parameters: {'subsample': 0.95, 'colsample_bytree': 0.8, 'max_depth': 3, 'gamma': 2.1862635418108604e-07, 'min_child_weight': 8.27039125466486}. Best is trial#3 with value: 2.642116832733154.
# [0]	validation_0-rmse:3.44778
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.45122
# [20]	validation_0-rmse:2.38560
# [30]	validation_0-rmse:2.34566
# [40]	validation_0-rmse:2.31829
# [50]	validation_0-rmse:2.30086
# [60]	validation_0-rmse:2.31116
# [70]	validation_0-rmse:2.31082
# [80]	validation_0-rmse:2.31309
# [90]	validation_0-rmse:2.31471
# [100]	validation_0-rmse:2.31509
# Stopping. Best iteration:
# [50]	validation_0-rmse:2.30086
#
# [TX_2] Fold1: 12.443676471710205 [sec]
# [0]	validation_0-rmse:3.87050
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.96145
# [20]	validation_0-rmse:2.87218
# [30]	validation_0-rmse:2.83259
# [40]	validation_0-rmse:2.79368
# [50]	validation_0-rmse:2.78835
# [60]	validation_0-rmse:2.78776
# [70]	validation_0-rmse:2.78888
# [80]	validation_0-rmse:2.78604
# [90]	validation_0-rmse:2.78385
# [100]	validation_0-rmse:2.78618
# [110]	validation_0-rmse:2.78611
# [120]	validation_0-rmse:2.78594
# [130]	validation_0-rmse:2.78302
# [140]	validation_0-rmse:2.78314
# Stopping. Best iteration:
# [91]	validation_0-rmse:2.78280
#
# [TX_2] Fold2: 14.019497632980347 [sec]
# [0]	validation_0-rmse:3.50171
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.69054
# [20]	validation_0-rmse:2.66113
# [30]	validation_0-rmse:2.63979
# [40]	validation_0-rmse:2.63559
# [50]	validation_0-rmse:2.63454
# [60]	validation_0-rmse:2.64652
# [70]	validation_0-rmse:2.65105
# [80]	validation_0-rmse:2.65294
# [90]	validation_0-rmse:2.65175
# Stopping. Best iteration:
# [44]	validation_0-rmse:2.63066
#
# [TX_2] Fold3: 10.726777076721191 [sec]
# [0]	validation_0-rmse:3.57637
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.76902
# [20]	validation_0-rmse:2.70548
# [30]	validation_0-rmse:2.68671
# [40]	validation_0-rmse:2.66315
# [50]	validation_0-rmse:2.67195
# [60]	validation_0-rmse:2.67579
# [70]	validation_0-rmse:2.68072
# [80]	validation_0-rmse:2.67984
# [90]	validation_0-rmse:2.68036
# Stopping. Best iteration:
# [43]	validation_0-rmse:2.66104
#
# [TX_2] Fold4: 9.870228290557861 [sec]
# [0]	validation_0-rmse:3.60162
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.59493
# [20]	validation_0-rmse:2.54446
# [30]	validation_0-rmse:2.51476
# [40]	validation_0-rmse:2.49309
# [50]	validation_0-rmse:2.49456
# [60]	validation_0-rmse:2.49393
# [70]	validation_0-rmse:2.49866
# [80]	validation_0-rmse:2.49909
# [90]	validation_0-rmse:2.49792
# Stopping. Best iteration:
# [43]	validation_0-rmse:2.48448
#
# [TX_2] Fold5: 8.955602169036865 [sec]
# [I 2020-06-30 21:14:01,526] Finished trial#5 with value: 2.5719700336456297 with parameters: {'subsample': 0.8, 'colsample_bytree': 0.6, 'max_depth': 8, 'gamma': 1.4694272121635845e-08, 'min_child_weight': 0.25199692639983184}. Best is trial#5 with value: 2.5719700336456297.
# [0]	validation_0-rmse:3.57667
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.94787
# [20]	validation_0-rmse:2.89330
# [30]	validation_0-rmse:2.90727
# [40]	validation_0-rmse:2.88339
# [50]	validation_0-rmse:2.89041
# [60]	validation_0-rmse:2.84889
# [70]	validation_0-rmse:2.82722
# [80]	validation_0-rmse:2.86401
# [90]	validation_0-rmse:2.85858
# [100]	validation_0-rmse:2.85726
# [110]	validation_0-rmse:2.87154
# Stopping. Best iteration:
# [67]	validation_0-rmse:2.82426
#
# [TX_2] Fold1: 9.180057764053345 [sec]
# [0]	validation_0-rmse:3.93458
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.24715
# [20]	validation_0-rmse:3.16812
# [30]	validation_0-rmse:3.14856
# [40]	validation_0-rmse:3.12200
# [50]	validation_0-rmse:3.10457
# [60]	validation_0-rmse:3.08080
# [70]	validation_0-rmse:3.06264
# [80]	validation_0-rmse:3.04402
# [90]	validation_0-rmse:3.03120
# [100]	validation_0-rmse:3.02470
# [110]	validation_0-rmse:3.02391
# [120]	validation_0-rmse:3.02441
# [130]	validation_0-rmse:3.01933
# [140]	validation_0-rmse:3.03512
# [150]	validation_0-rmse:3.03247
# [160]	validation_0-rmse:3.01405
# [170]	validation_0-rmse:2.99875
# [180]	validation_0-rmse:2.99512
# [190]	validation_0-rmse:3.00267
# [200]	validation_0-rmse:3.00379
# [210]	validation_0-rmse:3.00815
# [220]	validation_0-rmse:3.01143
# Stopping. Best iteration:
# [175]	validation_0-rmse:2.99349
#
# [TX_2] Fold2: 10.82686471939087 [sec]
# [0]	validation_0-rmse:3.57678
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.04675
# [20]	validation_0-rmse:2.99294
# [30]	validation_0-rmse:3.00121
# [40]	validation_0-rmse:2.96860
# [50]	validation_0-rmse:2.96486
# [60]	validation_0-rmse:2.93849
# [70]	validation_0-rmse:2.92606
# [80]	validation_0-rmse:2.92906
# [90]	validation_0-rmse:2.93057
# [100]	validation_0-rmse:2.91785
# [110]	validation_0-rmse:2.93650
# [120]	validation_0-rmse:2.92827
# [130]	validation_0-rmse:2.92631
# [140]	validation_0-rmse:2.93545
# [150]	validation_0-rmse:2.93818
# Stopping. Best iteration:
# [101]	validation_0-rmse:2.91740
#
# [TX_2] Fold3: 8.58706259727478 [sec]
# [0]	validation_0-rmse:3.69017
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.15002
# [20]	validation_0-rmse:3.08421
# [30]	validation_0-rmse:3.05898
# [40]	validation_0-rmse:3.01911
# [50]	validation_0-rmse:3.02000
# [60]	validation_0-rmse:3.01365
# [70]	validation_0-rmse:3.00561
# [80]	validation_0-rmse:3.00711
# [90]	validation_0-rmse:2.99846
# [100]	validation_0-rmse:3.00264
# [110]	validation_0-rmse:3.00654
# [120]	validation_0-rmse:3.00924
# [130]	validation_0-rmse:3.00595
# [140]	validation_0-rmse:2.99655
# [150]	validation_0-rmse:2.99666
# [160]	validation_0-rmse:2.99919
# [170]	validation_0-rmse:2.99640
# [180]	validation_0-rmse:2.99905
# [190]	validation_0-rmse:3.00149
# [200]	validation_0-rmse:3.00393
# [210]	validation_0-rmse:3.00523
# [220]	validation_0-rmse:3.00596
# Stopping. Best iteration:
# [175]	validation_0-rmse:2.99284
#
# [TX_2] Fold4: 8.563931226730347 [sec]
# [0]	validation_0-rmse:3.68861
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.12327
# [20]	validation_0-rmse:3.05736
# [30]	validation_0-rmse:2.97069
# [40]	validation_0-rmse:2.91755
# [50]	validation_0-rmse:2.92940
# [60]	validation_0-rmse:2.92349
# [70]	validation_0-rmse:2.90169
# [80]	validation_0-rmse:2.89335
# [90]	validation_0-rmse:2.87540
# [100]	validation_0-rmse:2.86012
# [110]	validation_0-rmse:2.85567
# [120]	validation_0-rmse:2.86076
# [130]	validation_0-rmse:2.85465
# [140]	validation_0-rmse:2.84943
# [150]	validation_0-rmse:2.84582
# [160]	validation_0-rmse:2.84939
# [170]	validation_0-rmse:2.85047
# [180]	validation_0-rmse:2.85018
# [190]	validation_0-rmse:2.84504
# [200]	validation_0-rmse:2.84851
# [210]	validation_0-rmse:2.84716
# [220]	validation_0-rmse:2.84634
# [230]	validation_0-rmse:2.84780
# [240]	validation_0-rmse:2.84808
# Stopping. Best iteration:
# [190]	validation_0-rmse:2.84504
#
# [TX_2] Fold5: 7.846407175064087 [sec]
# [I 2020-06-30 21:14:46,697] Finished trial#6 with value: 2.914606523513794 with parameters: {'subsample': 0.8, 'colsample_bytree': 0.85, 'max_depth': 4, 'gamma': 3.103710533894073e-05, 'min_child_weight': 0.10110171207210424}. Best is trial#5 with value: 2.5719700336456297.
# [0]	validation_0-rmse:3.58095
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.10858
# [20]	validation_0-rmse:3.05883
# [30]	validation_0-rmse:3.01907
# [40]	validation_0-rmse:3.02164
# [50]	validation_0-rmse:3.03353
# [60]	validation_0-rmse:3.00490
# [70]	validation_0-rmse:2.99377
# [80]	validation_0-rmse:2.98678
# [90]	validation_0-rmse:2.94475
# [100]	validation_0-rmse:2.91589
# [110]	validation_0-rmse:2.91110
# [120]	validation_0-rmse:2.89796
# [130]	validation_0-rmse:2.89656
# [140]	validation_0-rmse:2.88170
# [150]	validation_0-rmse:2.86577
# [160]	validation_0-rmse:2.86217
# [170]	validation_0-rmse:2.85841
# [180]	validation_0-rmse:2.85718
# [190]	validation_0-rmse:2.85904
# [200]	validation_0-rmse:2.85814
# [210]	validation_0-rmse:2.84953
# [220]	validation_0-rmse:2.84877
# [230]	validation_0-rmse:2.84289
# [240]	validation_0-rmse:2.84033
# [250]	validation_0-rmse:2.84545
# [260]	validation_0-rmse:2.83737
# [270]	validation_0-rmse:2.82973
# [280]	validation_0-rmse:2.87715
# [290]	validation_0-rmse:2.87344
# [300]	validation_0-rmse:2.87203
# [310]	validation_0-rmse:2.87173
# [320]	validation_0-rmse:2.86862
# Stopping. Best iteration:
# [271]	validation_0-rmse:2.82953
#
# [TX_2] Fold1: 14.450032472610474 [sec]
# [0]	validation_0-rmse:3.93897
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.49365
# [20]	validation_0-rmse:3.37218
# [30]	validation_0-rmse:3.37245
# [40]	validation_0-rmse:3.35582
# [50]	validation_0-rmse:3.37226
# [60]	validation_0-rmse:3.36248
# [70]	validation_0-rmse:3.34448
# [80]	validation_0-rmse:3.31607
# [90]	validation_0-rmse:3.27998
# [100]	validation_0-rmse:3.25317
# [110]	validation_0-rmse:3.23918
# [120]	validation_0-rmse:3.23101
# [130]	validation_0-rmse:3.22536
# [140]	validation_0-rmse:3.22336
# [150]	validation_0-rmse:3.20309
# [160]	validation_0-rmse:3.19901
# [170]	validation_0-rmse:3.19563
# [180]	validation_0-rmse:3.18602
# [190]	validation_0-rmse:3.18748
# [200]	validation_0-rmse:3.19846
# [210]	validation_0-rmse:3.19812
# [220]	validation_0-rmse:3.19698
# Stopping. Best iteration:
# [173]	validation_0-rmse:3.18340
#
# [TX_2] Fold2: 11.381011724472046 [sec]
# [0]	validation_0-rmse:3.58814
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.24205
# [20]	validation_0-rmse:3.20275
# [30]	validation_0-rmse:3.20163
# [40]	validation_0-rmse:3.25127
# [50]	validation_0-rmse:3.27654
# [60]	validation_0-rmse:3.27437
# [70]	validation_0-rmse:3.26321
# Stopping. Best iteration:
# [27]	validation_0-rmse:3.17561
#
# [TX_2] Fold3: 7.599817514419556 [sec]
# [0]	validation_0-rmse:3.69752
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.32030
# [20]	validation_0-rmse:3.24272
# [30]	validation_0-rmse:3.18600
# [40]	validation_0-rmse:3.12687
# [50]	validation_0-rmse:3.13278
# [60]	validation_0-rmse:3.11748
# [70]	validation_0-rmse:3.10292
# [80]	validation_0-rmse:3.08993
# [90]	validation_0-rmse:3.08059
# [100]	validation_0-rmse:3.06935
# [110]	validation_0-rmse:3.05399
# [120]	validation_0-rmse:3.03856
# [130]	validation_0-rmse:3.03505
# [140]	validation_0-rmse:3.03838
# [150]	validation_0-rmse:3.02488
# [160]	validation_0-rmse:3.02251
# [170]	validation_0-rmse:3.01785
# [180]	validation_0-rmse:3.01715
# [190]	validation_0-rmse:3.01675
# [200]	validation_0-rmse:3.01705
# [210]	validation_0-rmse:3.01330
# [220]	validation_0-rmse:3.01457
# [230]	validation_0-rmse:3.01730
# [240]	validation_0-rmse:3.01673
# [250]	validation_0-rmse:3.01477
# [260]	validation_0-rmse:3.01062
# [270]	validation_0-rmse:3.01444
# [280]	validation_0-rmse:3.01667
# [290]	validation_0-rmse:3.01164
# [300]	validation_0-rmse:3.00861
# [310]	validation_0-rmse:3.00848
# [320]	validation_0-rmse:3.01098
# [330]	validation_0-rmse:3.00898
# [340]	validation_0-rmse:3.00733
# [350]	validation_0-rmse:3.00879
# [360]	validation_0-rmse:3.00639
# [370]	validation_0-rmse:3.00222
# [380]	validation_0-rmse:3.00301
# [390]	validation_0-rmse:3.00307
# [400]	validation_0-rmse:3.00117
# [410]	validation_0-rmse:2.99440
# [420]	validation_0-rmse:2.99670
# [430]	validation_0-rmse:2.99372
# [440]	validation_0-rmse:2.99171
# [450]	validation_0-rmse:2.99127
# [460]	validation_0-rmse:2.99016
# [470]	validation_0-rmse:2.99077
# [480]	validation_0-rmse:2.98977
# [490]	validation_0-rmse:2.98879
# [500]	validation_0-rmse:2.98564
# [510]	validation_0-rmse:2.98443
# [520]	validation_0-rmse:2.98710
# [530]	validation_0-rmse:2.98815
# [540]	validation_0-rmse:2.98623
# [550]	validation_0-rmse:2.98215
# [560]	validation_0-rmse:2.97967
# [570]	validation_0-rmse:2.97994
# [580]	validation_0-rmse:2.98010
# [590]	validation_0-rmse:2.97763
# [600]	validation_0-rmse:2.97795
# [610]	validation_0-rmse:2.97734
# [620]	validation_0-rmse:2.97691
# [630]	validation_0-rmse:2.97641
# [640]	validation_0-rmse:2.97606
# [650]	validation_0-rmse:2.97598
# [660]	validation_0-rmse:2.97510
# [670]	validation_0-rmse:2.97633
# [680]	validation_0-rmse:2.97685
# [690]	validation_0-rmse:2.97776
# [700]	validation_0-rmse:2.97705
# [710]	validation_0-rmse:2.98120
# Stopping. Best iteration:
# [660]	validation_0-rmse:2.97510
#
# [TX_2] Fold4: 16.862432956695557 [sec]
# [0]	validation_0-rmse:3.73995
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.35269
# [20]	validation_0-rmse:3.29288
# [30]	validation_0-rmse:3.33148
# [40]	validation_0-rmse:3.36679
# [50]	validation_0-rmse:3.35875
# [60]	validation_0-rmse:3.35173
# [70]	validation_0-rmse:3.32326
# Stopping. Best iteration:
# [23]	validation_0-rmse:3.28551
#
# [TX_2] Fold5: 6.144309997558594 [sec]
# [I 2020-06-30 21:15:43,292] Finished trial#7 with value: 3.089828062057495 with parameters: {'subsample': 0.9, 'colsample_bytree': 0.9, 'max_depth': 5, 'gamma': 1.0379056754710156e-08, 'min_child_weight': 1.393402087291755}. Best is trial#5 with value: 2.5719700336456297.
# [0]	validation_0-rmse:3.57945
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.85036
# [20]	validation_0-rmse:2.79641
# [30]	validation_0-rmse:2.76892
# [40]	validation_0-rmse:2.75494
# [50]	validation_0-rmse:2.75171
# [60]	validation_0-rmse:2.71863
# [70]	validation_0-rmse:2.67901
# [80]	validation_0-rmse:2.67067
# [90]	validation_0-rmse:2.67279
# [100]	validation_0-rmse:2.65785
# [110]	validation_0-rmse:2.65711
# [120]	validation_0-rmse:2.65563
# [130]	validation_0-rmse:2.65151
# [140]	validation_0-rmse:2.65429
# [150]	validation_0-rmse:2.65309
# [160]	validation_0-rmse:2.65610
# [170]	validation_0-rmse:2.65572
# Stopping. Best iteration:
# [124]	validation_0-rmse:2.65017
#
# [TX_2] Fold1: 10.329758644104004 [sec]
# [0]	validation_0-rmse:3.93148
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.24353
# [20]	validation_0-rmse:3.13754
# [30]	validation_0-rmse:3.12073
# [40]	validation_0-rmse:3.06575
# [50]	validation_0-rmse:3.03854
# [60]	validation_0-rmse:3.01486
# [70]	validation_0-rmse:3.00824
# [80]	validation_0-rmse:2.97329
# [90]	validation_0-rmse:2.97931
# [100]	validation_0-rmse:2.98307
# [110]	validation_0-rmse:2.98271
# [120]	validation_0-rmse:2.97446
# [130]	validation_0-rmse:2.97309
# [140]	validation_0-rmse:2.97361
# [150]	validation_0-rmse:2.96945
# [160]	validation_0-rmse:2.96829
# [170]	validation_0-rmse:2.96366
# [180]	validation_0-rmse:2.95668
# [190]	validation_0-rmse:2.95823
# [200]	validation_0-rmse:2.95718
# [210]	validation_0-rmse:2.95035
# [220]	validation_0-rmse:2.94527
# [230]	validation_0-rmse:2.92932
# [240]	validation_0-rmse:2.92556
# [250]	validation_0-rmse:2.93129
# [260]	validation_0-rmse:2.92301
# [270]	validation_0-rmse:2.91468
# [280]	validation_0-rmse:2.91303
# [290]	validation_0-rmse:2.91519
# [300]	validation_0-rmse:2.91340
# [310]	validation_0-rmse:2.91164
# [320]	validation_0-rmse:2.90697
# [330]	validation_0-rmse:2.90737
# [340]	validation_0-rmse:2.89843
# [350]	validation_0-rmse:2.89781
# [360]	validation_0-rmse:2.89048
# [370]	validation_0-rmse:2.88408
# [380]	validation_0-rmse:2.88260
# [390]	validation_0-rmse:2.88122
# [400]	validation_0-rmse:2.88142
# [410]	validation_0-rmse:2.87384
# [420]	validation_0-rmse:2.87180
# [430]	validation_0-rmse:2.86428
# [440]	validation_0-rmse:2.86404
# [450]	validation_0-rmse:2.86361
# [460]	validation_0-rmse:2.86697
# [470]	validation_0-rmse:2.86721
# [480]	validation_0-rmse:2.86642
# [490]	validation_0-rmse:2.86286
# [500]	validation_0-rmse:2.86586
# [510]	validation_0-rmse:2.86483
# [520]	validation_0-rmse:2.86616
# [530]	validation_0-rmse:2.85589
# [540]	validation_0-rmse:2.85726
# [550]	validation_0-rmse:2.85786
# [560]	validation_0-rmse:2.85738
# [570]	validation_0-rmse:2.85725
# Stopping. Best iteration:
# [524]	validation_0-rmse:2.85567
#
# [TX_2] Fold2: 17.273966550827026 [sec]
# [0]	validation_0-rmse:3.56634
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.01402
# [20]	validation_0-rmse:2.93849
# [30]	validation_0-rmse:2.91242
# [40]	validation_0-rmse:2.88059
# [50]	validation_0-rmse:2.86455
# [60]	validation_0-rmse:2.85567
# [70]	validation_0-rmse:2.83973
# [80]	validation_0-rmse:2.83483
# [90]	validation_0-rmse:2.84126
# [100]	validation_0-rmse:2.84055
# [110]	validation_0-rmse:2.83835
# [120]	validation_0-rmse:2.84328
# Stopping. Best iteration:
# [79]	validation_0-rmse:2.83396
#
# [TX_2] Fold3: 8.429868698120117 [sec]
# [0]	validation_0-rmse:3.67640
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.98011
# [20]	validation_0-rmse:2.93875
# [30]	validation_0-rmse:2.93968
# [40]	validation_0-rmse:2.88624
# [50]	validation_0-rmse:2.86509
# [60]	validation_0-rmse:2.86952
# [70]	validation_0-rmse:2.88270
# [80]	validation_0-rmse:2.87627
# [90]	validation_0-rmse:2.89960
# [100]	validation_0-rmse:2.89999
# Stopping. Best iteration:
# [57]	validation_0-rmse:2.86342
#
# [TX_2] Fold4: 7.03998327255249 [sec]
# [0]	validation_0-rmse:3.72401
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.97845
# [20]	validation_0-rmse:2.91264
# [30]	validation_0-rmse:2.86684
# [40]	validation_0-rmse:2.82818
# [50]	validation_0-rmse:2.81519
# [60]	validation_0-rmse:2.80320
# [70]	validation_0-rmse:2.78708
# [80]	validation_0-rmse:2.77580
# [90]	validation_0-rmse:2.77370
# [100]	validation_0-rmse:2.78506
# [110]	validation_0-rmse:2.78136
# [120]	validation_0-rmse:2.78313
# [130]	validation_0-rmse:2.78436
# [140]	validation_0-rmse:2.78471
# Stopping. Best iteration:
# [91]	validation_0-rmse:2.77356
#
# [TX_2] Fold5: 6.721750020980835 [sec]
# [I 2020-06-30 21:16:33,250] Finished trial#8 with value: 2.795354652404785 with parameters: {'subsample': 0.9, 'colsample_bytree': 0.75, 'max_depth': 4, 'gamma': 1.5428642135880798e-08, 'min_child_weight': 3.6609918024041974}. Best is trial#5 with value: 2.5719700336456297.
# [0]	validation_0-rmse:3.57482
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.14082
# [20]	validation_0-rmse:3.02626
# [30]	validation_0-rmse:2.92494
# [40]	validation_0-rmse:2.86769
# [50]	validation_0-rmse:2.88944
# [60]	validation_0-rmse:2.89548
# [70]	validation_0-rmse:2.88671
# [80]	validation_0-rmse:2.89105
# [90]	validation_0-rmse:2.88917
# Stopping. Best iteration:
# [41]	validation_0-rmse:2.86663
#
# [TX_2] Fold1: 8.629385948181152 [sec]
# [0]	validation_0-rmse:3.93611
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.59976
# [20]	validation_0-rmse:3.45226
# [30]	validation_0-rmse:3.37426
# [40]	validation_0-rmse:3.37431
# [50]	validation_0-rmse:3.36140
# [60]	validation_0-rmse:3.36339
# [70]	validation_0-rmse:3.35205
# [80]	validation_0-rmse:3.33124
# [90]	validation_0-rmse:3.31387
# [100]	validation_0-rmse:3.29620
# [110]	validation_0-rmse:3.29122
# [120]	validation_0-rmse:3.28686
# [130]	validation_0-rmse:3.28273
# [140]	validation_0-rmse:3.27409
# [150]	validation_0-rmse:3.26410
# [160]	validation_0-rmse:3.26223
# [170]	validation_0-rmse:3.25676
# [180]	validation_0-rmse:3.24805
# [190]	validation_0-rmse:3.24864
# [200]	validation_0-rmse:3.24259
# [210]	validation_0-rmse:3.23591
# [220]	validation_0-rmse:3.23121
# [230]	validation_0-rmse:3.22208
# [240]	validation_0-rmse:3.22069
# [250]	validation_0-rmse:3.21699
# [260]	validation_0-rmse:3.21349
# [270]	validation_0-rmse:3.21438
# [280]	validation_0-rmse:3.21214
# [290]	validation_0-rmse:3.20787
# [300]	validation_0-rmse:3.20927
# [310]	validation_0-rmse:3.19713
# [320]	validation_0-rmse:3.19399
# [330]	validation_0-rmse:3.19266
# [340]	validation_0-rmse:3.19552
# [350]	validation_0-rmse:3.19526
# [360]	validation_0-rmse:3.19568
# [370]	validation_0-rmse:3.18821
# [380]	validation_0-rmse:3.18642
# [390]	validation_0-rmse:3.18651
# [400]	validation_0-rmse:3.19085
# [410]	validation_0-rmse:3.18886
# [420]	validation_0-rmse:3.18717
# [430]	validation_0-rmse:3.16870
# [440]	validation_0-rmse:3.16570
# [450]	validation_0-rmse:3.16483
# [460]	validation_0-rmse:3.16552
# [470]	validation_0-rmse:3.16446
# [480]	validation_0-rmse:3.16007
# [490]	validation_0-rmse:3.15736
# [500]	validation_0-rmse:3.15658
# [510]	validation_0-rmse:3.15751
# [520]	validation_0-rmse:3.15699
# [530]	validation_0-rmse:3.15452
# [540]	validation_0-rmse:3.15354
# [550]	validation_0-rmse:3.15388
# [560]	validation_0-rmse:3.14922
# [570]	validation_0-rmse:3.14901
# [580]	validation_0-rmse:3.15083
# [590]	validation_0-rmse:3.14916
# [600]	validation_0-rmse:3.14963
# [610]	validation_0-rmse:3.14509
# [620]	validation_0-rmse:3.14556
# [630]	validation_0-rmse:3.14742
# [640]	validation_0-rmse:3.14581
# [650]	validation_0-rmse:3.14737
# [660]	validation_0-rmse:3.14845
# Stopping. Best iteration:
# [610]	validation_0-rmse:3.14509
#
# [TX_2] Fold2: 18.654497385025024 [sec]
# [0]	validation_0-rmse:3.57416
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.28688
# [20]	validation_0-rmse:3.17856
# [30]	validation_0-rmse:3.08172
# [40]	validation_0-rmse:3.12449
# [50]	validation_0-rmse:3.12267
# [60]	validation_0-rmse:3.12064
# [70]	validation_0-rmse:3.10185
# [80]	validation_0-rmse:3.10040
# Stopping. Best iteration:
# [30]	validation_0-rmse:3.08172
#
# [TX_2] Fold3: 7.297806739807129 [sec]
# [0]	validation_0-rmse:3.68976
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.37188
# [20]	validation_0-rmse:3.27350
# [30]	validation_0-rmse:3.20425
# [40]	validation_0-rmse:3.20085
# [50]	validation_0-rmse:3.19084
# [60]	validation_0-rmse:3.16777
# [70]	validation_0-rmse:3.14589
# [80]	validation_0-rmse:3.14528
# [90]	validation_0-rmse:3.14677
# [100]	validation_0-rmse:3.12871
# [110]	validation_0-rmse:3.12903
# [120]	validation_0-rmse:3.12756
# [130]	validation_0-rmse:3.12811
# [140]	validation_0-rmse:3.12456
# [150]	validation_0-rmse:3.12303
# [160]	validation_0-rmse:3.12431
# [170]	validation_0-rmse:3.12577
# [180]	validation_0-rmse:3.12351
# [190]	validation_0-rmse:3.12469
# [200]	validation_0-rmse:3.12233
# [210]	validation_0-rmse:3.11665
# [220]	validation_0-rmse:3.11428
# [230]	validation_0-rmse:3.11333
# [240]	validation_0-rmse:3.11471
# [250]	validation_0-rmse:3.11386
# [260]	validation_0-rmse:3.10815
# [270]	validation_0-rmse:3.10522
# [280]	validation_0-rmse:3.10139
# [290]	validation_0-rmse:3.10063
# [300]	validation_0-rmse:3.10396
# [310]	validation_0-rmse:3.09960
# [320]	validation_0-rmse:3.09944
# [330]	validation_0-rmse:3.09699
# [340]	validation_0-rmse:3.09615
# [350]	validation_0-rmse:3.09503
# [360]	validation_0-rmse:3.09374
# [370]	validation_0-rmse:3.09069
# [380]	validation_0-rmse:3.09157
# [390]	validation_0-rmse:3.09478
# [400]	validation_0-rmse:3.08810
# [410]	validation_0-rmse:3.08817
# [420]	validation_0-rmse:3.08643
# [430]	validation_0-rmse:3.08296
# [440]	validation_0-rmse:3.08022
# [450]	validation_0-rmse:3.08158
# [460]	validation_0-rmse:3.08008
# [470]	validation_0-rmse:3.07943
# [480]	validation_0-rmse:3.07058
# [490]	validation_0-rmse:3.06865
# [500]	validation_0-rmse:3.06411
# [510]	validation_0-rmse:3.06631
# [520]	validation_0-rmse:3.06676
# [530]	validation_0-rmse:3.06673
# [540]	validation_0-rmse:3.06383
# [550]	validation_0-rmse:3.06366
# [560]	validation_0-rmse:3.06120
# [570]	validation_0-rmse:3.06194
# [580]	validation_0-rmse:3.05968
# [590]	validation_0-rmse:3.05812
# [600]	validation_0-rmse:3.05924
# [610]	validation_0-rmse:3.05595
# [620]	validation_0-rmse:3.05515
# [630]	validation_0-rmse:3.05097
# [640]	validation_0-rmse:3.05101
# [650]	validation_0-rmse:3.04998
# [660]	validation_0-rmse:3.04992
# [670]	validation_0-rmse:3.04997
# [680]	validation_0-rmse:3.04983
# [690]	validation_0-rmse:3.05065
# [700]	validation_0-rmse:3.05230
# [710]	validation_0-rmse:3.05131
# [720]	validation_0-rmse:3.05247
# Stopping. Best iteration:
# [676]	validation_0-rmse:3.04892
#
# [TX_2] Fold4: 15.000843048095703 [sec]
# [0]	validation_0-rmse:3.73255
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.36475
# [20]	validation_0-rmse:3.25263
# [30]	validation_0-rmse:3.16696
# [40]	validation_0-rmse:3.18910
# [50]	validation_0-rmse:3.17839
# [60]	validation_0-rmse:3.16474
# [70]	validation_0-rmse:3.13673
# [80]	validation_0-rmse:3.11387
# [90]	validation_0-rmse:3.10860
# [100]	validation_0-rmse:3.10614
# [110]	validation_0-rmse:3.11409
# [120]	validation_0-rmse:3.10758
# [130]	validation_0-rmse:3.10354
# [140]	validation_0-rmse:3.10961
# [150]	validation_0-rmse:3.11084
# Stopping. Best iteration:
# [104]	validation_0-rmse:3.10189
#
# [TX_2] Fold5: 6.766522169113159 [sec]
# [I 2020-06-30 21:17:29,761] Finished trial#9 with value: 3.0488515853881837 with parameters: {'subsample': 0.85, 'colsample_bytree': 0.9, 'max_depth': 4, 'gamma': 0.10162320886498524, 'min_child_weight': 1.5826309013654887}. Best is trial#5 with value: 2.5719700336456297.
# [0]	validation_0-rmse:3.44807
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.48917
# [20]	validation_0-rmse:2.40206
# [30]	validation_0-rmse:2.36722
# [40]	validation_0-rmse:2.35272
# [50]	validation_0-rmse:2.35711
# [60]	validation_0-rmse:2.35934
# [70]	validation_0-rmse:2.36197
# [80]	validation_0-rmse:2.36648
# Stopping. Best iteration:
# [39]	validation_0-rmse:2.35040
#
# [TX_2] Fold1: 14.001842260360718 [sec]
# [0]	validation_0-rmse:3.85207
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.97244
# [20]	validation_0-rmse:2.87479
# [30]	validation_0-rmse:2.81650
# [40]	validation_0-rmse:2.77669
# [50]	validation_0-rmse:2.75952
# [60]	validation_0-rmse:2.75891
# [70]	validation_0-rmse:2.75403
# [80]	validation_0-rmse:2.75957
# [90]	validation_0-rmse:2.75640
# [100]	validation_0-rmse:2.75779
# Stopping. Best iteration:
# [56]	validation_0-rmse:2.75331
#
# [TX_2] Fold2: 14.694905996322632 [sec]
# [0]	validation_0-rmse:3.50622
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.70353
# [20]	validation_0-rmse:2.67456
# [30]	validation_0-rmse:2.66943
# [40]	validation_0-rmse:2.67556
# [50]	validation_0-rmse:2.67760
# [60]	validation_0-rmse:2.68191
# [70]	validation_0-rmse:2.73224
# [80]	validation_0-rmse:2.73868
# Stopping. Best iteration:
# [34]	validation_0-rmse:2.66533
#
# [TX_2] Fold3: 12.019413232803345 [sec]
# [0]	validation_0-rmse:3.58732
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.76559
# [20]	validation_0-rmse:2.71718
# [30]	validation_0-rmse:2.68525
# [40]	validation_0-rmse:2.66278
# [50]	validation_0-rmse:2.65384
# [60]	validation_0-rmse:2.66139
# [70]	validation_0-rmse:2.66274
# [80]	validation_0-rmse:2.65919
# [90]	validation_0-rmse:2.65850
# Stopping. Best iteration:
# [47]	validation_0-rmse:2.65273
#
# [TX_2] Fold4: 11.698222875595093 [sec]
# [0]	validation_0-rmse:3.59246
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.61156
# [20]	validation_0-rmse:2.56033
# [30]	validation_0-rmse:2.51577
# [40]	validation_0-rmse:2.49704
# [50]	validation_0-rmse:2.49927
# [60]	validation_0-rmse:2.50563
# [70]	validation_0-rmse:2.50628
# [80]	validation_0-rmse:2.51219
# Stopping. Best iteration:
# [35]	validation_0-rmse:2.49413
#
# [TX_2] Fold5: 10.125531196594238 [sec]
# [I 2020-06-30 21:18:32,472] Finished trial#10 with value: 2.583181095123291 with parameters: {'subsample': 0.6, 'colsample_bytree': 0.6, 'max_depth': 9, 'gamma': 0.0010941126406432754, 'min_child_weight': 0.10038267164525866}. Best is trial#5 with value: 2.5719700336456297.
# [0]	validation_0-rmse:3.44807
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.48917
# [20]	validation_0-rmse:2.40424
# [30]	validation_0-rmse:2.36084
# [40]	validation_0-rmse:2.34319
# [50]	validation_0-rmse:2.32797
# [60]	validation_0-rmse:2.33984
# [70]	validation_0-rmse:2.34278
# [80]	validation_0-rmse:2.34554
# [90]	validation_0-rmse:2.34807
# Stopping. Best iteration:
# [48]	validation_0-rmse:2.32735
#
# [TX_2] Fold1: 14.692296981811523 [sec]
# [0]	validation_0-rmse:3.85207
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.99464
# [20]	validation_0-rmse:2.89695
# [30]	validation_0-rmse:2.84653
# [40]	validation_0-rmse:2.80525
# [50]	validation_0-rmse:2.79379
# [60]	validation_0-rmse:2.79025
# [70]	validation_0-rmse:2.78781
# [80]	validation_0-rmse:2.78400
# [90]	validation_0-rmse:2.78694
# [100]	validation_0-rmse:2.78436
# [110]	validation_0-rmse:2.78040
# [120]	validation_0-rmse:2.77413
# [130]	validation_0-rmse:2.77271
# [140]	validation_0-rmse:2.77008
# [150]	validation_0-rmse:2.77014
# [160]	validation_0-rmse:2.77153
# [170]	validation_0-rmse:2.76791
# [180]	validation_0-rmse:2.76113
# [190]	validation_0-rmse:2.76007
# [200]	validation_0-rmse:2.75929
# [210]	validation_0-rmse:2.76250
# [220]	validation_0-rmse:2.76299
# [230]	validation_0-rmse:2.76332
# [240]	validation_0-rmse:2.76501
# Stopping. Best iteration:
# [197]	validation_0-rmse:2.75834
#
# [TX_2] Fold2: 23.71139359474182 [sec]
# [0]	validation_0-rmse:3.50622
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.70353
# [20]	validation_0-rmse:2.67456
# [30]	validation_0-rmse:2.66988
# [40]	validation_0-rmse:2.67600
# [50]	validation_0-rmse:2.67946
# [60]	validation_0-rmse:2.68800
# [70]	validation_0-rmse:2.73915
# [80]	validation_0-rmse:2.74282
# Stopping. Best iteration:
# [34]	validation_0-rmse:2.66578
#
# [TX_2] Fold3: 11.987457275390625 [sec]
# [0]	validation_0-rmse:3.58732
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.76559
# [20]	validation_0-rmse:2.71772
# [30]	validation_0-rmse:2.68330
# [40]	validation_0-rmse:2.66602
# [50]	validation_0-rmse:2.66209
# [60]	validation_0-rmse:2.66421
# [70]	validation_0-rmse:2.66608
# [80]	validation_0-rmse:2.66202
# [90]	validation_0-rmse:2.66215
# Stopping. Best iteration:
# [46]	validation_0-rmse:2.65474
#
# [TX_2] Fold4: 11.67736029624939 [sec]
# [0]	validation_0-rmse:3.59246
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.61156
# [20]	validation_0-rmse:2.56033
# [30]	validation_0-rmse:2.51577
# [40]	validation_0-rmse:2.49704
# [50]	validation_0-rmse:2.49927
# [60]	validation_0-rmse:2.50563
# [70]	validation_0-rmse:2.50609
# [80]	validation_0-rmse:2.51028
# Stopping. Best iteration:
# [35]	validation_0-rmse:2.49413
#
# [TX_2] Fold5: 9.999825477600098 [sec]
# [I 2020-06-30 21:19:44,703] Finished trial#11 with value: 2.580069923400879 with parameters: {'subsample': 0.6, 'colsample_bytree': 0.6, 'max_depth': 9, 'gamma': 0.0014947129383570562, 'min_child_weight': 0.1052828965200365}. Best is trial#5 with value: 2.5719700336456297.
# [0]	validation_0-rmse:3.45404
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.46615
# [20]	validation_0-rmse:2.37920
# [30]	validation_0-rmse:2.33990
# [40]	validation_0-rmse:2.31797
# [50]	validation_0-rmse:2.33604
# [60]	validation_0-rmse:2.35624
# [70]	validation_0-rmse:2.35524
# [80]	validation_0-rmse:2.36049
# Stopping. Best iteration:
# [39]	validation_0-rmse:2.31622
#
# [TX_2] Fold1: 10.392425298690796 [sec]
# [0]	validation_0-rmse:3.84871
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.87200
# [20]	validation_0-rmse:2.78107
# [30]	validation_0-rmse:2.74846
# [40]	validation_0-rmse:2.75118
# [50]	validation_0-rmse:2.75633
# [60]	validation_0-rmse:2.76126
# [70]	validation_0-rmse:2.76658
# [80]	validation_0-rmse:2.76392
# Stopping. Best iteration:
# [34]	validation_0-rmse:2.73032
#
# [TX_2] Fold2: 9.802509784698486 [sec]
# [0]	validation_0-rmse:3.49450
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.72982
# [20]	validation_0-rmse:2.67542
# [30]	validation_0-rmse:2.65824
# [40]	validation_0-rmse:2.64554
# [50]	validation_0-rmse:2.65292
# [60]	validation_0-rmse:2.66377
# [70]	validation_0-rmse:2.67424
# [80]	validation_0-rmse:2.67949
# Stopping. Best iteration:
# [35]	validation_0-rmse:2.64411
#
# [TX_2] Fold3: 9.007937669754028 [sec]
# [0]	validation_0-rmse:3.58643
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.73875
# [20]	validation_0-rmse:2.68570
# [30]	validation_0-rmse:2.75825
# [40]	validation_0-rmse:2.77880
# [50]	validation_0-rmse:2.78664
# [60]	validation_0-rmse:2.89514
# [70]	validation_0-rmse:2.90269
# Stopping. Best iteration:
# [27]	validation_0-rmse:2.67549
#
# [TX_2] Fold4: 7.958414554595947 [sec]
# [0]	validation_0-rmse:3.60027
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.65447
# [20]	validation_0-rmse:2.57988
# [30]	validation_0-rmse:2.52759
# [40]	validation_0-rmse:2.49759
# [50]	validation_0-rmse:2.49551
# [60]	validation_0-rmse:2.52096
# [70]	validation_0-rmse:2.52595
# [80]	validation_0-rmse:2.53063
# [90]	validation_0-rmse:2.53062
# Stopping. Best iteration:
# [47]	validation_0-rmse:2.48972
#
# [TX_2] Fold5: 7.686715126037598 [sec]
# [I 2020-06-30 21:20:29,715] Finished trial#12 with value: 2.571170949935913 with parameters: {'subsample': 0.65, 'colsample_bytree': 0.6, 'max_depth': 7, 'gamma': 0.003351610111917839, 'min_child_weight': 0.2199065549666421}. Best is trial#12 with value: 2.571170949935913.
# [0]	validation_0-rmse:3.44889
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.55572
# [20]	validation_0-rmse:2.47085
# [30]	validation_0-rmse:2.44663
# [40]	validation_0-rmse:2.42116
# [50]	validation_0-rmse:2.41828
# [60]	validation_0-rmse:2.43004
# [70]	validation_0-rmse:2.44518
# [80]	validation_0-rmse:2.44693
# [90]	validation_0-rmse:2.45175
# Stopping. Best iteration:
# [45]	validation_0-rmse:2.41616
#
# [TX_2] Fold1: 10.542816400527954 [sec]
# [0]	validation_0-rmse:3.85318
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.91790
# [20]	validation_0-rmse:2.81938
# [30]	validation_0-rmse:2.78525
# [40]	validation_0-rmse:2.77006
# [50]	validation_0-rmse:2.76616
# [60]	validation_0-rmse:2.77136
# [70]	validation_0-rmse:2.77980
# [80]	validation_0-rmse:2.76999
# Stopping. Best iteration:
# [39]	validation_0-rmse:2.75490
#
# [TX_2] Fold2: 9.884717226028442 [sec]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\io\pickle.py in read_pickle(path, compression)
#     154             warnings.simplefilter("ignore", Warning)
# --> 155             return pickle.load(f)
#     156     except Exception:  # noqa: E722
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _new_Index(cls, d)
#     171
# --> 172 def _new_Index(cls, d):
#     173     """
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\optuna\study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     338                 self._optimize_sequential(
# --> 339                     func, n_trials, timeout, catch, callbacks, gc_after_trial, None
#     340                 )
#
# ~\Anaconda3\lib\site-packages\optuna\study.py in _optimize_sequential(self, func, n_trials, timeout, catch, callbacks, gc_after_trial, time_start)
#     681
# --> 682             self._run_trial_and_callbacks(func, catch, callbacks, gc_after_trial)
#     683
#
# ~\Anaconda3\lib\site-packages\optuna\study.py in _run_trial_and_callbacks(self, func, catch, callbacks, gc_after_trial)
#     712
# --> 713         trial = self._run_trial(func, catch, gc_after_trial)
#     714         if callbacks is not None:
#
# ~\Anaconda3\lib\site-packages\optuna\study.py in _run_trial(self, func, catch, gc_after_trial)
#     733         try:
# --> 734             result = func(trial)
#     735         except exceptions.TrialPruned as e:
#
# <ipython-input-15-5c40a8279676> in objective(trial)
#      32             if os.path.isfile(df_fold_file):   # make_new_feature 適用後のファイルがあればそれを使う
# ---> 33                 df_fold = pd.read_pickle(df_fold_file)
#      34             else:
#
# ~\Anaconda3\lib\site-packages\pandas\io\pickle.py in read_pickle(path, compression)
#     154             warnings.simplefilter("ignore", Warning)
# --> 155             return pickle.load(f)
#     156     except Exception:  # noqa: E722
#
# ~\Anaconda3\lib\warnings.py in __exit__(self, *exc_info)
#     492
# --> 493     def __exit__(self, *exc_info):
#     494         if not self._entered:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-abe0898f7833> in <module>
#       5     print('##################### CV START: {0} #####################'.format(d_store_id[store]))
#       6     study = optuna.create_study()
# ----> 7     study.optimize(xgboost_cv_store(df, store), n_trials=OPTUNA_TRIAL)
#       8
#       9     # save optuna log
#
# ~\Anaconda3\lib\site-packages\optuna\study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     337             if n_jobs == 1:
#     338                 self._optimize_sequential(
# --> 339                     func, n_trials, timeout, catch, callbacks, gc_after_trial, None
#     340                 )
#     341             else:
#
# KeyboardInterrupt:

# %%
del df
gc.collect()

# %% [markdown]
# ## Train & Predict by best model (function)

# %%
# def xgboost_by_bestparam_for_valid(df, store, best_params, valid_preds):
#     print('##################### Traing4ValidByBestParam START: {0} #####################'.format(d_store_id[store]))
#     print('Best Parameters of store {0} model: {1}'.format(d_store_id[store], best_params))
    
#     # prepare data set
#     df_store = df[df['store_id'] == store]
#     X_train = df_store[df_store['d'] < VALID_FIRST_DAY].drop('sold', axis=1)
#     y_train = df_store[df_store['d'] < VALID_FIRST_DAY]['sold']
#     X_valid = df_store[(df_store['d'] >= VALID_FIRST_DAY) & (df_store['d'] <= VALID_LAST_DAY)].drop('sold', axis=1)
    
#     # train XGBoost by using best_params
#     model = xgb.XGBRegressor(**best_params)
#     model.fit(X_train, y_train, eval_metric='rmse')
    
#     # save model for validation
# #     modelfile = 'BestModel4valid_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.pkl'
#     modelfile = 'BestModel4valid_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'_lagOlder28Modified.pkl'
#     with open(os.path.join('result', 'best_model', modelfile), 'wb') as f:
#         pickle.dump(model, f)
    
#     # predict for valid
#     valid_preds[X_valid.index] = model.predict(X_valid)
#     del df_store, X_train, y_train, X_valid, model
#     gc.collect()

# %%
# def xgboost_by_bestparam_for_test(df, store, best_params, eval_preds):
#     print('##################### Traing4TestByBestParam START: {0} #####################'.format(d_store_id[store]))
    
#     # prepare data set
#     df_store = df[df['store_id'] == store]
#     X_train = df_store[df_store['d'] <= VALID_LAST_DAY].drop('sold', axis=1)
#     y_train = df_store[df_store['d'] <= VALID_LAST_DAY]['sold']
#     X_test = df_store[df_store['d'] > VALID_LAST_DAY].drop('sold', axis=1)
    
#     # train XGBoost by using best_params
#     model = xgb.XGBRegressor(**best_params)
#     model.fit(X_train, y_train, eval_metric='rmse')
        
#     # predict for test
#     eval_preds[X_test.index] = model.predict(X_test)
    
#     # save model for test
# #     modelfile = 'BestModel4test_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.pkl'
#     modelfile = 'BestModel4test_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'_lagOlder28Modified.pkl'
#     with open(os.path.join('result', 'best_model', modelfile), 'wb') as f:
#         pickle.dump(model, f)
    
#     del df_store, X_train, y_train, X_test, model
#     gc.collect()

# %% [markdown]
# ## Train & Predict by best model

# %%
# # train & predict (best model)
# # df_all = pd.read_pickle(os.path.join(data_dir, 'data_all.pkl'))
# df_all = pd.read_pickle(os.path.join(data_dir, 'data_all_lagOlder28Modified.pkl'))

# valid = df_all[(df_all['d'] >= VALID_FIRST_DAY) & (df_all['d'] <= VALID_LAST_DAY)][['id','d','sold']]
# test = df_all[df_all['d'] > VALID_LAST_DAY][['id','d','sold']]
# valid_preds = valid['sold']
# eval_preds = test['sold']

# for store in tqdm(stores):
#     # read best param selected by CV
# #     bestparam_filename = 'BestParamsSelectedByCV_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.pkl'
#     bestparam_filename = 'BestParamsSelectedByCV_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'_lagOlder28Modified.pkl'
#     with open(os.path.join('result', 'best_param_cv', bestparam_filename), 'rb') as f:
#         best_params = pickle.load(f)

#     # add other params
#     best_params['objective'] = 'reg:squarederror'
#     best_params['n_estimators'] = 1000
#     best_params['learning_rate'] = 0.1
#     best_params['tree_method'] = 'gpu_hist'
    
#     # best model for valid
#     xgboost_by_bestparam_for_valid(df_all, store, best_params, valid_preds) # 大丈夫?

    
#     # best model for test
#     xgboost_by_bestparam_for_test(df_all, store, best_params, eval_preds)

# %%
# # save valid_preds
# # valid_preds_filename = 'ValidPreds_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.pkl'
# valid_preds_filename = 'ValidPreds_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'_lagOlder28Modified.pkl'
# with open(os.path.join('result', 'preds', valid_preds_filename), 'wb') as f:
#     pickle.dump(valid_preds, f)
    
# # save test_preds
# # eval_preds_filename = 'EvalPreds_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.pkl'
# eval_preds_filename = 'EvalPreds_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'_lagOlder28Modified.pkl'
# with open(os.path.join('result', 'preds', eval_preds_filename), 'wb') as f:
#     pickle.dump(eval_preds, f)

# %%
# del df_all
# gc.collect()

# %% [markdown]
# # Make submission

# %%
# #Set actual equal to false if you want to top in the public leaderboard :P
# actual = True
# if actual == False:
#     #Get the validation results(We already have them as less than one month left for competition to end)
#     validation = sales[['id']+['d_' + str(i) for i in range(1914,1942)]]
#     validation['id']=pd.read_csv(os.path.join(rawdata_dir, 'sales_train_validation.csv')).id
#     validation.columns=['id'] + ['F' + str(i + 1) for i in range(28)]
# else:
#     #Get the actual validation results
#     valid['sold'] = valid_preds
#     validation = valid[['id','d','sold']]
#     validation = pd.pivot(validation, index='id', columns='d', values='sold').reset_index()
#     validation.columns=['id'] + ['F' + str(i + 1) for i in range(28)]
#     validation.id = validation.id.map(d_id).str.replace('evaluation','validation')

# #Get the evaluation results
# test['sold'] = eval_preds
# evaluation = test[['id','d','sold']]
# evaluation = pd.pivot(evaluation, index='id', columns='d', values='sold').reset_index()
# evaluation.columns=['id'] + ['F' + str(i + 1) for i in range(28)]
# #Remap the category id to their respective categories
# evaluation.id = evaluation.id.map(d_id)

# #Prepare the submission
# submit = pd.concat([validation,evaluation]).reset_index(drop=True)

# isNegative2Zero = True
# if isNegative2Zero:
#     submit = submit.set_index("id", drop=True)
#     submit[submit < 0] = 0
#     submit = submit.reset_index()

# # submit_file = 'xgboost_cv_UseValidPredsIs'+str(actual)+'_Negative2ZeroIs'+str(isNegative2Zero)+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.csv'
# submit_file = 'xgboost_cv_UseValidPredsIs'+str(actual)+'_Negative2ZeroIs'+str(isNegative2Zero)+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'_lagOlder28Modified.csv'
# submit.to_csv(os.path.join('submission_point', submit_file), index=False)
