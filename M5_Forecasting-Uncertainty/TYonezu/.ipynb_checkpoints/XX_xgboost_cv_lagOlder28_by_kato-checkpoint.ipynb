# %%
import os
import pandas as pd
import numpy as np
import plotly_express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt
import seaborn as sns
import gc
import copy
import warnings
warnings.filterwarnings('ignore')
import xgboost as xgb
from sklearn.metrics import mean_squared_error
import joblib
import optuna
from tqdm import tqdm
import time
import codecs
import pickle

# %% [markdown]
# # Configuration

# %%
rawdata_dir = 'rawdata'
data_dir = 'data'

# lags = [1,2,3,6,12,24,36]
lags = [28, 35, 42, 49, 56]

# NUM_FOLD_DAYS = 28
NUM_FOLD_DAYS = 56
VALID_FIRST_DAY = 1914
VALID_LAST_DAY = 1941
NUM_USE_DAY = 365
# TRAIN_FIRST_DAY = max(lags)
TRAIN_FIRST_DAY = VALID_FIRST_DAY - NUM_USE_DAY + 1

OPTUNA_TRIAL = 70

# %% [markdown]
# # Read data

# %%
sales = pd.read_csv(os.path.join(rawdata_dir, 'sales_train_evaluation.csv'))
sales.name = 'sales'
calendar = pd.read_csv(os.path.join(rawdata_dir, 'calendar.csv'))
calendar.name = 'calendar'
prices = pd.read_csv(os.path.join(rawdata_dir, 'sell_prices.csv'))
prices.name = 'prices'

# %% [markdown]
# Since, the validation data is now available for the days 1914-1941, Adding zero sales for days: d_1942 - d_1969(Test)

# %%
#Add zero sales for the remaining days 1942-1969
for d in range(1942,1970):
    col = 'd_' + str(d)
    sales[col] = 0
    sales[col] = sales[col].astype(np.int16)

# %% [markdown]
# # Downcast

# %%
#Downcast in order to save memory
def downcast(df):
    cols = df.dtypes.index.tolist()
    types = df.dtypes.values.tolist()
    for i,t in enumerate(types):
        if 'int' in str(t):
            
            if df[cols[i]].min() > np.iinfo(np.int8).min and df[cols[i]].max() < np.iinfo(np.int8).max:
                df[cols[i]] = df[cols[i]].astype(np.int8)
            elif df[cols[i]].min() > np.iinfo(np.int16).min and df[cols[i]].max() < np.iinfo(np.int16).max:
                df[cols[i]] = df[cols[i]].astype(np.int16)
            elif df[cols[i]].min() > np.iinfo(np.int32).min and df[cols[i]].max() < np.iinfo(np.int32).max:
                df[cols[i]] = df[cols[i]].astype(np.int32)
            else:
                df[cols[i]] = df[cols[i]].astype(np.int64)
        elif 'float' in str(t):
            if df[cols[i]].min() > np.finfo(np.float16).min and df[cols[i]].max() < np.finfo(np.float16).max:
                df[cols[i]] = df[cols[i]].astype(np.float16)
            elif df[cols[i]].min() > np.finfo(np.float32).min and df[cols[i]].max() < np.finfo(np.float32).max:
                df[cols[i]] = df[cols[i]].astype(np.float32)
            else:
                df[cols[i]] = df[cols[i]].astype(np.float64)
        elif t == np.object:
            if cols[i] == 'date':
                df[cols[i]] = pd.to_datetime(df[cols[i]], format='%Y-%m-%d')
            else:
                df[cols[i]] = df[cols[i]].astype('category')
    return df

sales = downcast(sales)
prices = downcast(prices)
calendar = downcast(calendar)

# %% [markdown]
# # Melt data

# %%
df = pd.melt(sales, id_vars=['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'], var_name='d', value_name='sold').dropna()

# %% [markdown]
# ## Combine data
# Combine price data from prices dataframe and days data from calendar dataset.

# %%
df = pd.merge(df, calendar, on='d', how='left')
df = pd.merge(df, prices, on=['store_id','item_id','wm_yr_wk'], how='left')

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Label Encoding

# %%
#Store the categories along with their codes
d_id = dict(zip(df.id.cat.codes, df.id))
d_item_id = dict(zip(df.item_id.cat.codes, df.item_id))
d_dept_id = dict(zip(df.dept_id.cat.codes, df.dept_id))
d_cat_id = dict(zip(df.cat_id.cat.codes, df.cat_id))
d_store_id = dict(zip(df.store_id.cat.codes, df.store_id))
d_state_id = dict(zip(df.state_id.cat.codes, df.state_id))

# %%
df.d = df['d'].apply(lambda x: x.split('_')[1]).astype(np.int16)
cols = df.dtypes.index.tolist()
types = df.dtypes.values.tolist()
for i,type in enumerate(types):
    if type.name == 'category':
        df[cols[i]] = df[cols[i]].cat.codes
        
df.drop('date',axis=1,inplace=True)

# %% [markdown]
# ## Introduce lags

# %%
#Introduce lags
def make_lags(df, lags):
    for lag in lags:
        df['sold_lag_'+str(lag)] = df.groupby(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'],as_index=False)['sold'].shift(lag).astype(np.float16)
        
    return df

# %%
df = make_lags(df, lags)

# %%
valid_mask = (df["d"] >= 1914)&(df["d"] <= 1941)
valid_df = df[valid_mask]

evalu_mask = (df["d"] > 1941)
evalu_df = df[evalu_mask]

train_df = df[(df["d"] < 1914)]

# %%
df.columns
# Out:
# Index(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id', 'd',
#        'sold', 'wm_yr_wk', 'weekday', 'wday', 'month', 'year', 'event_name_1',
#        'event_type_1', 'event_name_2', 'event_type_2', 'snap_CA', 'snap_TX',
#        'snap_WI', 'sell_price', 'sold_lag_28', 'sold_lag_35', 'sold_lag_42',
#        'sold_lag_49', 'sold_lag_56'],
#       dtype='object')

# %% [markdown]
# ## make new features

# %%
col = "sold_lag_28"
evalu_df[col].sample(n=10000).hist(bins=50)
plt.show()

valid_df[col].sample(n=10000).hist(bins=50)
plt.show()


train_df[col].sample(n=10000).hist(bins=50)
plt.show()

# %%
def make_new_feature(df, d_last = df['d'].max()):
    # copy sold
    sold_tmp = copy.copy(df['sold'])
    
    # embed NaN
    df['sold'][df['d'] > d_last] = np.nan
    
    # make feature using sold
    df['item_sold_avg'] = df.groupby('item_id')['sold'].transform('mean').astype(np.float16)
    df['state_sold_avg'] = df.groupby('state_id')['sold'].transform('mean').astype(np.float16)
    df['store_sold_avg'] = df.groupby('store_id')['sold'].transform('mean').astype(np.float16)
    df['cat_sold_avg'] = df.groupby('cat_id')['sold'].transform('mean').astype(np.float16)
    df['dept_sold_avg'] = df.groupby('dept_id')['sold'].transform('mean').astype(np.float16)
    df['cat_dept_sold_avg'] = df.groupby(['cat_id','dept_id'])['sold'].transform('mean').astype(np.float16)
    df['store_item_sold_avg'] = df.groupby(['store_id','item_id'])['sold'].transform('mean').astype(np.float16)
    df['cat_item_sold_avg'] = df.groupby(['cat_id','item_id'])['sold'].transform('mean').astype(np.float16)
    df['dept_item_sold_avg'] = df.groupby(['dept_id','item_id'])['sold'].transform('mean').astype(np.float16)
    df['state_store_sold_avg'] = df.groupby(['state_id','store_id'])['sold'].transform('mean').astype(np.float16)
    df['state_store_cat_sold_avg'] = df.groupby(['state_id','store_id','cat_id'])['sold'].transform('mean').astype(np.float16)
    df['store_cat_dept_sold_avg'] = df.groupby(['store_id','cat_id','dept_id'])['sold'].transform('mean').astype(np.float16)
    
    df['rolling_sold_mean'] = df.groupby(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'])['sold'].transform(lambda x: x.rolling(window=7).mean()).astype(np.float16)
    df['expanding_sold_mean'] = df.groupby(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'])['sold'].transform(lambda x: x.expanding(2).mean()).astype(np.float16)
    
    df['daily_avg_sold'] = df.groupby(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id','d'])['sold'].transform('mean').astype(np.float16)
    df['avg_sold'] = df.groupby(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'])['sold'].transform('mean').astype(np.float16)
    df['selling_trend'] = (df['daily_avg_sold'] - df['avg_sold']).astype(np.float16)
    df.drop(['daily_avg_sold','avg_sold'],axis=1,inplace=True)
    
    # restore sold
    df['sold'] = sold_tmp
    
    return df

# %%
df_all = copy.copy(df)
df_all = make_new_feature(df_all)
df_all = df_all[df_all['d'] >= max(lags)]
df_all.info()

# df_all.to_pickle(os.path.join(data_dir, 'data_all.pkl'))   # save df_all (use this after CV)
df_all.to_pickle(os.path.join(data_dir, 'data_all_lagOlder28.pkl'))   # save df_all (use this after CV)
del df_all
gc.collect()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58357860 entries, 1676950 to 60034809
# Data columns (total 41 columns):
# id                          int16
# item_id                     int16
# dept_id                     int8
# cat_id                      int8
# store_id                    int8
# state_id                    int8
# d                           int16
# sold                        int16
# wm_yr_wk                    int16
# weekday                     int8
# wday                        int8
# month                       int8
# year                        int16
# event_name_1                int8
# event_type_1                int8
# event_name_2                int8
# event_type_2                int8
# snap_CA                     int8
# snap_TX                     int8
# snap_WI                     int8
# sell_price                  float16
# sold_lag_28                 float16
# sold_lag_35                 float16
# sold_lag_42                 float16
# sold_lag_49                 float16
# sold_lag_56                 float16
# item_sold_avg               float16
# state_sold_avg              float16
# store_sold_avg              float16
# cat_sold_avg                float16
# dept_sold_avg               float16
# cat_dept_sold_avg           float16
# store_item_sold_avg         float16
# cat_item_sold_avg           float16
# dept_item_sold_avg          float16
# state_store_sold_avg        float16
# state_store_cat_sold_avg    float16
# store_cat_dept_sold_avg     float16
# rolling_sold_mean           float16
# expanding_sold_mean         float16
# selling_trend               float16
# dtypes: float16(21), int16(6), int8(14)
# memory usage: 4.1 GB
# 0

# %%
#df_all = pd.read_pickle(os.path.join(data_dir, 'data_all_lagOlder28.pkl')) 

valid_mask = (df_all["d"] >= 1914)&(df_all["d"] <= 1941)
valid_df = df_all[valid_mask]

evalu_mask = (df_all["d"] > 1941)
evalu_df = df_all[evalu_mask]

train_df = df_all[(df_all["d"] < 1914)]


col = "sold_lag_56"
evalu_df[col].sample(n=10000).hist(bins=50)
plt.show()

valid_df[col].sample(n=10000).hist(bins=50)
plt.show()


train_df[col].sample(n=10000).hist(bins=50)
plt.show()

# %% [markdown]
# # Cross Validation

# %% [markdown]
# ## Cross Validation for each store (function)

# %%
def xgboost_cv_store(df, store):
    def objective(trial):
        # param space
        param = {
            'objective': 'reg:squarederror',
            'n_estimators': 1000,
            'learning_rate': 0.1,
            'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 0.95, 0.05),
            'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.6, 0.95, 0.05),
            'max_depth':  trial.suggest_int('max_depth', 3, 9),
            'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
            'min_child_weight': trial.suggest_loguniform('min_child_weight', 0.1, 10.0),
            'tree_method': 'gpu_hist'
        }
        
        ### START: CV Loop ###
        isBreakCV = False
        fold_iter = 0
        rmse_mean = 0.
        while not(isBreakCV):
            start = time.time()   # start timer
            
            d_valid_last = VALID_LAST_DAY - NUM_FOLD_DAYS * fold_iter
            d_train_last = VALID_LAST_DAY - NUM_FOLD_DAYS * (fold_iter + 1)
            if d_train_last < TRAIN_FIRST_DAY + NUM_FOLD_DAYS * 2:
                isBreakCV = True
            
            # make_new_feature
#             df_fold_file = os.path.join(data_dir, 'data_foldday'+str(NUM_FOLD_DAYS)+'_fold'+str(fold_iter + 1)+'.pkl')
            df_fold_file = os.path.join(data_dir, 'data_foldday'+str(NUM_FOLD_DAYS)+'_fold'+str(fold_iter + 1)+'_lagOlder28.pkl')
            
            if os.path.isfile(df_fold_file):   # make_new_feature 適用後のファイルがあればそれを使う
                df_fold = pd.read_pickle(df_fold_file)
            else:
                df_fold = df[df['d'] <= d_valid_last]
                df_fold = make_new_feature(df_fold, d_train_last)   # train の情報だけを使って特徴量を作成
                df_fold.to_pickle(df_fold_file)   # pickleとして保存しておく

            # Extract store
            df_fold = df_fold[df_fold['store_id'] == store]
                        
            # Split data
            X_train = df_fold[(df_fold['d'] >= TRAIN_FIRST_DAY) & (df_fold['d'] <= d_train_last)].drop('sold', axis=1)
            y_train = df_fold[(df_fold['d'] >= TRAIN_FIRST_DAY) & (df_fold['d'] <= d_train_last)]['sold']
            X_valid = df_fold[(df_fold['d'] > d_train_last) & (df_fold['d'] <= d_valid_last)].drop('sold', axis=1)
            y_valid = df_fold[(df_fold['d'] > d_train_last) & (df_fold['d'] <= d_valid_last)]['sold']
            
            # Train XGBoost model
            model = xgb.XGBRegressor(**param)
#             model.fit(X_train, y_train, eval_set=[(X_train,y_train), (X_valid, y_valid)],
#                  eval_metric='rmse', verbose=10, early_stopping_rounds=100)
            model.fit(X_train, y_train, eval_set=[(X_valid, y_valid)],
                  eval_metric='rmse', verbose=10, early_stopping_rounds=50)
            y_pred = model.predict(X_valid)
            rmse_mean += np.sqrt(mean_squared_error(y_valid.values, y_pred))
            
            fold_iter += 1
            elapsed_time = time.time() - start   # stop timer
            print("[{0}] Fold{1}: {2} [sec]".format(d_store_id[store], fold_iter, elapsed_time))
        ### END: CV Loop ###
        
        del df_fold, model, X_train, y_train, X_valid, y_valid, y_pred
        gc.collect()
        
        rmse_mean /= fold_iter
        return rmse_mean
    return objective

# %% [markdown]
# ## Execute CV

# %%
stores = sales.store_id.cat.codes.unique().tolist()

# find best params by doing CV (optuna)
for store in tqdm(stores[:6]):
    print('##################### CV START: {0} #####################'.format(d_store_id[store]))
    study = optuna.create_study()
    study.optimize(xgboost_cv_store(df, store), n_trials=OPTUNA_TRIAL)
    
    # save optuna log
    df_trial = study.trials_dataframe()
#     df_trial.to_pickle(os.path.join('report', 'OptunaTrials_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.pkl'))
    df_trial.to_pickle(os.path.join('report', 'OptunaTrials_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'_lagOlder28.pkl'))
    
    del df_trial
    gc.collect()
    
    # savae best params found by CV
#     bestparam_filename = 'BestParamsSelectedByCV_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.pkl'
    bestparam_filename = 'BestParamsSelectedByCV_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'_lagOlder28.pkl'
    with open(os.path.join('result', 'best_param_cv', bestparam_filename), 'wb') as f:
        pickle.dump(study.best_params, f)
# Out:
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
# ##################### CV START: CA_1 #####################
# [0]	validation_0-rmse:3.55907
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.06345
# [20]	validation_0-rmse:2.95139
# [30]	validation_0-rmse:2.82877
# [40]	validation_0-rmse:2.80327
# [50]	validation_0-rmse:2.76787
# [60]	validation_0-rmse:2.75769
# [70]	validation_0-rmse:2.73857
# [80]	validation_0-rmse:2.73253
# [90]	validation_0-rmse:2.73577
# [100]	validation_0-rmse:2.73576
# [110]	validation_0-rmse:2.72599
# [120]	validation_0-rmse:2.72274
# [130]	validation_0-rmse:2.72144
# [140]	validation_0-rmse:2.71928
# [150]	validation_0-rmse:2.71385
# [160]	validation_0-rmse:2.73406
# [170]	validation_0-rmse:2.73506
# [180]	validation_0-rmse:2.73240
# [190]	validation_0-rmse:2.72010
# [200]	validation_0-rmse:2.72092
# Stopping. Best iteration:
# [150]	validation_0-rmse:2.71385
#
# [CA_1] Fold1: 223.40014052391052 [sec]
# [0]	validation_0-rmse:3.46679
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.97640
# [20]	validation_0-rmse:2.87414
# [30]	validation_0-rmse:2.75284
# [40]	validation_0-rmse:2.73165
# [50]	validation_0-rmse:2.71251
# [60]	validation_0-rmse:2.70587
# [70]	validation_0-rmse:2.70664
# [80]	validation_0-rmse:2.70284
# [90]	validation_0-rmse:2.71141
# [100]	validation_0-rmse:2.70696
# [110]	validation_0-rmse:2.70072
# [120]	validation_0-rmse:2.69883
# [130]	validation_0-rmse:2.69667
# [140]	validation_0-rmse:2.69664
# [150]	validation_0-rmse:2.68639
# [160]	validation_0-rmse:2.68030
# [170]	validation_0-rmse:2.68234
# [180]	validation_0-rmse:2.68565
# [190]	validation_0-rmse:2.68619
# [200]	validation_0-rmse:2.69134
# [210]	validation_0-rmse:2.69272
# Stopping. Best iteration:
# [161]	validation_0-rmse:2.68010
#
# [CA_1] Fold2: 217.20381951332092 [sec]
# [0]	validation_0-rmse:3.20650
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.78992
# [20]	validation_0-rmse:2.74497
# [30]	validation_0-rmse:2.69238
# [40]	validation_0-rmse:2.67905
# [50]	validation_0-rmse:2.68252
# [60]	validation_0-rmse:2.67357
# [70]	validation_0-rmse:2.67607
# [80]	validation_0-rmse:2.65932
# [90]	validation_0-rmse:2.66376
# [100]	validation_0-rmse:2.66047
# [110]	validation_0-rmse:2.69472
# [120]	validation_0-rmse:2.69759
# [130]	validation_0-rmse:2.69885
# [140]	validation_0-rmse:2.69779
# [150]	validation_0-rmse:2.68680
# Stopping. Best iteration:
# [109]	validation_0-rmse:2.65788
#
# [CA_1] Fold3: 216.51156187057495 [sec]
# [0]	validation_0-rmse:3.46202
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.94583
# [20]	validation_0-rmse:2.85754
# [30]	validation_0-rmse:2.80035
# [40]	validation_0-rmse:2.77214
# [50]	validation_0-rmse:2.77424
# [60]	validation_0-rmse:2.78158
# [70]	validation_0-rmse:2.78651
# [80]	validation_0-rmse:2.77459
# Stopping. Best iteration:
# [39]	validation_0-rmse:2.76824
#
# [CA_1] Fold4: 208.8409264087677 [sec]
# [0]	validation_0-rmse:3.76188
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.16618
# [20]	validation_0-rmse:3.10254
# [30]	validation_0-rmse:2.96748
# [40]	validation_0-rmse:2.94169
# [50]	validation_0-rmse:2.91517
# [60]	validation_0-rmse:2.90747
# [70]	validation_0-rmse:2.90146
# [80]	validation_0-rmse:2.90312
# [90]	validation_0-rmse:2.89713
# [100]	validation_0-rmse:2.89945
# [110]	validation_0-rmse:2.89645
# [120]	validation_0-rmse:2.89509
# [130]	validation_0-rmse:2.89156
# [140]	validation_0-rmse:2.88890
# [150]	validation_0-rmse:2.87347
# [160]	validation_0-rmse:2.87343
# [170]	validation_0-rmse:2.87409
# [180]	validation_0-rmse:2.87427
# [190]	validation_0-rmse:2.87103
# [200]	validation_0-rmse:2.87035
# [210]	validation_0-rmse:2.87000
# [220]	validation_0-rmse:2.87292
# [230]	validation_0-rmse:2.87345
# [240]	validation_0-rmse:2.87687
# Stopping. Best iteration:
# [198]	validation_0-rmse:2.86987
#
# [CA_1] Fold5: 205.89423608779907 [sec]
# [I 2020-06-29 01:11:30,174] Finished trial#0 with value: 2.7379889488220215 with parameters: {'subsample': 0.6, 'colsample_bytree': 0.8, 'max_depth': 6, 'gamma': 0.00022077269687625656, 'min_child_weight': 0.3704085379205699}. Best is trial#0 with value: 2.7379889488220215.
# [0]	validation_0-rmse:3.63049
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.31574
# [20]	validation_0-rmse:3.20507
# [30]	validation_0-rmse:3.12518
# [40]	validation_0-rmse:3.13984
# [50]	validation_0-rmse:3.11047
# [60]	validation_0-rmse:3.07117
# [70]	validation_0-rmse:3.03614
# [80]	validation_0-rmse:3.01286
# [90]	validation_0-rmse:2.98363
# [100]	validation_0-rmse:2.96482
# [110]	validation_0-rmse:2.95683
# [120]	validation_0-rmse:2.94658
# [130]	validation_0-rmse:2.93486
# [140]	validation_0-rmse:2.92348
# [150]	validation_0-rmse:2.91260
# [160]	validation_0-rmse:2.89981
# [170]	validation_0-rmse:2.88931
# [180]	validation_0-rmse:2.88282
# [190]	validation_0-rmse:2.87956
# [200]	validation_0-rmse:2.87575
# [210]	validation_0-rmse:2.87293
# [220]	validation_0-rmse:2.87017
# [230]	validation_0-rmse:2.86205
# [240]	validation_0-rmse:2.85753
# [250]	validation_0-rmse:2.85515
# [260]	validation_0-rmse:2.85180
# [270]	validation_0-rmse:2.84863
# [280]	validation_0-rmse:2.84751
# [290]	validation_0-rmse:2.84476
# [300]	validation_0-rmse:2.84317
# [310]	validation_0-rmse:2.84462
# [320]	validation_0-rmse:2.83826
# [330]	validation_0-rmse:2.83482
# [340]	validation_0-rmse:2.83236
# [350]	validation_0-rmse:2.83121
# [360]	validation_0-rmse:2.82928
# [370]	validation_0-rmse:2.82829
# [380]	validation_0-rmse:2.82310
# [390]	validation_0-rmse:2.82135
# [400]	validation_0-rmse:2.82354
# [410]	validation_0-rmse:2.82315
# [420]	validation_0-rmse:2.82360
# [430]	validation_0-rmse:2.82003
# [440]	validation_0-rmse:2.81999
# [450]	validation_0-rmse:2.82104
# [460]	validation_0-rmse:2.81962
# [470]	validation_0-rmse:2.81928
# [480]	validation_0-rmse:2.81847
# [490]	validation_0-rmse:2.81577
# [500]	validation_0-rmse:2.81433
# [510]	validation_0-rmse:2.81162
# [520]	validation_0-rmse:2.80942
# [530]	validation_0-rmse:2.80340
# [540]	validation_0-rmse:2.80145
# [550]	validation_0-rmse:2.80733
# [560]	validation_0-rmse:2.80629
# [570]	validation_0-rmse:2.80510
# [580]	validation_0-rmse:2.80537
# [590]	validation_0-rmse:2.80666
# Stopping. Best iteration:
# [545]	validation_0-rmse:2.79851
#
# [CA_1] Fold1: 17.52782392501831 [sec]
# [0]	validation_0-rmse:3.53221
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.23725
# [20]	validation_0-rmse:3.16002
# [30]	validation_0-rmse:3.12550
# [40]	validation_0-rmse:3.10914
# [50]	validation_0-rmse:3.08439
# [60]	validation_0-rmse:3.03764
# [70]	validation_0-rmse:2.99768
# [80]	validation_0-rmse:2.97172
# [90]	validation_0-rmse:2.94104
# [100]	validation_0-rmse:2.92476
# [110]	validation_0-rmse:2.90531
# [120]	validation_0-rmse:2.89681
# [130]	validation_0-rmse:2.88627
# [140]	validation_0-rmse:2.88199
# [150]	validation_0-rmse:2.88018
# [160]	validation_0-rmse:2.87502
# [170]	validation_0-rmse:2.87287
# [180]	validation_0-rmse:2.87071
# [190]	validation_0-rmse:2.86793
# [200]	validation_0-rmse:2.86208
# [210]	validation_0-rmse:2.85723
# [220]	validation_0-rmse:2.85195
# [230]	validation_0-rmse:2.84599
# [240]	validation_0-rmse:2.84402
# [250]	validation_0-rmse:2.84594
# [260]	validation_0-rmse:2.84377
# [270]	validation_0-rmse:2.84852
# [280]	validation_0-rmse:2.84681
# [290]	validation_0-rmse:2.84564
# Stopping. Best iteration:
# [245]	validation_0-rmse:2.84328
#
# [CA_1] Fold2: 11.303091049194336 [sec]
# [0]	validation_0-rmse:3.26835
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.00128
# [20]	validation_0-rmse:2.90124
# [30]	validation_0-rmse:2.83699
# [40]	validation_0-rmse:2.85096
# [50]	validation_0-rmse:2.82109
# [60]	validation_0-rmse:2.79208
# [70]	validation_0-rmse:2.77322
# [80]	validation_0-rmse:2.75953
# [90]	validation_0-rmse:2.75087
# [100]	validation_0-rmse:2.74201
# [110]	validation_0-rmse:2.74170
# [120]	validation_0-rmse:2.74017
# [130]	validation_0-rmse:2.73155
# [140]	validation_0-rmse:2.72791
# [150]	validation_0-rmse:2.72459
# [160]	validation_0-rmse:2.71616
# [170]	validation_0-rmse:2.71286
# [180]	validation_0-rmse:2.71154
# [190]	validation_0-rmse:2.70630
# [200]	validation_0-rmse:2.69949
# [210]	validation_0-rmse:2.69693
# [220]	validation_0-rmse:2.69598
# [230]	validation_0-rmse:2.69505
# [240]	validation_0-rmse:2.69531
# [250]	validation_0-rmse:2.69365
# [260]	validation_0-rmse:2.69601
# [270]	validation_0-rmse:2.69539
# [280]	validation_0-rmse:2.69538
# [290]	validation_0-rmse:2.69524
# [300]	validation_0-rmse:2.69388
# Stopping. Best iteration:
# [253]	validation_0-rmse:2.69336
#
# [CA_1] Fold3: 10.723561763763428 [sec]
# [0]	validation_0-rmse:3.52746
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.20733
# [20]	validation_0-rmse:3.16414
# [30]	validation_0-rmse:3.05039
# [40]	validation_0-rmse:3.04421
# [50]	validation_0-rmse:3.02137
# [60]	validation_0-rmse:2.99038
# [70]	validation_0-rmse:2.97212
# [80]	validation_0-rmse:2.96721
# [90]	validation_0-rmse:2.95420
# [100]	validation_0-rmse:2.94501
# [110]	validation_0-rmse:2.93810
# [120]	validation_0-rmse:2.93062
# [130]	validation_0-rmse:2.92210
# [140]	validation_0-rmse:2.91589
# [150]	validation_0-rmse:2.91485
# [160]	validation_0-rmse:2.91548
# [170]	validation_0-rmse:2.91275
# [180]	validation_0-rmse:2.91010
# [190]	validation_0-rmse:2.90871
# [200]	validation_0-rmse:2.90659
# [210]	validation_0-rmse:2.90449
# [220]	validation_0-rmse:2.87458
# [230]	validation_0-rmse:2.86034
# [240]	validation_0-rmse:2.85893
# [250]	validation_0-rmse:2.85911
# [260]	validation_0-rmse:2.85563
# [270]	validation_0-rmse:2.85346
# [280]	validation_0-rmse:2.85403
# [290]	validation_0-rmse:2.85198
# [300]	validation_0-rmse:2.84784
# [310]	validation_0-rmse:2.84824
# [320]	validation_0-rmse:2.84932
# [330]	validation_0-rmse:2.84733
# [340]	validation_0-rmse:2.84514
# [350]	validation_0-rmse:2.84204
# [360]	validation_0-rmse:2.84148
# [370]	validation_0-rmse:2.84184
# [380]	validation_0-rmse:2.83844
# [390]	validation_0-rmse:2.83602
# [400]	validation_0-rmse:2.83320
# [410]	validation_0-rmse:2.83388
# [420]	validation_0-rmse:2.83257
# [430]	validation_0-rmse:2.83065
# [440]	validation_0-rmse:2.82999
# [450]	validation_0-rmse:2.82665
# [460]	validation_0-rmse:2.82724
# [470]	validation_0-rmse:2.82447
# [480]	validation_0-rmse:2.82574
# [490]	validation_0-rmse:2.82570
# [500]	validation_0-rmse:2.82421
# [510]	validation_0-rmse:2.82372
# [520]	validation_0-rmse:2.82295
# [530]	validation_0-rmse:2.82341
# [540]	validation_0-rmse:2.82234
# [550]	validation_0-rmse:2.82323
# [560]	validation_0-rmse:2.82360
# [570]	validation_0-rmse:2.82378
# [580]	validation_0-rmse:2.82461
# [590]	validation_0-rmse:2.82410
# Stopping. Best iteration:
# [542]	validation_0-rmse:2.82218
#
# [CA_1] Fold4: 12.331658601760864 [sec]
# [0]	validation_0-rmse:3.84104
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.52135
# [20]	validation_0-rmse:3.46299
# [30]	validation_0-rmse:3.33132
# [40]	validation_0-rmse:3.32962
# [50]	validation_0-rmse:3.32112
# [60]	validation_0-rmse:3.28349
# [70]	validation_0-rmse:3.25985
# [80]	validation_0-rmse:3.23664
# [90]	validation_0-rmse:3.22010
# [100]	validation_0-rmse:3.20776
# [110]	validation_0-rmse:3.19922
# [120]	validation_0-rmse:3.17501
# [130]	validation_0-rmse:3.16513
# [140]	validation_0-rmse:3.15262
# [150]	validation_0-rmse:3.14444
# [160]	validation_0-rmse:3.14047
# [170]	validation_0-rmse:3.13510
# [180]	validation_0-rmse:3.12896
# [190]	validation_0-rmse:3.12746
# [200]	validation_0-rmse:3.11741
# [210]	validation_0-rmse:3.11585
# [220]	validation_0-rmse:3.11669
# [230]	validation_0-rmse:3.11296
# [240]	validation_0-rmse:3.10572
# [250]	validation_0-rmse:3.11345
# [260]	validation_0-rmse:3.11113
# [270]	validation_0-rmse:3.11025
# [280]	validation_0-rmse:3.10321
# [290]	validation_0-rmse:3.09668
# [300]	validation_0-rmse:3.09341
# [310]	validation_0-rmse:3.08515
# [320]	validation_0-rmse:3.08189
# [330]	validation_0-rmse:3.08003
# [340]	validation_0-rmse:3.07802
# [350]	validation_0-rmse:3.07569
# [360]	validation_0-rmse:3.07011
# [370]	validation_0-rmse:3.07019
# [380]	validation_0-rmse:3.07770
# [390]	validation_0-rmse:3.07410
# [400]	validation_0-rmse:3.07011
# [410]	validation_0-rmse:3.06883
# [420]	validation_0-rmse:3.06949
# [430]	validation_0-rmse:3.06997
# [440]	validation_0-rmse:3.06767
# [450]	validation_0-rmse:3.06676
# [460]	validation_0-rmse:3.06532
# [470]	validation_0-rmse:3.06166
# [480]	validation_0-rmse:3.05964
# [490]	validation_0-rmse:3.05946
# [500]	validation_0-rmse:3.06025
# [510]	validation_0-rmse:3.06092
# [520]	validation_0-rmse:3.05646
# [530]	validation_0-rmse:3.05643
# [540]	validation_0-rmse:3.05548
# [550]	validation_0-rmse:3.05350
# [560]	validation_0-rmse:3.05269
# [570]	validation_0-rmse:3.05387
# [580]	validation_0-rmse:3.05430
# [590]	validation_0-rmse:3.05402
# [600]	validation_0-rmse:3.05455
# [610]	validation_0-rmse:3.05365
# Stopping. Best iteration:
# [561]	validation_0-rmse:3.05243
#
# [CA_1] Fold5: 11.973971843719482 [sec]
# [I 2020-06-29 01:12:34,207] Finished trial#1 with value: 2.8419509887695313 with parameters: {'subsample': 0.95, 'colsample_bytree': 0.85, 'max_depth': 3, 'gamma': 0.00022872717567308434, 'min_child_weight': 0.2787791830573246}. Best is trial#0 with value: 2.7379889488220215.
# [0]	validation_0-rmse:3.48232
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.89670
# [20]	validation_0-rmse:2.74592
# [30]	validation_0-rmse:2.68671
# [40]	validation_0-rmse:2.67542
# [50]	validation_0-rmse:2.65263
# [60]	validation_0-rmse:2.65310
# [70]	validation_0-rmse:2.65968
# [80]	validation_0-rmse:2.66191
# [90]	validation_0-rmse:2.65654
# [100]	validation_0-rmse:2.65932
# Stopping. Best iteration:
# [56]	validation_0-rmse:2.65023
#
# [CA_1] Fold1: 10.504072904586792 [sec]
# [0]	validation_0-rmse:3.40520
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.78501
# [20]	validation_0-rmse:2.66958
# [30]	validation_0-rmse:2.62562
# [40]	validation_0-rmse:2.60799
# [50]	validation_0-rmse:2.59924
# [60]	validation_0-rmse:2.58957
# [70]	validation_0-rmse:2.59947
# [80]	validation_0-rmse:2.60151
# [90]	validation_0-rmse:2.60319
# [100]	validation_0-rmse:2.60298
# [110]	validation_0-rmse:2.60303
# Stopping. Best iteration:
# [61]	validation_0-rmse:2.58892
#
# [CA_1] Fold2: 10.012500762939453 [sec]
# [0]	validation_0-rmse:3.13598
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.62239
# [20]	validation_0-rmse:2.56808
# [30]	validation_0-rmse:2.56701
# [40]	validation_0-rmse:2.56392
# [50]	validation_0-rmse:2.57182
# [60]	validation_0-rmse:2.58868
# [70]	validation_0-rmse:2.59214
# [80]	validation_0-rmse:2.59425
# [90]	validation_0-rmse:2.59712
# Stopping. Best iteration:
# [40]	validation_0-rmse:2.56392
#
# [CA_1] Fold3: 8.891268014907837 [sec]
# [0]	validation_0-rmse:3.38067
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.76739
# [20]	validation_0-rmse:2.72309
# [30]	validation_0-rmse:2.71276
# [40]	validation_0-rmse:2.71693
# [50]	validation_0-rmse:2.72632
# [60]	validation_0-rmse:2.73499
# [70]	validation_0-rmse:2.73948
# [80]	validation_0-rmse:2.74503
# Stopping. Best iteration:
# [36]	validation_0-rmse:2.71133
#
# [CA_1] Fold4: 7.9428136348724365 [sec]
# [0]	validation_0-rmse:3.66619
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.92541
# [20]	validation_0-rmse:2.84920
# [30]	validation_0-rmse:2.82537
# [40]	validation_0-rmse:2.78908
# [50]	validation_0-rmse:2.78471
# [60]	validation_0-rmse:2.78805
# [70]	validation_0-rmse:2.79501
# [80]	validation_0-rmse:2.79540
# [90]	validation_0-rmse:2.79566
# Stopping. Best iteration:
# [47]	validation_0-rmse:2.78468
#
# [CA_1] Fold5: 7.484451055526733 [sec]
# [I 2020-06-29 01:13:19,206] Finished trial#2 with value: 2.659815549850464 with parameters: {'subsample': 0.75, 'colsample_bytree': 0.7, 'max_depth': 7, 'gamma': 0.006752265103791889, 'min_child_weight': 9.495685358486714}. Best is trial#2 with value: 2.659815549850464.
# [0]	validation_0-rmse:3.60305
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.22213
# [20]	validation_0-rmse:3.16126
# [30]	validation_0-rmse:3.18528
# [40]	validation_0-rmse:3.17654
# [50]	validation_0-rmse:3.17056
# [60]	validation_0-rmse:3.16742
# [70]	validation_0-rmse:3.14071
# [80]	validation_0-rmse:3.12854
# [90]	validation_0-rmse:3.11773
# [100]	validation_0-rmse:3.11255
# [110]	validation_0-rmse:3.09147
# [120]	validation_0-rmse:3.08806
# [130]	validation_0-rmse:3.08178
# [140]	validation_0-rmse:3.06320
# [150]	validation_0-rmse:3.04703
# [160]	validation_0-rmse:3.04314
# [170]	validation_0-rmse:3.03667
# [180]	validation_0-rmse:3.03041
# [190]	validation_0-rmse:3.02637
# [200]	validation_0-rmse:3.02234
# [210]	validation_0-rmse:3.02169
# [220]	validation_0-rmse:3.01982
# [230]	validation_0-rmse:3.01665
# [240]	validation_0-rmse:3.01446
# [250]	validation_0-rmse:3.00923
# [260]	validation_0-rmse:3.00405
# [270]	validation_0-rmse:3.00367
# [280]	validation_0-rmse:3.00114
# [290]	validation_0-rmse:2.99955
# [300]	validation_0-rmse:3.00277
# [310]	validation_0-rmse:3.00430
# [320]	validation_0-rmse:3.00323
# [330]	validation_0-rmse:2.99946
# [340]	validation_0-rmse:2.99894
# [350]	validation_0-rmse:2.99794
# [360]	validation_0-rmse:2.99636
# [370]	validation_0-rmse:2.99373
# [380]	validation_0-rmse:2.99149
# [390]	validation_0-rmse:2.99107
# [400]	validation_0-rmse:2.98877
# [410]	validation_0-rmse:2.99028
# [420]	validation_0-rmse:2.99168
# [430]	validation_0-rmse:2.98395
# [440]	validation_0-rmse:2.98110
# [450]	validation_0-rmse:2.98041
# [460]	validation_0-rmse:2.98301
# [470]	validation_0-rmse:2.98256
# [480]	validation_0-rmse:2.96836
# [490]	validation_0-rmse:2.96929
# [500]	validation_0-rmse:2.96118
# [510]	validation_0-rmse:2.95685
# [520]	validation_0-rmse:2.95631
# [530]	validation_0-rmse:2.95551
# [540]	validation_0-rmse:2.95333
# [550]	validation_0-rmse:2.95267
# [560]	validation_0-rmse:2.95097
# [570]	validation_0-rmse:2.95159
# [580]	validation_0-rmse:2.95244
# [590]	validation_0-rmse:2.95310
# [600]	validation_0-rmse:2.94612
# [610]	validation_0-rmse:2.94679
# [620]	validation_0-rmse:2.94608
# [630]	validation_0-rmse:2.94598
# [640]	validation_0-rmse:2.94498
# [650]	validation_0-rmse:2.94452
# [660]	validation_0-rmse:2.93610
# [670]	validation_0-rmse:2.93596
# [680]	validation_0-rmse:2.92981
# [690]	validation_0-rmse:2.91753
# [700]	validation_0-rmse:2.91794
# [710]	validation_0-rmse:2.91615
# [720]	validation_0-rmse:2.91574
# [730]	validation_0-rmse:2.91660
# [740]	validation_0-rmse:2.91695
# [750]	validation_0-rmse:2.91666
# [760]	validation_0-rmse:2.91716
# [770]	validation_0-rmse:2.91691
# Stopping. Best iteration:
# [721]	validation_0-rmse:2.91559
#
# [CA_1] Fold1: 21.861461877822876 [sec]
# [0]	validation_0-rmse:3.50961
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.17774
# [20]	validation_0-rmse:3.07109
# [30]	validation_0-rmse:3.05236
# [40]	validation_0-rmse:3.13235
# [50]	validation_0-rmse:3.10663
# [60]	validation_0-rmse:3.10366
# [70]	validation_0-rmse:3.08512
# Stopping. Best iteration:
# [25]	validation_0-rmse:3.02103
#
# [CA_1] Fold2: 7.877090692520142 [sec]
# [0]	validation_0-rmse:3.24051
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.90761
# [20]	validation_0-rmse:2.82111
# [30]	validation_0-rmse:2.75025
# [40]	validation_0-rmse:2.73713
# [50]	validation_0-rmse:2.72899
# [60]	validation_0-rmse:2.72180
# [70]	validation_0-rmse:2.71540
# [80]	validation_0-rmse:2.71138
# [90]	validation_0-rmse:2.70880
# [100]	validation_0-rmse:2.70771
# [110]	validation_0-rmse:2.70800
# [120]	validation_0-rmse:2.70753
# [130]	validation_0-rmse:2.70481
# [140]	validation_0-rmse:2.70360
# [150]	validation_0-rmse:2.70035
# [160]	validation_0-rmse:2.69892
# [170]	validation_0-rmse:2.69862
# [180]	validation_0-rmse:2.69687
# [190]	validation_0-rmse:2.69797
# [200]	validation_0-rmse:2.69752
# [210]	validation_0-rmse:2.69605
# [220]	validation_0-rmse:2.69830
# [230]	validation_0-rmse:2.69567
# [240]	validation_0-rmse:2.69621
# [250]	validation_0-rmse:2.69652
# [260]	validation_0-rmse:2.69638
# Stopping. Best iteration:
# [216]	validation_0-rmse:2.69517
#
# [CA_1] Fold3: 10.460659980773926 [sec]
# [0]	validation_0-rmse:3.49957
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.14174
# [20]	validation_0-rmse:3.10072
# [30]	validation_0-rmse:3.07245
# [40]	validation_0-rmse:3.07035
# [50]	validation_0-rmse:3.06078
# [60]	validation_0-rmse:3.05830
# [70]	validation_0-rmse:3.05725
# [80]	validation_0-rmse:3.04037
# [90]	validation_0-rmse:3.03369
# [100]	validation_0-rmse:3.02685
# [110]	validation_0-rmse:3.02133
# [120]	validation_0-rmse:3.01981
# [130]	validation_0-rmse:3.01937
# [140]	validation_0-rmse:3.01531
# [150]	validation_0-rmse:3.01579
# [160]	validation_0-rmse:3.01681
# [170]	validation_0-rmse:3.01051
# [180]	validation_0-rmse:3.00725
# [190]	validation_0-rmse:3.01034
# [200]	validation_0-rmse:3.00956
# [210]	validation_0-rmse:3.00186
# [220]	validation_0-rmse:3.00015
# [230]	validation_0-rmse:3.00126
# [240]	validation_0-rmse:2.99688
# [250]	validation_0-rmse:2.99304
# [260]	validation_0-rmse:3.00290
# [270]	validation_0-rmse:3.00066
# [280]	validation_0-rmse:2.99966
# [290]	validation_0-rmse:2.99817
# [300]	validation_0-rmse:2.99685
# Stopping. Best iteration:
# [250]	validation_0-rmse:2.99304
#
# [CA_1] Fold4: 9.517786979675293 [sec]
# [0]	validation_0-rmse:3.81420
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.50335
# [20]	validation_0-rmse:3.44424
# [30]	validation_0-rmse:3.38715
# [40]	validation_0-rmse:3.38064
# [50]	validation_0-rmse:3.38712
# [60]	validation_0-rmse:3.38209
# [70]	validation_0-rmse:3.37677
# [80]	validation_0-rmse:3.35289
# [90]	validation_0-rmse:3.33797
# [100]	validation_0-rmse:3.32762
# [110]	validation_0-rmse:3.32100
# [120]	validation_0-rmse:3.31136
# [130]	validation_0-rmse:3.26373
# [140]	validation_0-rmse:3.24422
# [150]	validation_0-rmse:3.23774
# [160]	validation_0-rmse:3.23363
# [170]	validation_0-rmse:3.21370
# [180]	validation_0-rmse:3.20926
# [190]	validation_0-rmse:3.20661
# [200]	validation_0-rmse:3.20915
# [210]	validation_0-rmse:3.20996
# [220]	validation_0-rmse:3.20027
# [230]	validation_0-rmse:3.18571
# [240]	validation_0-rmse:3.18368
# [250]	validation_0-rmse:3.18381
# [260]	validation_0-rmse:3.18297
# [270]	validation_0-rmse:3.18154
# [280]	validation_0-rmse:3.18146
# [290]	validation_0-rmse:3.17802
# [300]	validation_0-rmse:3.16293
# [310]	validation_0-rmse:3.16188
# [320]	validation_0-rmse:3.16626
# [330]	validation_0-rmse:3.16660
# [340]	validation_0-rmse:3.15698
# [350]	validation_0-rmse:3.16044
# [360]	validation_0-rmse:3.15352
# [370]	validation_0-rmse:3.15241
# [380]	validation_0-rmse:3.14899
# [390]	validation_0-rmse:3.14854
# [400]	validation_0-rmse:3.14695
# [410]	validation_0-rmse:3.13795
# [420]	validation_0-rmse:3.14425
# [430]	validation_0-rmse:3.14327
# [440]	validation_0-rmse:3.14103
# [450]	validation_0-rmse:3.13824
# [460]	validation_0-rmse:3.13838
# Stopping. Best iteration:
# [410]	validation_0-rmse:3.13795
#
# [CA_1] Fold5: 10.984368324279785 [sec]
# [I 2020-06-29 01:14:20,071] Finished trial#3 with value: 2.9525554180145264 with parameters: {'subsample': 0.75, 'colsample_bytree': 0.95, 'max_depth': 4, 'gamma': 6.943249558103036e-05, 'min_child_weight': 0.2039487181276517}. Best is trial#2 with value: 2.659815549850464.
# [0]	validation_0-rmse:3.57435
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.94760
# [20]	validation_0-rmse:2.85941
# [30]	validation_0-rmse:2.82211
# [40]	validation_0-rmse:2.81419
# [50]	validation_0-rmse:2.80957
# [60]	validation_0-rmse:2.80827
# [70]	validation_0-rmse:2.80721
# [80]	validation_0-rmse:2.80007
# [90]	validation_0-rmse:2.79575
# [100]	validation_0-rmse:2.79587
# [110]	validation_0-rmse:2.79516
# [120]	validation_0-rmse:2.79308
# [130]	validation_0-rmse:2.79507
# [140]	validation_0-rmse:2.79357
# [150]	validation_0-rmse:2.79449
# [160]	validation_0-rmse:2.80540
# [170]	validation_0-rmse:2.79283
# Stopping. Best iteration:
# [125]	validation_0-rmse:2.79120
#
# [CA_1] Fold1: 15.354440927505493 [sec]
# [0]	validation_0-rmse:3.47540
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.85638
# [20]	validation_0-rmse:2.75164
# [30]	validation_0-rmse:2.70548
# [40]	validation_0-rmse:2.70383
# [50]	validation_0-rmse:2.69827
# [60]	validation_0-rmse:2.69044
# [70]	validation_0-rmse:2.68648
# [80]	validation_0-rmse:2.68397
# [90]	validation_0-rmse:2.67595
# [100]	validation_0-rmse:2.67285
# [110]	validation_0-rmse:2.68427
# [120]	validation_0-rmse:2.68524
# [130]	validation_0-rmse:2.68593
# [140]	validation_0-rmse:2.68647
# Stopping. Best iteration:
# [95]	validation_0-rmse:2.67251
#
# [CA_1] Fold2: 13.21434998512268 [sec]
# [0]	validation_0-rmse:3.21097
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.67093
# [20]	validation_0-rmse:2.63511
# [30]	validation_0-rmse:2.63199
# [40]	validation_0-rmse:2.64010
# [50]	validation_0-rmse:2.64807
# [60]	validation_0-rmse:2.64958
# [70]	validation_0-rmse:2.64714
# Stopping. Best iteration:
# [28]	validation_0-rmse:2.62785
#
# [CA_1] Fold3: 9.85267424583435 [sec]
# [0]	validation_0-rmse:3.46108
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.88556
# [20]	validation_0-rmse:2.81719
# [30]	validation_0-rmse:2.80058
# [40]	validation_0-rmse:2.79158
# [50]	validation_0-rmse:2.79129
# [60]	validation_0-rmse:2.79157
# [70]	validation_0-rmse:2.79637
# [80]	validation_0-rmse:2.78736
# [90]	validation_0-rmse:2.78464
# [100]	validation_0-rmse:2.80378
# [110]	validation_0-rmse:2.80154
# [120]	validation_0-rmse:2.80114
# [130]	validation_0-rmse:2.79832
# [140]	validation_0-rmse:2.79740
# Stopping. Best iteration:
# [97]	validation_0-rmse:2.78438
#
# [CA_1] Fold4: 11.529064416885376 [sec]
# [0]	validation_0-rmse:3.78462
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.22801
# [20]	validation_0-rmse:3.08563
# [30]	validation_0-rmse:3.04079
# [40]	validation_0-rmse:3.04221
# [50]	validation_0-rmse:3.02765
# [60]	validation_0-rmse:3.02404
# [70]	validation_0-rmse:3.02574
# [80]	validation_0-rmse:3.01467
# [90]	validation_0-rmse:3.01225
# [100]	validation_0-rmse:3.01054
# [110]	validation_0-rmse:3.00846
# [120]	validation_0-rmse:3.00437
# [130]	validation_0-rmse:3.00627
# [140]	validation_0-rmse:3.00418
# [150]	validation_0-rmse:3.00343
# [160]	validation_0-rmse:3.00208
# [170]	validation_0-rmse:3.00329
# [180]	validation_0-rmse:3.00279
# [190]	validation_0-rmse:3.00260
# [200]	validation_0-rmse:2.99897
# [210]	validation_0-rmse:2.99798
# [220]	validation_0-rmse:2.99963
# [230]	validation_0-rmse:2.99913
# [240]	validation_0-rmse:2.99938
# [250]	validation_0-rmse:3.00088
# [260]	validation_0-rmse:3.00041
# Stopping. Best iteration:
# [210]	validation_0-rmse:2.99798
#
# [CA_1] Fold5: 15.07530403137207 [sec]
# [I 2020-06-29 01:15:25,258] Finished trial#4 with value: 2.774782657623291 with parameters: {'subsample': 0.9, 'colsample_bytree': 0.9, 'max_depth': 8, 'gamma': 6.856512188858513e-05, 'min_child_weight': 0.18715894149923398}. Best is trial#2 with value: 2.659815549850464.
# [0]	validation_0-rmse:3.48487
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.89927
# [20]	validation_0-rmse:2.75065
# [30]	validation_0-rmse:2.87315
# [40]	validation_0-rmse:2.80605
# [50]	validation_0-rmse:2.79651
# [60]	validation_0-rmse:2.79829
# [70]	validation_0-rmse:2.81173
# Stopping. Best iteration:
# [27]	validation_0-rmse:2.68164
#
# [CA_1] Fold1: 9.299187898635864 [sec]
# [0]	validation_0-rmse:3.39881
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.81220
# [20]	validation_0-rmse:2.72743
# [30]	validation_0-rmse:2.67993
# [40]	validation_0-rmse:2.64304
# [50]	validation_0-rmse:2.63741
# [60]	validation_0-rmse:2.64151
# [70]	validation_0-rmse:2.64708
# [80]	validation_0-rmse:2.65890
# [90]	validation_0-rmse:2.65945
# [100]	validation_0-rmse:2.65739
# Stopping. Best iteration:
# [57]	validation_0-rmse:2.62787
#
# [CA_1] Fold2: 9.53170394897461 [sec]
# [0]	validation_0-rmse:3.14618
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.67601
# [20]	validation_0-rmse:2.60455
# [30]	validation_0-rmse:2.56933
# [40]	validation_0-rmse:2.53889
# [50]	validation_0-rmse:2.56065
# [60]	validation_0-rmse:2.54093
# [70]	validation_0-rmse:2.52930
# [80]	validation_0-rmse:2.53295
# [90]	validation_0-rmse:2.53478
# [100]	validation_0-rmse:2.53947
# [110]	validation_0-rmse:2.54266
# Stopping. Best iteration:
# [63]	validation_0-rmse:2.52244
#
# [CA_1] Fold3: 9.04595136642456 [sec]
# [0]	validation_0-rmse:3.37945
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.83534
# [20]	validation_0-rmse:2.75505
# [30]	validation_0-rmse:2.71338
# [40]	validation_0-rmse:2.69197
# [50]	validation_0-rmse:2.69926
# [60]	validation_0-rmse:2.70607
# [70]	validation_0-rmse:2.71825
# [80]	validation_0-rmse:2.72488
# [90]	validation_0-rmse:2.72400
# Stopping. Best iteration:
# [42]	validation_0-rmse:2.69141
#
# [CA_1] Fold4: 7.8519816398620605 [sec]
# [0]	validation_0-rmse:3.67555
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.00475
# [20]	validation_0-rmse:2.90454
# [30]	validation_0-rmse:2.83012
# [40]	validation_0-rmse:2.78703
# [50]	validation_0-rmse:2.77018
# [60]	validation_0-rmse:2.77001
# [70]	validation_0-rmse:2.78491
# [80]	validation_0-rmse:2.78727
# [90]	validation_0-rmse:2.78779
# [100]	validation_0-rmse:2.78877
# Stopping. Best iteration:
# [54]	validation_0-rmse:2.76765
#
# [CA_1] Fold5: 7.47918176651001 [sec]
# [I 2020-06-29 01:16:08,627] Finished trial#5 with value: 2.6582026958465574 with parameters: {'subsample': 0.8, 'colsample_bytree': 0.65, 'max_depth': 6, 'gamma': 0.5332126259744261, 'min_child_weight': 0.16730361868276866}. Best is trial#5 with value: 2.6582026958465574.
# [0]	validation_0-rmse:3.57407
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.91783
# [20]	validation_0-rmse:2.79166
# [30]	validation_0-rmse:2.76929
# [40]	validation_0-rmse:2.76667
# [50]	validation_0-rmse:2.76827
# [60]	validation_0-rmse:2.76769
# [70]	validation_0-rmse:2.79273
# [80]	validation_0-rmse:2.79429
# [90]	validation_0-rmse:2.79081
# [100]	validation_0-rmse:2.78479
# [110]	validation_0-rmse:2.78312
# Stopping. Best iteration:
# [65]	validation_0-rmse:2.75887
#
# [CA_1] Fold1: 12.571731090545654 [sec]
# [0]	validation_0-rmse:3.47484
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.84948
# [20]	validation_0-rmse:2.76182
# [30]	validation_0-rmse:2.74319
# [40]	validation_0-rmse:2.73812
# [50]	validation_0-rmse:2.73173
# [60]	validation_0-rmse:2.72735
# [70]	validation_0-rmse:2.72946
# [80]	validation_0-rmse:2.72079
# [90]	validation_0-rmse:2.73657
# [100]	validation_0-rmse:2.73335
# [110]	validation_0-rmse:2.72722
# [120]	validation_0-rmse:2.72545
# [130]	validation_0-rmse:2.72093
# Stopping. Best iteration:
# [85]	validation_0-rmse:2.71417
#
# [CA_1] Fold2: 12.720815420150757 [sec]
# [0]	validation_0-rmse:3.21097
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.64704
# [20]	validation_0-rmse:2.60691
# [30]	validation_0-rmse:2.61157
# [40]	validation_0-rmse:2.61346
# [50]	validation_0-rmse:2.60366
# [60]	validation_0-rmse:2.60702
# [70]	validation_0-rmse:2.60716
# [80]	validation_0-rmse:2.60734
# [90]	validation_0-rmse:2.61694
# [100]	validation_0-rmse:2.62436
# Stopping. Best iteration:
# [51]	validation_0-rmse:2.60330
#
# [CA_1] Fold3: 10.663382053375244 [sec]
# [0]	validation_0-rmse:3.46108
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.87816
# [20]	validation_0-rmse:2.81785
# [30]	validation_0-rmse:2.81162
# [40]	validation_0-rmse:2.80799
# [50]	validation_0-rmse:2.81209
# [60]	validation_0-rmse:2.81299
# [70]	validation_0-rmse:2.81317
# [80]	validation_0-rmse:2.81169
# Stopping. Best iteration:
# [32]	validation_0-rmse:2.80552
#
# [CA_1] Fold4: 9.12454104423523 [sec]
# [0]	validation_0-rmse:3.78462
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.19749
# [20]	validation_0-rmse:3.10029
# [30]	validation_0-rmse:3.06592
# [40]	validation_0-rmse:3.05778
# [50]	validation_0-rmse:3.04324
# [60]	validation_0-rmse:3.03598
# [70]	validation_0-rmse:3.04462
# [80]	validation_0-rmse:3.03582
# [90]	validation_0-rmse:3.03515
# [100]	validation_0-rmse:3.02661
# [110]	validation_0-rmse:3.01568
# [120]	validation_0-rmse:3.01547
# [130]	validation_0-rmse:3.02141
# [140]	validation_0-rmse:3.01870
# [150]	validation_0-rmse:3.01384
# [160]	validation_0-rmse:3.01350
# [170]	validation_0-rmse:3.01212
# [180]	validation_0-rmse:3.01220
# [190]	validation_0-rmse:3.00577
# [200]	validation_0-rmse:3.00436
# [210]	validation_0-rmse:3.00386
# [220]	validation_0-rmse:3.00394
# [230]	validation_0-rmse:3.00394
# [240]	validation_0-rmse:3.00425
# [250]	validation_0-rmse:3.00288
# [260]	validation_0-rmse:3.00189
# Stopping. Best iteration:
# [214]	validation_0-rmse:3.00147
#
# [CA_1] Fold5: 15.294158935546875 [sec]
# [I 2020-06-29 01:17:09,163] Finished trial#6 with value: 2.776665687561035 with parameters: {'subsample': 0.9, 'colsample_bytree': 0.95, 'max_depth': 8, 'gamma': 1.3406331803770942e-06, 'min_child_weight': 0.40337521499237744}. Best is trial#5 with value: 2.6582026958465574.
# [0]	validation_0-rmse:3.55778
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.98992
# [20]	validation_0-rmse:2.83715
# [30]	validation_0-rmse:2.77581
# [40]	validation_0-rmse:2.77745
# [50]	validation_0-rmse:2.73395
# [60]	validation_0-rmse:2.71313
# [70]	validation_0-rmse:2.69833
# [80]	validation_0-rmse:2.69980
# [90]	validation_0-rmse:2.69920
# [100]	validation_0-rmse:2.69500
# [110]	validation_0-rmse:2.68812
# [120]	validation_0-rmse:2.74959
# [130]	validation_0-rmse:2.77148
# [140]	validation_0-rmse:2.76811
# [150]	validation_0-rmse:2.76979
# [160]	validation_0-rmse:2.76446
# Stopping. Best iteration:
# [112]	validation_0-rmse:2.68756
#
# [CA_1] Fold1: 12.719160795211792 [sec]
# [0]	validation_0-rmse:3.47145
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.95861
# [20]	validation_0-rmse:2.83530
# [30]	validation_0-rmse:2.76425
# [40]	validation_0-rmse:2.75657
# [50]	validation_0-rmse:2.72760
# [60]	validation_0-rmse:2.71481
# [70]	validation_0-rmse:2.71386
# [80]	validation_0-rmse:2.71169
# [90]	validation_0-rmse:2.71321
# [100]	validation_0-rmse:2.72238
# [110]	validation_0-rmse:2.71382
# [120]	validation_0-rmse:2.71052
# Stopping. Best iteration:
# [74]	validation_0-rmse:2.70762
#
# [CA_1] Fold2: 10.844269752502441 [sec]
# [0]	validation_0-rmse:3.21132
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.73903
# [20]	validation_0-rmse:2.66848
# [30]	validation_0-rmse:2.64302
# [40]	validation_0-rmse:2.63698
# [50]	validation_0-rmse:2.65554
# [60]	validation_0-rmse:2.66054
# [70]	validation_0-rmse:2.66979
# [80]	validation_0-rmse:2.68297
# [90]	validation_0-rmse:2.87046
# Stopping. Best iteration:
# [41]	validation_0-rmse:2.63584
#
# [CA_1] Fold3: 9.184505462646484 [sec]
# [0]	validation_0-rmse:3.45083
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.89122
# [20]	validation_0-rmse:2.80687
# [30]	validation_0-rmse:2.77266
# [40]	validation_0-rmse:2.77006
# [50]	validation_0-rmse:2.75857
# [60]	validation_0-rmse:2.75994
# [70]	validation_0-rmse:2.77805
# [80]	validation_0-rmse:2.76944
# [90]	validation_0-rmse:2.76755
# [100]	validation_0-rmse:2.75988
# Stopping. Best iteration:
# [50]	validation_0-rmse:2.75857
#
# [CA_1] Fold4: 8.665913581848145 [sec]
# [0]	validation_0-rmse:3.77681
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.13055
# [20]	validation_0-rmse:3.02543
# [30]	validation_0-rmse:2.95694
# [40]	validation_0-rmse:2.94977
# [50]	validation_0-rmse:2.94251
# [60]	validation_0-rmse:2.93092
# [70]	validation_0-rmse:2.91859
# [80]	validation_0-rmse:2.92231
# [90]	validation_0-rmse:2.89578
# [100]	validation_0-rmse:2.89350
# [110]	validation_0-rmse:2.92763
# [120]	validation_0-rmse:2.91966
# [130]	validation_0-rmse:2.90891
# [140]	validation_0-rmse:2.90694
# [150]	validation_0-rmse:2.90799
# Stopping. Best iteration:
# [108]	validation_0-rmse:2.89303
#
# [CA_1] Fold5: 9.256125450134277 [sec]
# [I 2020-06-29 01:17:59,990] Finished trial#7 with value: 2.73652663230896 with parameters: {'subsample': 0.9, 'colsample_bytree': 0.85, 'max_depth': 7, 'gamma': 0.0021272057228889185, 'min_child_weight': 2.3293609888192806}. Best is trial#5 with value: 2.6582026958465574.
# [0]	validation_0-rmse:3.57842
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.96444
# [20]	validation_0-rmse:2.84521
# [30]	validation_0-rmse:2.79512
# [40]	validation_0-rmse:2.77856
# [50]	validation_0-rmse:2.78174
# [60]	validation_0-rmse:2.80630
# [70]	validation_0-rmse:2.80348
# [80]	validation_0-rmse:2.79228
# [90]	validation_0-rmse:2.79314
# Stopping. Best iteration:
# [44]	validation_0-rmse:2.77655
#
# [CA_1] Fold1: 11.896896362304688 [sec]
# [0]	validation_0-rmse:3.48644
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.85669
# [20]	validation_0-rmse:2.73385
# [30]	validation_0-rmse:2.70854
# [40]	validation_0-rmse:2.70590
# [50]	validation_0-rmse:2.70643
# [60]	validation_0-rmse:2.70079
# [70]	validation_0-rmse:2.69893
# [80]	validation_0-rmse:2.69281
# [90]	validation_0-rmse:2.68588
# [100]	validation_0-rmse:2.68373
# [110]	validation_0-rmse:2.68525
# [120]	validation_0-rmse:2.68363
# [130]	validation_0-rmse:2.68431
# [140]	validation_0-rmse:2.67821
# [150]	validation_0-rmse:2.67807
# [160]	validation_0-rmse:2.67682
# [170]	validation_0-rmse:2.67403
# [180]	validation_0-rmse:2.67619
# [190]	validation_0-rmse:2.67706
# [200]	validation_0-rmse:2.67634
# [210]	validation_0-rmse:2.67391
# [220]	validation_0-rmse:2.67486
# [230]	validation_0-rmse:2.67484
# [240]	validation_0-rmse:2.67492
# [250]	validation_0-rmse:2.67571
# Stopping. Best iteration:
# [201]	validation_0-rmse:2.67231
#
# [CA_1] Fold2: 17.084867238998413 [sec]
# [0]	validation_0-rmse:3.20993
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.68487
# [20]	validation_0-rmse:2.61859
# [30]	validation_0-rmse:2.62245
# [40]	validation_0-rmse:2.63101
# [50]	validation_0-rmse:2.61967
# [60]	validation_0-rmse:2.63303
# [70]	validation_0-rmse:2.63593
# Stopping. Best iteration:
# [22]	validation_0-rmse:2.61775
#
# [CA_1] Fold3: 9.902673721313477 [sec]
# [0]	validation_0-rmse:3.44872
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.88867
# [20]	validation_0-rmse:2.82647
# [30]	validation_0-rmse:2.82268
# [40]	validation_0-rmse:2.81698
# [50]	validation_0-rmse:2.83021
# [60]	validation_0-rmse:2.83053
# [70]	validation_0-rmse:2.82971
# [80]	validation_0-rmse:2.83008
# [90]	validation_0-rmse:2.83146
# Stopping. Best iteration:
# [47]	validation_0-rmse:2.81074
#
# [CA_1] Fold4: 9.586685180664062 [sec]
# [0]	validation_0-rmse:3.75609
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.14038
# [20]	validation_0-rmse:3.01960
# [30]	validation_0-rmse:2.98526
# [40]	validation_0-rmse:2.96717
# [50]	validation_0-rmse:2.95025
# [60]	validation_0-rmse:2.94503
# [70]	validation_0-rmse:2.94381
# [80]	validation_0-rmse:2.94699
# [90]	validation_0-rmse:2.95253
# [100]	validation_0-rmse:2.95406
# [110]	validation_0-rmse:2.95234
# Stopping. Best iteration:
# [66]	validation_0-rmse:2.94294
#
# [CA_1] Fold5: 9.037402391433716 [sec]
# [I 2020-06-29 01:18:57,659] Finished trial#8 with value: 2.7640557289123535 with parameters: {'subsample': 0.75, 'colsample_bytree': 0.9, 'max_depth': 9, 'gamma': 0.025144877213662174, 'min_child_weight': 6.215915845453812}. Best is trial#5 with value: 2.6582026958465574.
# [0]	validation_0-rmse:3.59842
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.23025
# [20]	validation_0-rmse:3.19712
# [30]	validation_0-rmse:3.14148
# [40]	validation_0-rmse:3.16260
# [50]	validation_0-rmse:3.15733
# [60]	validation_0-rmse:3.12180
# [70]	validation_0-rmse:3.09639
# [80]	validation_0-rmse:3.08983
# [90]	validation_0-rmse:3.07384
# [100]	validation_0-rmse:3.07292
# [110]	validation_0-rmse:3.06034
# [120]	validation_0-rmse:3.06364
# [130]	validation_0-rmse:3.05687
# [140]	validation_0-rmse:3.05669
# [150]	validation_0-rmse:3.05559
# [160]	validation_0-rmse:3.04947
# [170]	validation_0-rmse:3.05210
# [180]	validation_0-rmse:3.05078
# [190]	validation_0-rmse:3.05539
# [200]	validation_0-rmse:3.05246
# [210]	validation_0-rmse:3.05156
# Stopping. Best iteration:
# [166]	validation_0-rmse:3.04869
#
# [CA_1] Fold1: 11.117990255355835 [sec]
# [0]	validation_0-rmse:3.50213
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.19237
# [20]	validation_0-rmse:3.14876
# [30]	validation_0-rmse:3.09210
# [40]	validation_0-rmse:3.14041
# [50]	validation_0-rmse:3.10859
# [60]	validation_0-rmse:3.07502
# [70]	validation_0-rmse:3.05221
# [80]	validation_0-rmse:3.04423
# [90]	validation_0-rmse:3.03527
# [100]	validation_0-rmse:3.02762
# [110]	validation_0-rmse:3.00973
# [120]	validation_0-rmse:3.00366
# [130]	validation_0-rmse:2.99797
# [140]	validation_0-rmse:2.99316
# [150]	validation_0-rmse:2.98748
# [160]	validation_0-rmse:2.98733
# [170]	validation_0-rmse:2.98205
# [180]	validation_0-rmse:2.98118
# [190]	validation_0-rmse:2.97898
# [200]	validation_0-rmse:2.95231
# [210]	validation_0-rmse:2.95002
# [220]	validation_0-rmse:2.94247
# [230]	validation_0-rmse:2.93867
# [240]	validation_0-rmse:2.93623
# [250]	validation_0-rmse:2.93218
# [260]	validation_0-rmse:2.93025
# [270]	validation_0-rmse:2.92911
# [280]	validation_0-rmse:2.92841
# [290]	validation_0-rmse:2.92734
# [300]	validation_0-rmse:2.93007
# [310]	validation_0-rmse:2.92532
# [320]	validation_0-rmse:2.92261
# [330]	validation_0-rmse:2.92010
# [340]	validation_0-rmse:2.91772
# [350]	validation_0-rmse:2.91694
# [360]	validation_0-rmse:2.91630
# [370]	validation_0-rmse:2.91237
# [380]	validation_0-rmse:2.91285
# [390]	validation_0-rmse:2.90008
# [400]	validation_0-rmse:2.89859
# [410]	validation_0-rmse:2.89921
# [420]	validation_0-rmse:2.89781
# [430]	validation_0-rmse:2.89823
# [440]	validation_0-rmse:2.89809
# Stopping. Best iteration:
# [398]	validation_0-rmse:2.89699
#
# [CA_1] Fold2: 14.581790924072266 [sec]
# [0]	validation_0-rmse:3.24286
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.94460
# [20]	validation_0-rmse:2.88594
# [30]	validation_0-rmse:2.85218
# [40]	validation_0-rmse:2.85273
# [50]	validation_0-rmse:2.86966
# [60]	validation_0-rmse:2.86245
# [70]	validation_0-rmse:2.84966
# [80]	validation_0-rmse:2.84979
# [90]	validation_0-rmse:2.84033
# [100]	validation_0-rmse:2.83713
# [110]	validation_0-rmse:2.83296
# [120]	validation_0-rmse:2.83216
# [130]	validation_0-rmse:2.83011
# [140]	validation_0-rmse:2.82764
# [150]	validation_0-rmse:2.82500
# [160]	validation_0-rmse:2.82314
# [170]	validation_0-rmse:2.82169
# [180]	validation_0-rmse:2.82053
# [190]	validation_0-rmse:2.82021
# [200]	validation_0-rmse:2.81872
# [210]	validation_0-rmse:2.82038
# [220]	validation_0-rmse:2.81768
# [230]	validation_0-rmse:2.81632
# [240]	validation_0-rmse:2.82116
# [250]	validation_0-rmse:2.81709
# [260]	validation_0-rmse:2.81320
# [270]	validation_0-rmse:2.81337
# [280]	validation_0-rmse:2.81284
# [290]	validation_0-rmse:2.81304
# [300]	validation_0-rmse:2.80829
# [310]	validation_0-rmse:2.81032
# [320]	validation_0-rmse:2.81162
# [330]	validation_0-rmse:2.81052
# [340]	validation_0-rmse:2.81061
# [350]	validation_0-rmse:2.80994
# Stopping. Best iteration:
# [306]	validation_0-rmse:2.80799
#
# [CA_1] Fold3: 11.936695575714111 [sec]
# [0]	validation_0-rmse:3.49986
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.22245
# [20]	validation_0-rmse:3.11709
# [30]	validation_0-rmse:3.02946
# [40]	validation_0-rmse:3.01590
# [50]	validation_0-rmse:3.02066
# [60]	validation_0-rmse:3.01251
# [70]	validation_0-rmse:3.00749
# [80]	validation_0-rmse:3.00165
# [90]	validation_0-rmse:2.99417
# [100]	validation_0-rmse:2.99291
# [110]	validation_0-rmse:2.98719
# [120]	validation_0-rmse:2.98263
# [130]	validation_0-rmse:2.97764
# [140]	validation_0-rmse:2.97160
# [150]	validation_0-rmse:2.96527
# [160]	validation_0-rmse:2.96125
# [170]	validation_0-rmse:2.95965
# [180]	validation_0-rmse:2.95964
# [190]	validation_0-rmse:2.95942
# [200]	validation_0-rmse:2.95707
# [210]	validation_0-rmse:2.95483
# [220]	validation_0-rmse:2.95128
# [230]	validation_0-rmse:2.94829
# [240]	validation_0-rmse:2.94752
# [250]	validation_0-rmse:2.94710
# [260]	validation_0-rmse:2.94639
# [270]	validation_0-rmse:2.94312
# [280]	validation_0-rmse:2.94463
# [290]	validation_0-rmse:2.93943
# [300]	validation_0-rmse:2.93720
# [310]	validation_0-rmse:2.93152
# [320]	validation_0-rmse:2.93238
# [330]	validation_0-rmse:2.93323
# [340]	validation_0-rmse:2.93040
# [350]	validation_0-rmse:2.92883
# [360]	validation_0-rmse:2.92785
# [370]	validation_0-rmse:2.92612
# [380]	validation_0-rmse:2.92510
# [390]	validation_0-rmse:2.92475
# [400]	validation_0-rmse:2.92489
# [410]	validation_0-rmse:2.92379
# [420]	validation_0-rmse:2.92350
# [430]	validation_0-rmse:2.92223
# [440]	validation_0-rmse:2.92161
# [450]	validation_0-rmse:2.91980
# [460]	validation_0-rmse:2.91126
# [470]	validation_0-rmse:2.91201
# [480]	validation_0-rmse:2.91183
# [490]	validation_0-rmse:2.91414
# [500]	validation_0-rmse:2.91260
# [510]	validation_0-rmse:2.91374
# Stopping. Best iteration:
# [465]	validation_0-rmse:2.91081
#
# [CA_1] Fold4: 12.23584246635437 [sec]
# [0]	validation_0-rmse:3.81455
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.48647
# [20]	validation_0-rmse:3.44388
# [30]	validation_0-rmse:3.36503
# [40]	validation_0-rmse:3.37540
# [50]	validation_0-rmse:3.35832
# [60]	validation_0-rmse:3.34198
# [70]	validation_0-rmse:3.33126
# [80]	validation_0-rmse:3.31657
# [90]	validation_0-rmse:3.30455
# [100]	validation_0-rmse:3.28115
# [110]	validation_0-rmse:3.26466
# [120]	validation_0-rmse:3.25343
# [130]	validation_0-rmse:3.23651
# [140]	validation_0-rmse:3.22816
# [150]	validation_0-rmse:3.22893
# [160]	validation_0-rmse:3.22815
# [170]	validation_0-rmse:3.22560
# [180]	validation_0-rmse:3.21946
# [190]	validation_0-rmse:3.21601
# [200]	validation_0-rmse:3.21323
# [210]	validation_0-rmse:3.21811
# [220]	validation_0-rmse:3.22219
# [230]	validation_0-rmse:3.21818
# [240]	validation_0-rmse:3.22038
# [250]	validation_0-rmse:3.21546
# Stopping. Best iteration:
# [201]	validation_0-rmse:3.21245
#
# [CA_1] Fold5: 8.39371132850647 [sec]
# [I 2020-06-29 01:19:56,086] Finished trial#9 with value: 2.975386381149292 with parameters: {'subsample': 0.65, 'colsample_bytree': 0.9, 'max_depth': 4, 'gamma': 0.00018458825635477689, 'min_child_weight': 1.4502002124824553}. Best is trial#5 with value: 2.6582026958465574.
# [0]	validation_0-rmse:3.48665
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.86870
# [20]	validation_0-rmse:2.74051
# [30]	validation_0-rmse:2.68533
# [40]	validation_0-rmse:2.63517
# [50]	validation_0-rmse:2.60924
# [60]	validation_0-rmse:2.60539
# [70]	validation_0-rmse:2.60127
# [80]	validation_0-rmse:2.59992
# [90]	validation_0-rmse:2.60087
# [100]	validation_0-rmse:2.60248
# [110]	validation_0-rmse:2.60196
# [120]	validation_0-rmse:2.60064
# [130]	validation_0-rmse:2.59911
# [140]	validation_0-rmse:2.59990
# [150]	validation_0-rmse:2.59965
# [160]	validation_0-rmse:2.59883
# [170]	validation_0-rmse:2.59808
# [180]	validation_0-rmse:2.59878
# [190]	validation_0-rmse:2.59916
# [200]	validation_0-rmse:2.59924
# [210]	validation_0-rmse:2.59903
# [220]	validation_0-rmse:2.59807
# Stopping. Best iteration:
# [179]	validation_0-rmse:2.59541
#
# [CA_1] Fold1: 12.309961557388306 [sec]
# [0]	validation_0-rmse:3.40645
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.79171
# [20]	validation_0-rmse:2.69362
# [30]	validation_0-rmse:2.64912
# [40]	validation_0-rmse:2.61595
# [50]	validation_0-rmse:2.60301
# [60]	validation_0-rmse:2.60217
# [70]	validation_0-rmse:2.60295
# [80]	validation_0-rmse:2.60820
# [90]	validation_0-rmse:2.60818
# [100]	validation_0-rmse:2.61213
# [110]	validation_0-rmse:2.61752
# Stopping. Best iteration:
# [64]	validation_0-rmse:2.60075
#
# [CA_1] Fold2: 9.204932689666748 [sec]
# [0]	validation_0-rmse:3.15161
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.68208
# [20]	validation_0-rmse:2.60416
# [30]	validation_0-rmse:2.58212
# [40]	validation_0-rmse:2.56560
# [50]	validation_0-rmse:2.57119
# [60]	validation_0-rmse:2.57915
# [70]	validation_0-rmse:2.54513
# [80]	validation_0-rmse:2.55046
# [90]	validation_0-rmse:2.55366
# [100]	validation_0-rmse:2.55829
# [110]	validation_0-rmse:2.56423
# Stopping. Best iteration:
# [66]	validation_0-rmse:2.54149
#
# [CA_1] Fold3: 8.612135171890259 [sec]
# [0]	validation_0-rmse:3.38708
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.82780
# [20]	validation_0-rmse:2.74600
# [30]	validation_0-rmse:2.70903
# [40]	validation_0-rmse:2.69797
# [50]	validation_0-rmse:2.71188
# [60]	validation_0-rmse:2.72753
# [70]	validation_0-rmse:2.73581
# ...
# Stopping. Best iteration:
# [45]	validation_0-rmse:2.70426
#
# [TX_2] Fold4: 7.262887954711914 [sec]
# [0]	validation_0-rmse:3.59884
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.80986
# [20]	validation_0-rmse:2.73622
# [30]	validation_0-rmse:2.69313
# [40]	validation_0-rmse:2.66349
# [50]	validation_0-rmse:2.67025
# [60]	validation_0-rmse:2.69459
# [70]	validation_0-rmse:2.69918
# [80]	validation_0-rmse:2.71822
# [90]	validation_0-rmse:2.72526
# Stopping. Best iteration:
# [45]	validation_0-rmse:2.66131
#
# [TX_2] Fold5: 6.6108715534210205 [sec]
# [I 2020-06-29 07:20:10,616] Finished trial#65 with value: 2.668150472640991 with parameters: {'subsample': 0.6, 'colsample_bytree': 0.65, 'max_depth': 5, 'gamma': 5.858007243464046e-08, 'min_child_weight': 3.687888573698908}. Best is trial#64 with value: 2.5518704414367677.
# [0]	validation_0-rmse:3.46268
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.53018
# [20]	validation_0-rmse:2.42721
# [30]	validation_0-rmse:2.39365
# [40]	validation_0-rmse:2.36088
# [50]	validation_0-rmse:2.37699
# [60]	validation_0-rmse:2.39472
# [70]	validation_0-rmse:2.41118
# [80]	validation_0-rmse:2.41139
# Stopping. Best iteration:
# [39]	validation_0-rmse:2.35585
#
# [TX_2] Fold1: 9.534744262695312 [sec]
# [0]	validation_0-rmse:3.84025
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.94060
# [20]	validation_0-rmse:2.82098
# [30]	validation_0-rmse:2.74810
# [40]	validation_0-rmse:2.72452
# [50]	validation_0-rmse:2.69829
# [60]	validation_0-rmse:2.70593
# [70]	validation_0-rmse:2.70518
# [80]	validation_0-rmse:2.69741
# [90]	validation_0-rmse:2.70121
# [100]	validation_0-rmse:2.70028
# [110]	validation_0-rmse:2.70054
# [120]	validation_0-rmse:2.69917
# [130]	validation_0-rmse:2.70131
# Stopping. Best iteration:
# [80]	validation_0-rmse:2.69741
#
# [TX_2] Fold2: 10.044929504394531 [sec]
# [0]	validation_0-rmse:3.48915
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.69510
# [20]	validation_0-rmse:2.65162
# [30]	validation_0-rmse:2.63912
# [40]	validation_0-rmse:2.64792
# [50]	validation_0-rmse:2.66700
# [60]	validation_0-rmse:2.68208
# [70]	validation_0-rmse:2.68482
# [80]	validation_0-rmse:2.69605
# Stopping. Best iteration:
# [30]	validation_0-rmse:2.63912
#
# [TX_2] Fold3: 8.157761096954346 [sec]
# [0]	validation_0-rmse:3.58492
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.72066
# [20]	validation_0-rmse:2.66880
# [30]	validation_0-rmse:2.64423
# [40]	validation_0-rmse:2.63826
# [50]	validation_0-rmse:2.64194
# [60]	validation_0-rmse:2.67021
# [70]	validation_0-rmse:2.68054
# [80]	validation_0-rmse:2.69176
# Stopping. Best iteration:
# [37]	validation_0-rmse:2.63457
#
# [TX_2] Fold4: 7.486264228820801 [sec]
# [0]	validation_0-rmse:3.59635
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.56120
# [20]	validation_0-rmse:2.49521
# [30]	validation_0-rmse:2.45793
# [40]	validation_0-rmse:2.45180
# [50]	validation_0-rmse:2.45636
# [60]	validation_0-rmse:2.46737
# [70]	validation_0-rmse:2.47598
# [80]	validation_0-rmse:2.48666
# Stopping. Best iteration:
# [35]	validation_0-rmse:2.45047
#
# [TX_2] Fold5: 6.811275005340576 [sec]
# [I 2020-06-29 07:20:52,827] Finished trial#66 with value: 2.5554852962493895 with parameters: {'subsample': 0.6, 'colsample_bytree': 0.6, 'max_depth': 6, 'gamma': 1.3378643071117892e-07, 'min_child_weight': 4.313244728414481}. Best is trial#64 with value: 2.5518704414367677.
# [0]	validation_0-rmse:3.46032
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.55879
# [20]	validation_0-rmse:2.45906
# [30]	validation_0-rmse:2.41120
# [40]	validation_0-rmse:2.38295
# [50]	validation_0-rmse:2.38257
# [60]	validation_0-rmse:2.39073
# [70]	validation_0-rmse:2.39463
# [80]	validation_0-rmse:2.39760
# Stopping. Best iteration:
# [39]	validation_0-rmse:2.38010
#
# [TX_2] Fold1: 9.559175729751587 [sec]
# [0]	validation_0-rmse:3.83565
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.97165
# [20]	validation_0-rmse:2.85728
# [30]	validation_0-rmse:2.80776
# [40]	validation_0-rmse:2.77445
# [50]	validation_0-rmse:2.78548
# [60]	validation_0-rmse:2.79922
# [70]	validation_0-rmse:2.79735
# [80]	validation_0-rmse:2.79331
# [90]	validation_0-rmse:2.79126
# Stopping. Best iteration:
# [40]	validation_0-rmse:2.77445
#
# [TX_2] Fold2: 9.091931104660034 [sec]
# [0]	validation_0-rmse:3.48650
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.69289
# [20]	validation_0-rmse:2.64682
# [30]	validation_0-rmse:2.63868
# [40]	validation_0-rmse:2.64420
# [50]	validation_0-rmse:2.64415
# [60]	validation_0-rmse:2.65381
# [70]	validation_0-rmse:2.64915
# [80]	validation_0-rmse:2.64724
# Stopping. Best iteration:
# [34]	validation_0-rmse:2.63664
#
# [TX_2] Fold3: 8.20892333984375 [sec]
# [0]	validation_0-rmse:3.58796
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.78099
# [20]	validation_0-rmse:2.72026
# [30]	validation_0-rmse:2.69955
# [40]	validation_0-rmse:2.68635
# [50]	validation_0-rmse:2.69804
# [60]	validation_0-rmse:2.72074
# [70]	validation_0-rmse:2.72321
# [80]	validation_0-rmse:2.72899
# Stopping. Best iteration:
# [37]	validation_0-rmse:2.67619
#
# [TX_2] Fold4: 7.460220575332642 [sec]
# [0]	validation_0-rmse:3.59488
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.62547
# [20]	validation_0-rmse:2.55040
# [30]	validation_0-rmse:2.51653
# [40]	validation_0-rmse:2.49118
# [50]	validation_0-rmse:2.49587
# [60]	validation_0-rmse:2.52223
# [70]	validation_0-rmse:2.53086
# [80]	validation_0-rmse:2.53201
# Stopping. Best iteration:
# [38]	validation_0-rmse:2.48969
#
# [TX_2] Fold5: 6.841679811477661 [sec]
# [I 2020-06-29 07:21:34,165] Finished trial#67 with value: 2.5914130210876465 with parameters: {'subsample': 0.65, 'colsample_bytree': 0.6, 'max_depth': 6, 'gamma': 7.023560384193827e-07, 'min_child_weight': 4.425576126608695}. Best is trial#64 with value: 2.5518704414367677.
# [0]	validation_0-rmse:3.45696
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.70009
# [20]	validation_0-rmse:2.58481
# [30]	validation_0-rmse:2.52308
# [40]	validation_0-rmse:2.46856
# [50]	validation_0-rmse:2.45025
# [60]	validation_0-rmse:2.45792
# [70]	validation_0-rmse:2.45302
# [80]	validation_0-rmse:2.45402
# [90]	validation_0-rmse:2.46282
# Stopping. Best iteration:
# [47]	validation_0-rmse:2.44813
#
# [TX_2] Fold1: 9.202473878860474 [sec]
# [0]	validation_0-rmse:3.84577
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.09529
# [20]	validation_0-rmse:2.94514
# [30]	validation_0-rmse:2.87493
# [40]	validation_0-rmse:2.81060
# [50]	validation_0-rmse:2.80543
# [60]	validation_0-rmse:2.86162
# [70]	validation_0-rmse:2.84744
# [80]	validation_0-rmse:2.83831
# [90]	validation_0-rmse:2.84575
# Stopping. Best iteration:
# [45]	validation_0-rmse:2.79764
#
# [TX_2] Fold2: 8.725050687789917 [sec]
# [0]	validation_0-rmse:3.49724
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.81222
# [20]	validation_0-rmse:2.76205
# [30]	validation_0-rmse:2.74289
# [40]	validation_0-rmse:2.72866
# [50]	validation_0-rmse:2.72803
# [60]	validation_0-rmse:2.73140
# [70]	validation_0-rmse:2.71299
# [80]	validation_0-rmse:2.72863
# [90]	validation_0-rmse:2.73695
# [100]	validation_0-rmse:2.74181
# [110]	validation_0-rmse:2.75106
# Stopping. Best iteration:
# [65]	validation_0-rmse:2.70309
#
# [TX_2] Fold3: 8.418901681900024 [sec]
# [0]	validation_0-rmse:3.58755
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.81847
# [20]	validation_0-rmse:2.75580
# [30]	validation_0-rmse:2.72782
# [40]	validation_0-rmse:2.71295
# [50]	validation_0-rmse:2.71247
# [60]	validation_0-rmse:2.72266
# [70]	validation_0-rmse:2.73383
# [80]	validation_0-rmse:2.74141
# [90]	validation_0-rmse:2.75081
# Stopping. Best iteration:
# [47]	validation_0-rmse:2.71000
#
# [TX_2] Fold4: 7.281013011932373 [sec]
# [0]	validation_0-rmse:3.59813
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.73467
# [20]	validation_0-rmse:2.66889
# [30]	validation_0-rmse:2.61517
# [40]	validation_0-rmse:2.57943
# [50]	validation_0-rmse:2.56508
# [60]	validation_0-rmse:2.57249
# [70]	validation_0-rmse:2.56928
# [80]	validation_0-rmse:2.56812
# [90]	validation_0-rmse:2.57686
# [100]	validation_0-rmse:2.58062
# Stopping. Best iteration:
# [56]	validation_0-rmse:2.55666
#
# [TX_2] Fold5: 6.768538236618042 [sec]
# [I 2020-06-29 07:22:14,731] Finished trial#68 with value: 2.643100309371948 with parameters: {'subsample': 0.6, 'colsample_bytree': 0.65, 'max_depth': 5, 'gamma': 2.666007407829248e-07, 'min_child_weight': 2.501492669016419}. Best is trial#64 with value: 2.5518704414367677.
# [0]	validation_0-rmse:3.59245
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.85122
# [20]	validation_0-rmse:2.76144
# [30]	validation_0-rmse:2.73700
# [40]	validation_0-rmse:2.71739
# [50]	validation_0-rmse:2.72369
# [60]	validation_0-rmse:2.72618
# [70]	validation_0-rmse:2.72435
# [80]	validation_0-rmse:2.72016
# [90]	validation_0-rmse:2.71421
# [100]	validation_0-rmse:2.70328
# [110]	validation_0-rmse:2.70129
# [120]	validation_0-rmse:2.69514
# [130]	validation_0-rmse:2.69443
# [140]	validation_0-rmse:2.68170
# [150]	validation_0-rmse:2.69442
# [160]	validation_0-rmse:2.69263
# [170]	validation_0-rmse:2.69410
# [180]	validation_0-rmse:2.68753
# [190]	validation_0-rmse:2.68659
# Stopping. Best iteration:
# [145]	validation_0-rmse:2.68065
#
# [TX_2] Fold1: 11.836095571517944 [sec]
# [0]	validation_0-rmse:3.94877
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.39133
# [20]	validation_0-rmse:3.28152
# [30]	validation_0-rmse:3.27349
# [40]	validation_0-rmse:3.24582
# [50]	validation_0-rmse:3.23609
# [60]	validation_0-rmse:3.21299
# [70]	validation_0-rmse:3.19569
# [80]	validation_0-rmse:3.20133
# [90]	validation_0-rmse:3.18496
# [100]	validation_0-rmse:3.17479
# [110]	validation_0-rmse:3.17033
# [120]	validation_0-rmse:3.15558
# [130]	validation_0-rmse:3.15165
# [140]	validation_0-rmse:3.14607
# [150]	validation_0-rmse:3.13687
# [160]	validation_0-rmse:3.12664
# [170]	validation_0-rmse:3.12343
# [180]	validation_0-rmse:3.11478
# [190]	validation_0-rmse:3.11487
# [200]	validation_0-rmse:3.11117
# [210]	validation_0-rmse:3.11629
# [220]	validation_0-rmse:3.11274
# [230]	validation_0-rmse:3.10964
# [240]	validation_0-rmse:3.12222
# [250]	validation_0-rmse:3.11409
# [260]	validation_0-rmse:3.10957
# [270]	validation_0-rmse:3.10903
# [280]	validation_0-rmse:3.10806
# Stopping. Best iteration:
# [234]	validation_0-rmse:3.10581
#
# [TX_2] Fold2: 13.200571537017822 [sec]
# [0]	validation_0-rmse:3.58892
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.12640
# [20]	validation_0-rmse:3.04005
# [30]	validation_0-rmse:3.04674
# [40]	validation_0-rmse:3.05957
# [50]	validation_0-rmse:3.06642
# [60]	validation_0-rmse:3.05897
# [70]	validation_0-rmse:3.04168
# [80]	validation_0-rmse:3.02185
# [90]	validation_0-rmse:3.02062
# [100]	validation_0-rmse:3.02040
# [110]	validation_0-rmse:3.02295
# [120]	validation_0-rmse:3.02163
# [130]	validation_0-rmse:3.00296
# [140]	validation_0-rmse:2.99549
# [150]	validation_0-rmse:2.99374
# [160]	validation_0-rmse:2.99073
# [170]	validation_0-rmse:2.98896
# [180]	validation_0-rmse:2.98864
# [190]	validation_0-rmse:2.97960
# [200]	validation_0-rmse:2.97596
# [210]	validation_0-rmse:2.98377
# [220]	validation_0-rmse:2.97526
# [230]	validation_0-rmse:2.97052
# [240]	validation_0-rmse:2.96731
# [250]	validation_0-rmse:2.96762
# [260]	validation_0-rmse:2.96723
# [270]	validation_0-rmse:2.95977
# [280]	validation_0-rmse:2.96327
# [290]	validation_0-rmse:2.96353
# [300]	validation_0-rmse:2.96096
# [310]	validation_0-rmse:2.93858
# [320]	validation_0-rmse:2.93548
# [330]	validation_0-rmse:2.93521
# [340]	validation_0-rmse:2.93277
# [350]	validation_0-rmse:2.93609
# [360]	validation_0-rmse:2.93644
# [370]	validation_0-rmse:2.93811
# [380]	validation_0-rmse:2.93798
# Stopping. Best iteration:
# [337]	validation_0-rmse:2.93122
#
# [TX_2] Fold3: 14.461045980453491 [sec]
# [0]	validation_0-rmse:3.70140
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.21141
# [20]	validation_0-rmse:3.13617
# [30]	validation_0-rmse:3.12959
# [40]	validation_0-rmse:3.10223
# [50]	validation_0-rmse:3.07555
# [60]	validation_0-rmse:3.09115
# [70]	validation_0-rmse:3.07675
# [80]	validation_0-rmse:3.07703
# [90]	validation_0-rmse:3.07503
# [100]	validation_0-rmse:3.07616
# [110]	validation_0-rmse:3.07156
# [120]	validation_0-rmse:3.06810
# [130]	validation_0-rmse:3.06418
# [140]	validation_0-rmse:3.05609
# [150]	validation_0-rmse:3.05580
# [160]	validation_0-rmse:3.05413
# [170]	validation_0-rmse:3.04885
# [180]	validation_0-rmse:3.04381
# [190]	validation_0-rmse:3.03848
# [200]	validation_0-rmse:3.03789
# [210]	validation_0-rmse:3.03560
# [220]	validation_0-rmse:3.03434
# [230]	validation_0-rmse:3.02904
# [240]	validation_0-rmse:3.03018
# [250]	validation_0-rmse:3.03276
# [260]	validation_0-rmse:3.03601
# [270]	validation_0-rmse:3.03339
# [280]	validation_0-rmse:3.03355
# Stopping. Best iteration:
# [230]	validation_0-rmse:3.02904
#
# [TX_2] Fold4: 10.60847783088684 [sec]
# [0]	validation_0-rmse:3.75186
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.31944
# [20]	validation_0-rmse:3.25092
# [30]	validation_0-rmse:3.22745
# [40]	validation_0-rmse:3.18577
# [50]	validation_0-rmse:3.19667
# [60]	validation_0-rmse:3.19421
# [70]	validation_0-rmse:3.17197
# [80]	validation_0-rmse:3.17524
# [90]	validation_0-rmse:3.17336
# [100]	validation_0-rmse:3.16481
# [110]	validation_0-rmse:3.16584
# [120]	validation_0-rmse:3.15799
# [130]	validation_0-rmse:3.16261
# [140]	validation_0-rmse:3.15316
# [150]	validation_0-rmse:3.15382
# [160]	validation_0-rmse:3.15206
# [170]	validation_0-rmse:3.15061
# [180]	validation_0-rmse:3.15298
# [190]	validation_0-rmse:3.14634
# [200]	validation_0-rmse:3.13920
# [210]	validation_0-rmse:3.14213
# [220]	validation_0-rmse:3.13576
# [230]	validation_0-rmse:3.13644
# [240]	validation_0-rmse:3.13841
# [250]	validation_0-rmse:3.13766
# [260]	validation_0-rmse:3.13638
# [270]	validation_0-rmse:3.13181
# [280]	validation_0-rmse:3.13240
# [290]	validation_0-rmse:3.13126
# [300]	validation_0-rmse:3.12664
# [310]	validation_0-rmse:3.12567
# [320]	validation_0-rmse:3.12441
# [330]	validation_0-rmse:3.12109
# [340]	validation_0-rmse:3.12094
# [350]	validation_0-rmse:3.11820
# [360]	validation_0-rmse:3.11496
# [370]	validation_0-rmse:3.11429
# [380]	validation_0-rmse:3.11164
# [390]	validation_0-rmse:3.11471
# [400]	validation_0-rmse:3.11757
# [410]	validation_0-rmse:3.11403
# [420]	validation_0-rmse:3.11105
# [430]	validation_0-rmse:3.10719
# [440]	validation_0-rmse:3.10946
# [450]	validation_0-rmse:3.10996
# [460]	validation_0-rmse:3.10628
# [470]	validation_0-rmse:3.10757
# [480]	validation_0-rmse:3.10599
# [490]	validation_0-rmse:3.10518
# [500]	validation_0-rmse:3.10655
# [510]	validation_0-rmse:3.10587
# [520]	validation_0-rmse:3.10306
# [530]	validation_0-rmse:3.10261
# [540]	validation_0-rmse:3.10208
# [550]	validation_0-rmse:3.10064
# [560]	validation_0-rmse:3.10290
# [570]	validation_0-rmse:3.10025
# [580]	validation_0-rmse:3.10249
# [590]	validation_0-rmse:3.09846
# [600]	validation_0-rmse:3.10117
# [610]	validation_0-rmse:3.09932
# [620]	validation_0-rmse:3.09595
# [630]	validation_0-rmse:3.09405
# [640]	validation_0-rmse:3.09008
# [650]	validation_0-rmse:3.08959
# [660]	validation_0-rmse:3.08628
# [670]	validation_0-rmse:3.08646
# [680]	validation_0-rmse:3.08515
# [690]	validation_0-rmse:3.08418
# [700]	validation_0-rmse:3.08571
# [710]	validation_0-rmse:3.08698
# [720]	validation_0-rmse:3.08555
# [730]	validation_0-rmse:3.08469
# [740]	validation_0-rmse:3.08514
# Stopping. Best iteration:
# [692]	validation_0-rmse:3.08389
#
# [TX_2] Fold5: 16.890161514282227 [sec]
# [I 2020-06-29 07:23:21,903] Finished trial#69 with value: 2.966122579574585 with parameters: {'subsample': 0.6, 'colsample_bytree': 0.95, 'max_depth': 6, 'gamma': 1.374639291653204e-07, 'min_child_weight': 5.4584171968959}. Best is trial#64 with value: 2.5518704414367677.
# 100%|████████████████████████████████████████████████████████████████████████████████| 6/6 [6:29:43<00:00, 3897.30s/it]

# %%
# del df
# gc.collect()

# %% [markdown]
# ## Train & Predict by best model (function)

# %%
def xgboost_by_bestparam_for_valid(df, store, best_params, valid_preds):
    print('##################### Traing4ValidByBestParam START: {0} #####################'.format(d_store_id[store]))
    print('Best Parameters of store {0} model: {1}'.format(d_store_id[store], best_params))
    
    # prepare data set
    df_store = df[df['store_id'] == store]
    X_train = df_store[df_store['d'] < VALID_FIRST_DAY].drop('sold', axis=1)
    y_train = df_store[df_store['d'] < VALID_FIRST_DAY]['sold']
    X_valid = df_store[(df_store['d'] >= VALID_FIRST_DAY) & (df_store['d'] <= VALID_LAST_DAY)].drop('sold', axis=1)
    
    # train XGBoost by using best_params
    model = xgb.XGBRegressor(**best_params)
    model.fit(X_train, y_train, eval_metric='rmse')
    
    # save model for validation
#     modelfile = 'BestModel4valid_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.pkl'
    modelfile = 'BestModel4valid_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'_lagOlder28.pkl'
    with open(os.path.join('result', 'best_model', modelfile), 'wb') as f:
        pickle.dump(model, f)
    
    # predict for valid
    valid_preds[X_valid.index] = model.predict(X_valid)
    del df_store, X_train, y_train, X_valid, model
    gc.collect()

# %%
# def xgboost_by_bestparam_for_test(df, store, best_params, eval_preds):
#     print('##################### Traing4TestByBestParam START: {0} #####################'.format(d_store_id[store]))
    
#     # prepare data set
#     df_store = df[df['store_id'] == store]
#     X_train = df_store[df_store['d'] <= VALID_LAST_DAY].drop('sold', axis=1)
#     y_train = df_store[df_store['d'] <= VALID_LAST_DAY]['sold']
#     X_test = df_store[df_store['d'] > VALID_LAST_DAY].drop('sold', axis=1)
    
#     # train XGBoost by using best_params
#     model = xgb.XGBRegressor(**best_params)
#     model.fit(X_train, y_train, eval_metric='rmse')
        
#     # predict for test
#     eval_preds[X_test.index] = model.predict(X_test)
    
#     # save model for test
# #     modelfile = 'BestModel4test_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.pkl'
#     modelfile = 'BestModel4test_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'_lagOlder28.pkl'
#     with open(os.path.join('result', 'best_model', modelfile), 'wb') as f:
#         pickle.dump(model, f)
    
#     del df_store, X_train, y_train, X_test, model
#     gc.collect()

# %% [markdown]
# ## Train & Predict by best model

# %%
# # train & predict (best model)
# # df_all = pd.read_pickle(os.path.join(data_dir, 'data_all.pkl'))
# df_all = pd.read_pickle(os.path.join(data_dir, 'data_all_lagOlder28.pkl'))

# valid = df_all[(df_all['d'] >= VALID_FIRST_DAY) & (df_all['d'] <= VALID_LAST_DAY)][['id','d','sold']]
# test = df_all[df_all['d'] > VALID_LAST_DAY][['id','d','sold']]
# valid_preds = valid['sold']
# eval_preds = test['sold']

# for store in tqdm(stores):
#     # read best param selected by CV
# #     bestparam_filename = 'BestParamsSelectedByCV_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.pkl'
#     bestparam_filename = 'BestParamsSelectedByCV_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'_lagOlder28.pkl'
#     with open(os.path.join('result', 'best_param_cv', bestparam_filename), 'rb') as f:
#         best_params = pickle.load(f)

#     # add other params
#     best_params['objective'] = 'reg:squarederror'
#     best_params['n_estimators'] = 1000
#     best_params['learning_rate'] = 0.1
#     best_params['tree_method'] = 'gpu_hist'
    
#     # best model for valid
#     xgboost_by_bestparam_for_valid(df_all, store, best_params, valid_preds)
    
#     # best model for test
#     xgboost_by_bestparam_for_test(df_all, store, best_params, eval_preds)

# %%
# # save valid_preds
# # valid_preds_filename = 'ValidPreds_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.pkl'
# valid_preds_filename = 'ValidPreds_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'_lagOlder28.pkl'
# with open(os.path.join('result', 'preds', valid_preds_filename), 'wb') as f:
#     pickle.dump(valid_preds, f)
    
# # save test_preds
# # eval_preds_filename = 'EvalPreds_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.pkl'
# eval_preds_filename = 'EvalPreds_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'_lagOlder28.pkl'
# with open(os.path.join('result', 'preds', eval_preds_filename), 'wb') as f:
#     pickle.dump(eval_preds, f)

# %%
# del df_all
# gc.collect()

# %% [markdown]
# # Make submission

# %%
#Set actual equal to false if you want to top in the public leaderboard :P
actual = True
if actual == False:
    #Get the validation results(We already have them as less than one month left for competition to end)
    validation = sales[['id']+['d_' + str(i) for i in range(1914,1942)]]
    validation['id']=pd.read_csv(os.path.join(rawdata_dir, 'sales_train_validation.csv')).id
    validation.columns=['id'] + ['F' + str(i + 1) for i in range(28)]
else:
    #Get the actual validation results
    valid['sold'] = valid_preds
    validation = valid[['id','d','sold']]
    validation = pd.pivot(validation, index='id', columns='d', values='sold').reset_index()
    validation.columns=['id'] + ['F' + str(i + 1) for i in range(28)]
    validation.id = validation.id.map(d_id).str.replace('evaluation','validation')

#Get the evaluation results
test['sold'] = eval_preds
evaluation = test[['id','d','sold']]
evaluation = pd.pivot(evaluation, index='id', columns='d', values='sold').reset_index()
evaluation.columns=['id'] + ['F' + str(i + 1) for i in range(28)]
#Remap the category id to their respective categories
evaluation.id = evaluation.id.map(d_id)

#Prepare the submission
submit = pd.concat([validation,evaluation]).reset_index(drop=True)

isNegative2Zero = False
if isNegative2Zero:
    submit = submit.set_index("id", drop=True)
    submit[submit < 0] = 0
    submit = submit.reset_index()

# submit_file = 'xgboost_cv_UseValidPredsIs'+str(actual)+'_Negative2ZeroIs'+str(isNegative2Zero)+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.csv'
submit_file = 'xgboost_cv_UseValidPredsIs'+str(actual)+'_Negative2ZeroIs'+str(isNegative2Zero)+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'_lagOlder28.csv'
submit.to_csv(os.path.join('submission_point', submit_file), index=False)
