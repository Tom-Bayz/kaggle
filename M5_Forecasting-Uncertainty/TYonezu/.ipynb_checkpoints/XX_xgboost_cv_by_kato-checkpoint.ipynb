# %%
import os
import pandas as pd
import numpy as np
import plotly_express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt
import seaborn as sns
import gc
import copy
import warnings
warnings.filterwarnings('ignore')
import xgboost as xgb
from sklearn.metrics import mean_squared_error
import joblib
import optuna
from tqdm import tqdm
import time
import codecs
import pickle

# %% [markdown]
# # Configuration

# %%
rawdata_dir = 'rawdata'
data_dir = 'data'

lags = [1,2,3,6,12,24,36]
#lags = [28,35,42,49,56]

# NUM_FOLD_DAYS = 28
NUM_FOLD_DAYS = 56
VALID_FIRST_DAY = 1914
VALID_LAST_DAY = 1941
NUM_USE_DAY = 365
# TRAIN_FIRST_DAY = max(lags)
TRAIN_FIRST_DAY = VALID_FIRST_DAY - NUM_USE_DAY + 1

OPTUNA_TRIAL = 70

# %% [markdown]
# # Read data

# %%
sales = pd.read_csv(os.path.join(rawdata_dir, 'sales_train_evaluation.csv'))
sales.name = 'sales'
calendar = pd.read_csv(os.path.join(rawdata_dir, 'calendar.csv'))
calendar.name = 'calendar'
prices = pd.read_csv(os.path.join(rawdata_dir, 'sell_prices.csv'))
prices.name = 'prices'

# %% [markdown]
# Since, the validation data is now available for the days 1914-1941, Adding zero sales for days: d_1942 - d_1969(Test)

# %%
#Add zero sales for the remaining days 1942-1969
for d in range(1942,1970):
    col = 'd_' + str(d)
    sales[col] = 0
    sales[col] = sales[col].astype(np.int16)

# %% [markdown]
# # Downcast

# %%
#Downcast in order to save memory
def downcast(df):
    cols = df.dtypes.index.tolist()
    types = df.dtypes.values.tolist()
    for i,t in enumerate(types):
        if 'int' in str(t):
            if df[cols[i]].min() > np.iinfo(np.int8).min and df[cols[i]].max() < np.iinfo(np.int8).max:
                df[cols[i]] = df[cols[i]].astype(np.int8)
            elif df[cols[i]].min() > np.iinfo(np.int16).min and df[cols[i]].max() < np.iinfo(np.int16).max:
                df[cols[i]] = df[cols[i]].astype(np.int16)
            elif df[cols[i]].min() > np.iinfo(np.int32).min and df[cols[i]].max() < np.iinfo(np.int32).max:
                df[cols[i]] = df[cols[i]].astype(np.int32)
            else:
                df[cols[i]] = df[cols[i]].astype(np.int64)
        elif 'float' in str(t):
            if df[cols[i]].min() > np.finfo(np.float16).min and df[cols[i]].max() < np.finfo(np.float16).max:
                df[cols[i]] = df[cols[i]].astype(np.float16)
            elif df[cols[i]].min() > np.finfo(np.float32).min and df[cols[i]].max() < np.finfo(np.float32).max:
                df[cols[i]] = df[cols[i]].astype(np.float32)
            else:
                df[cols[i]] = df[cols[i]].astype(np.float64)
        elif t == np.object:
            if cols[i] == 'date':
                df[cols[i]] = pd.to_datetime(df[cols[i]], format='%Y-%m-%d')
            else:
                df[cols[i]] = df[cols[i]].astype('category')
    return df

sales = downcast(sales)
prices = downcast(prices)
calendar = downcast(calendar)

# %% [markdown]
# # Melt data

# %%
df = pd.melt(sales, id_vars=['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'], var_name='d', value_name='sold').dropna()

# %% [markdown]
# ## Combine data
# Combine price data from prices dataframe and days data from calendar dataset.

# %%
df = pd.merge(df, calendar, on='d', how='left')
df = pd.merge(df, prices, on=['store_id','item_id','wm_yr_wk'], how='left')

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Label Encoding

# %%
#Store the categories along with their codes
d_id = dict(zip(df.id.cat.codes, df.id))
d_item_id = dict(zip(df.item_id.cat.codes, df.item_id))
d_dept_id = dict(zip(df.dept_id.cat.codes, df.dept_id))
d_cat_id = dict(zip(df.cat_id.cat.codes, df.cat_id))
d_store_id = dict(zip(df.store_id.cat.codes, df.store_id))
d_state_id = dict(zip(df.state_id.cat.codes, df.state_id))

# %%
df.d = df['d'].apply(lambda x: x.split('_')[1]).astype(np.int16)
cols = df.dtypes.index.tolist()
types = df.dtypes.values.tolist()
for i,type in enumerate(types):
    if type.name == 'category':
        df[cols[i]] = df[cols[i]].cat.codes
        
df.drop('date',axis=1,inplace=True)

# %% [markdown]
# ## Introduce lags

# %%
#Introduce lags
def make_lags(df, lags):
    for lag in lags:
        df['sold_lag_'+str(lag)] = df.groupby(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'],as_index=False)['sold'].shift(lag).astype(np.float16)
        
    return df

# %%
df = make_lags(df, lags)

# %%
df.columns
# Out:
# Index(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id', 'd',
#        'sold', 'wm_yr_wk', 'weekday', 'wday', 'month', 'year', 'event_name_1',
#        'event_type_1', 'event_name_2', 'event_type_2', 'snap_CA', 'snap_TX',
#        'snap_WI', 'sell_price', 'sold_lag_28', 'sold_lag_35', 'sold_lag_42',
#        'sold_lag_49', 'sold_lag_56', 'sold_lag_1', 'sold_lag_2', 'sold_lag_3',
#        'sold_lag_6', 'sold_lag_12', 'sold_lag_24', 'sold_lag_36'],
#       dtype='object')

# %%
import seaborn as sn

tmp = df[['sold','sold_lag_1', 'sold_lag_2', 'sold_lag_3',
       'sold_lag_6', 'sold_lag_12', 'sold_lag_24', 'sold_lag_36','sold_lag_28', 'sold_lag_35', 'sold_lag_42','sold_lag_49', 'sold_lag_56']].sample(n=1000000)
tmp.corr()
# Out:
#                  sold  sold_lag_28  sold_lag_35  sold_lag_42  sold_lag_49  \
# sold         1.000000     0.661409     0.649749     0.628176     0.636591
# sold_lag_28  0.661409     1.000000     0.720323     0.670618     0.679960
# sold_lag_35  0.649749     0.720323     1.000000     0.706760     0.689883
# sold_lag_42  0.628176     0.670618     0.706760     1.000000     0.719236
# sold_lag_49  0.636591     0.679960     0.689883     0.719236     1.000000
# sold_lag_56  0.628994     0.665978     0.671965     0.687853     0.726725
#
#              sold_lag_56
# sold            0.628994
# sold_lag_28     0.665978
# sold_lag_35     0.671965
# sold_lag_42     0.687853
# sold_lag_49     0.726725
# sold_lag_56     1.000000

# %%
sn.pairplot(tmp)
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-8201d1849928> in <module>
# ----> 1 sn.pairplot(tmp)
#       2 plt.grid(True)
#       3 plt.show()
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2119     if kind == "scatter":
#    2120         from .relational import scatterplot  # Avoid circular import
# -> 2121         plotter(scatterplot, **plot_kws)
#    2122     elif kind == "reg":
#    2123         from .regression import regplot  # Avoid circular import
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map_offdiag(self, func, **kwargs)
#    1511
#    1512         self.map_lower(func, **kwargs)
# -> 1513         self.map_upper(func, **kwargs)
#    1514         return self
#    1515
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map_upper(self, func, **kwargs)
#    1471                 # Attempt to get data for this level, allowing for empty
#    1472                 try:
# -> 1473                     data_k = hue_grouped.get_group(label_k)
#    1474                 except KeyError:
#    1475                     data_k = pd.DataFrame(columns=self.data.columns,
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in get_group(self, name, obj)
#     680             raise KeyError(name)
#     681
# --> 682         return obj.take(inds, axis=self.axis)
#     683
#     684     def __iter__(self):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3602
#    3603         new_data = self._data.take(
# -> 3604             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3605         )
#    3606         result = self._constructor(new_data).__finalize__(self)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in take(self, indexer, axis, verify, convert)
#    1395         new_labels = self.axes[axis].take(indexer)
#    1396         return self.reindex_indexer(
# -> 1397             new_axis=new_labels, indexer=indexer, axis=axis, allow_dups=True
#    1398         )
#    1399
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1265                     ),
#    1266                 )
# -> 1267                 for blk in self.blocks
#    1268             ]
#    1269
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in <listcomp>(.0)
#    1265                     ),
#    1266                 )
# -> 1267                 for blk in self.blocks
#    1268             ]
#    1269
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_tuple)
#    1312
#    1313         new_values = algos.take_nd(
# -> 1314             values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1315         )
#    1316
#
# ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py in take_nd(arr, indexer, axis, out, fill_value, mask_info, allow_fill)
#    1719         arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#    1720     )
# -> 1721     func(arr, indexer, out, fill_value)
#    1722
#    1723     if flip_order:
#
# ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py in func(arr, indexer, out, fill_value)
#    1507         indexer = ensure_int64(indexer)
#    1508         _take_nd_object(
# -> 1509             arr, indexer, out, axis=axis, fill_value=fill_value, mask_info=mask_info
#    1510         )
#    1511
#
# ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py in _take_nd_object(arr, indexer, out, axis, fill_value, mask_info)
#    1371         arr = arr.astype(out.dtype)
#    1372     if arr.shape[axis] > 0:
# -> 1373         arr.take(ensure_platform_int(indexer), axis=axis, out=out)
#    1374     if needs_masking:
#    1375         outindexer = [slice(None)] * arr.ndim
#
# KeyboardInterrupt:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x000001468C5C5678> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# ~\Anaconda3\lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     125         for f_mgr in cls.get_all_fig_managers():
#     126             if force or f_mgr.canvas.figure.stale:
# --> 127                 f_mgr.canvas.draw_idle()
#     128
#     129 atexit.register(Gcf.destroy_all)
#
# ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    1929         if not self._is_idle_drawing:
#    1930             with self._idle_draw_cntx():
# -> 1931                 self.draw(*args, **kwargs)
#    1932
#    1933     @cbook.deprecated("3.2")
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     391              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     392               else nullcontext()):
# --> 393             self.figure.draw(self.renderer)
#     394             # A GUI class may be need to update a window using this draw, so
#     395             # don't forget to call the superclass.
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1734             self.patch.draw(renderer)
#    1735             mimage._draw_list_compositing_images(
# -> 1736                 renderer, self, artists, self.suppressComposite)
#    1737
#    1738             renderer.close_group('figure')
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2628             renderer.stop_rasterizing()
#    2629
# -> 2630         mimage._draw_list_compositing_images(renderer, self, artists)
#    2631
#    2632         renderer.close_group('axes')
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\collections.py in draw(self, renderer)
#     893     def draw(self, renderer):
#     894         self.set_sizes(self._sizes, self.figure.dpi)
# --> 895         Collection.draw(self, renderer)
#     896
#     897
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\collections.py in draw(self, renderer)
#     370                 self._offset_position)
#     371
# --> 372         gc.restore()
#     373         renderer.close_group(self.__class__.__name__)
#     374         self.stale = False
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x000001468C5CDA68> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in flush_figures()
#     115         # ignore the tracking, just draw and close all figures
#     116         try:
# --> 117             return show(True)
#     118         except Exception as e:
#     119             # safely show traceback if in IPython, else raise
#
# ~\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~\Anaconda3\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <C:\Users\organ\Anaconda3\lib\site-packages\decorator.py:decorator-gen-9> in __call__(self, obj)
#
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2077                             print_method, dpi=dpi, orientation=orientation),
#    2078                         draw_disabled=True)
# -> 2079                     self.figure.draw(renderer)
#    2080                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2081                     bbox_inches = self.figure.get_tightbbox(renderer,
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1734             self.patch.draw(renderer)
#    1735             mimage._draw_list_compositing_images(
# -> 1736                 renderer, self, artists, self.suppressComposite)
#    1737
#    1738             renderer.close_group('figure')
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2628             renderer.stop_rasterizing()
#    2629
# -> 2630         mimage._draw_list_compositing_images(renderer, self, artists)
#    2631
#    2632         renderer.close_group('axes')
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1237         # the actual bbox
#    1238
# -> 1239         self._update_label_position(renderer)
#    1240
#    1241         self.label.draw(renderer)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in _update_label_position(self, renderer)
#    2019         # get bounding boxes for this axis and any siblings
#    2020         # that have been set by `fig.align_xlabels()`
# -> 2021         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2022
#    2023         x, y = self.label.get_position()
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick_boxes_siblings(self, renderer)
#    2003         # if we want to align labels from other axes:
#    2004         for nn, axx in enumerate(grp.get_siblings(self.axes)):
# -> 2005             ticks_to_draw = axx.xaxis._update_ticks()
#    2006             tlb, tlb2 = axx.xaxis._get_tick_bboxes(ticks_to_draw, renderer)
#    2007             bboxes.extend(tlb)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in _update_ticks(self)
#    1101         the axes.  Return the list of ticks that will be drawn.
#    1102         """
# -> 1103         major_locs = self.get_majorticklocs()
#    1104         major_labels = self.major.formatter.format_ticks(major_locs)
#    1105         major_ticks = self.get_major_ticks(len(major_locs))
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in get_majorticklocs(self)
#    1346     def get_majorticklocs(self):
#    1347         """Get the array of major tick locations in data coordinates."""
# -> 1348         return self.major.locator()
#    1349
#    1350     def get_minorticklocs(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\ticker.py in __call__(self)
#    2232     def __call__(self):
#    2233         vmin, vmax = self.axis.get_view_interval()
# -> 2234         return self.tick_values(vmin, vmax)
#    2235
#    2236     def tick_values(self, vmin, vmax):
#
# ~\Anaconda3\lib\site-packages\matplotlib\ticker.py in tick_values(self, vmin, vmax)
#    2240         vmin, vmax = mtransforms.nonsingular(
#    2241             vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2242         locs = self._raw_ticks(vmin, vmax)
#    2243
#    2244         prune = self._prune
#
# ~\Anaconda3\lib\site-packages\matplotlib\ticker.py in _raw_ticks(self, vmin, vmax)
#    2179         if self._nbins == 'auto':
#    2180             if self.axis is not None:
# -> 2181                 nbins = np.clip(self.axis.get_tick_space(),
#    2182                                 max(1, self._min_n_ticks - 1), 9)
#    2183             else:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in get_tick_space(self)
#    2188         ends = self.axes.transAxes.transform([[0, 0], [1, 0]])
#    2189         length = ((ends[1][0] - ends[0][0]) / self.axes.figure.dpi) * 72
# -> 2190         tick = self._get_tick(True)
#    2191         # There is a heuristic here that the aspect ratio of tick text
#    2192         # is no more than 3:1
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    1941         else:
#    1942             tick_kw = self._minor_tick_kw
# -> 1943         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1944
#    1945     def _get_label(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     159         self.gridline = self._get_gridline()
#     160         self.label1 = self._get_text1()
# --> 161         self.label2 = self._get_text2()
#     162
#     163         self.gridline.set_visible(gridOn)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in _get_text2(self)
#     451             color=self._labelcolor,
#     452             verticalalignment=vert,
# --> 453             horizontalalignment=horiz,
#     454             )
#     455         t.set_transform(trans)
#
# ~\Anaconda3\lib\site-packages\matplotlib\text.py in __init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, **kwargs)
#     166         self._linespacing = linespacing
#     167         self.set_rotation_mode(rotation_mode)
# --> 168         self.update(kwargs)
#     169
#     170     def update(self, kwargs):
#
# ~\Anaconda3\lib\site-packages\matplotlib\text.py in update(self, kwargs)
#     175         sentinel = object()  # bbox can be None, so use another sentinel.
#     176         bbox = kwargs.pop("bbox", sentinel)
# --> 177         super().update(kwargs)
#     178         if bbox is not sentinel:
#     179             self.set_bbox(bbox)
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1003                 return func(v)
#    1004
# -> 1005         with cbook._setattr_cm(self, eventson=False):
#    1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#
# ~\Anaconda3\lib\contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in _setattr_cm(obj, **kwargs)
#    1959     """
#    1960     sentinel = object()
# -> 1961     origs = [(attr, getattr(obj, attr, sentinel)) for attr in kwargs]
#    1962     try:
#    1963         for attr, val in kwargs.items():
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in <listcomp>(.0)
#    1959     """
#    1960     sentinel = object()
# -> 1961     origs = [(attr, getattr(obj, attr, sentinel)) for attr in kwargs]
#    1962     try:
#    1963         for attr, val in kwargs.items():
#
# KeyboardInterrupt:

# %%
# Out:
#                  sold  sold_lag_28  sold_lag_35  sold_lag_42  sold_lag_49  \
# sold         1.000000     0.646618     0.643921     0.644276     0.629174
# sold_lag_28  0.646618     1.000000     0.709752     0.687339     0.664617
# sold_lag_35  0.643921     0.709752     1.000000     0.722043     0.669054
# sold_lag_42  0.644276     0.687339     0.722043     1.000000     0.703272
# sold_lag_49  0.629174     0.664617     0.669054     0.703272     1.000000
# sold_lag_56  0.676310     0.668944     0.665401     0.675082     0.697300
#
#              sold_lag_56
# sold            0.676310
# sold_lag_28     0.668944
# sold_lag_35     0.665401
# sold_lag_42     0.675082
# sold_lag_49     0.697300
# sold_lag_56     1.000000

# %% [markdown]
# ## make new features

# %%
def make_new_feature(df, d_last = df['d'].max()):
    # copy sold
    sold_tmp = copy.copy(df['sold'])
    
    # embed NaN
    df['sold'][df['d'] > d_last] = np.nan
    
    # make feature using sold
    df['item_sold_avg'] = df.groupby('item_id')['sold'].transform('mean').astype(np.float16)
    df['state_sold_avg'] = df.groupby('state_id')['sold'].transform('mean').astype(np.float16)
    df['store_sold_avg'] = df.groupby('store_id')['sold'].transform('mean').astype(np.float16)
    df['cat_sold_avg'] = df.groupby('cat_id')['sold'].transform('mean').astype(np.float16)
    df['dept_sold_avg'] = df.groupby('dept_id')['sold'].transform('mean').astype(np.float16)
    df['cat_dept_sold_avg'] = df.groupby(['cat_id','dept_id'])['sold'].transform('mean').astype(np.float16)
    df['store_item_sold_avg'] = df.groupby(['store_id','item_id'])['sold'].transform('mean').astype(np.float16)
    df['cat_item_sold_avg'] = df.groupby(['cat_id','item_id'])['sold'].transform('mean').astype(np.float16)
    df['dept_item_sold_avg'] = df.groupby(['dept_id','item_id'])['sold'].transform('mean').astype(np.float16)
    df['state_store_sold_avg'] = df.groupby(['state_id','store_id'])['sold'].transform('mean').astype(np.float16)
    df['state_store_cat_sold_avg'] = df.groupby(['state_id','store_id','cat_id'])['sold'].transform('mean').astype(np.float16)
    df['store_cat_dept_sold_avg'] = df.groupby(['store_id','cat_id','dept_id'])['sold'].transform('mean').astype(np.float16)
    
    df['rolling_sold_mean'] = df.groupby(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'])['sold'].transform(lambda x: x.rolling(window=7).mean()).astype(np.float16)
    df['expanding_sold_mean'] = df.groupby(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'])['sold'].transform(lambda x: x.expanding(2).mean()).astype(np.float16)
    
    df['daily_avg_sold'] = df.groupby(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id','d'])['sold'].transform('mean').astype(np.float16)
    df['avg_sold'] = df.groupby(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'])['sold'].transform('mean').astype(np.float16)
    df['selling_trend'] = (df['daily_avg_sold'] - df['avg_sold']).astype(np.float16)
    df.drop(['daily_avg_sold','avg_sold'],axis=1,inplace=True)
    
    # restore sold
    df['sold'] = sold_tmp
    
    return df

# %%
df_all = copy.copy(df)
df_all = make_new_feature(df_all)
df_all = df_all[df_all['d'] >= max(lags)]
df_all.info()

# df_all.to_pickle(os.path.join(data_dir, 'data_all.pkl'))   # save df_all (use this after CV)
df_all.to_pickle(os.path.join(data_dir, 'data_all_lag'+str(max(lags))+'.pkl'))   # save df_all (use this after CV)
del df_all
gc.collect()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57870020 entries, 2164790 to 60034809
# Data columns (total 46 columns):
# id                          int16
# item_id                     int16
# dept_id                     int8
# cat_id                      int8
# store_id                    int8
# state_id                    int8
# d                           int16
# sold                        int16
# wm_yr_wk                    int16
# weekday                     int8
# wday                        int8
# month                       int8
# year                        int16
# event_name_1                int8
# event_type_1                int8
# event_name_2                int8
# event_type_2                int8
# snap_CA                     int8
# snap_TX                     int8
# snap_WI                     int8
# sell_price                  float16
# sold_lag_1                  float16
# sold_lag_2                  float16
# sold_lag_3                  float16
# sold_lag_6                  float16
# sold_lag_12                 float16
# sold_lag_24                 float16
# sold_lag_36                 float16
# sold_lag_48                 float16
# sold_lag_60                 float16
# sold_lag_72                 float16
# item_sold_avg               float16
# state_sold_avg              float16
# store_sold_avg              float16
# cat_sold_avg                float16
# dept_sold_avg               float16
# cat_dept_sold_avg           float16
# store_item_sold_avg         float16
# cat_item_sold_avg           float16
# dept_item_sold_avg          float16
# state_store_sold_avg        float16
# state_store_cat_sold_avg    float16
# store_cat_dept_sold_avg     float16
# rolling_sold_mean           float16
# expanding_sold_mean         float16
# selling_trend               float16
# dtypes: float16(26), int16(6), int8(14)
# memory usage: 4.6 GB
# 0

# %% [markdown]
# # Cross Validation

# %% [markdown]
# ## Cross Validation for each store (function)

# %%
def xgboost_cv_store(df, store):
    def objective(trial):
        # param space
        param = {
            'objective': 'reg:squarederror',
            'n_estimators': 1000,
            'learning_rate': 0.1,
            'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 0.95, 0.05),
            'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.6, 0.95, 0.05),
            'max_depth':  trial.suggest_int('max_depth', 3, 9),
            'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
            'min_child_weight': trial.suggest_loguniform('min_child_weight', 0.1, 10.0),
            'tree_method': 'gpu_hist'
        }
        
        ### START: CV Loop ###
        isBreakCV = False
        fold_iter = 0
        rmse_mean = 0.
        while not(isBreakCV):
            start = time.time()   # start timer
            
            d_valid_last = VALID_LAST_DAY - NUM_FOLD_DAYS * fold_iter
            d_train_last = VALID_LAST_DAY - NUM_FOLD_DAYS * (fold_iter + 1)
            if d_train_last < TRAIN_FIRST_DAY + NUM_FOLD_DAYS * 2:
                isBreakCV = True
            
            # make_new_feature
#             df_fold_file = os.path.join(data_dir, 'data_foldday'+str(NUM_FOLD_DAYS)+'_fold'+str(fold_iter + 1)+'.pkl')
            df_fold_file = os.path.join(data_dir, 'data_foldday'+str(NUM_FOLD_DAYS)+'_fold'+str(fold_iter + 1)+'_lag'+str(max(lags))+'.pkl')
            
            if os.path.isfile(df_fold_file):   # make_new_feature 適用後のファイルがあればそれを使う
                df_fold = pd.read_pickle(df_fold_file)
            else:
                df_fold = df[df['d'] <= d_valid_last]
                df_fold = make_new_feature(df_fold, d_train_last)   # train の情報だけを使って特徴量を作成
                df_fold.to_pickle(df_fold_file)   # pickleとして保存しておく

            # Extract store
            df_fold = df_fold[df_fold['store_id'] == store]
                        
            # Split data
            X_train = df_fold[(df_fold['d'] >= TRAIN_FIRST_DAY) & (df_fold['d'] <= d_train_last)].drop('sold', axis=1)
            y_train = df_fold[(df_fold['d'] >= TRAIN_FIRST_DAY) & (df_fold['d'] <= d_train_last)]['sold']
            X_valid = df_fold[(df_fold['d'] > d_train_last) & (df_fold['d'] <= d_valid_last)].drop('sold', axis=1)
            y_valid = df_fold[(df_fold['d'] > d_train_last) & (df_fold['d'] <= d_valid_last)]['sold']
            
            # Train XGBoost model
            model = xgb.XGBRegressor(**param)
#             model.fit(X_train, y_train, eval_set=[(X_train,y_train), (X_valid, y_valid)],
#                  eval_metric='rmse', verbose=10, early_stopping_rounds=100)
            model.fit(X_train, y_train, eval_set=[(X_valid, y_valid)],
                  eval_metric='rmse', verbose=10, early_stopping_rounds=50)
            y_pred = model.predict(X_valid)
            rmse_mean += np.sqrt(mean_squared_error(y_valid.values, y_pred))
            
            fold_iter += 1
            elapsed_time = time.time() - start   # stop timer
            print("[{0}] Fold{1}: {2} [sec]".format(d_store_id[store], fold_iter, elapsed_time))
        ### END: CV Loop ###
        
        del df_fold, model, X_train, y_train, X_valid, y_valid, y_pred
        gc.collect()
        
        rmse_mean /= fold_iter
        return rmse_mean
    return objective

# %% [markdown]
# ## Execute CV

# %%
stores = sales.store_id.cat.codes.unique().tolist()

# find best params by doing CV (optuna)
# for store in tqdm(stores[5:]):
for store in tqdm(stores[:5]):
    print('##################### CV START: {0} #####################'.format(d_store_id[store]))
    study = optuna.create_study()
    study.optimize(xgboost_cv_store(df, store), n_trials=OPTUNA_TRIAL)
    
    # save optuna log
    df_trial = study.trials_dataframe()
#     df_trial.to_pickle(os.path.join('report', 'OptunaTrials_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.pkl'))
    df_trial.to_pickle(os.path.join('report', 'OptunaTrials_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'_lag'+str(max(lags))+'.pkl'))
    del df_trial
    gc.collect()
    
    # savae best params found by CV
#     bestparam_filename = 'BestParamsSelectedByCV_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.pkl'
    bestparam_filename = 'BestParamsSelectedByCV_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'_lag'+str(max(lags))+'.pkl'
    with open(os.path.join('result', 'best_param_cv', bestparam_filename), 'wb') as f:
        pickle.dump(study.best_params, f)
# Out:
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# ##################### CV START: CA_1 #####################
# [0]	validation_0-rmse:3.61895
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.37840
# [20]	validation_0-rmse:3.27766
# [30]	validation_0-rmse:3.11593
# [40]	validation_0-rmse:3.03029
# [50]	validation_0-rmse:3.00279
# [60]	validation_0-rmse:2.99300
# [70]	validation_0-rmse:2.97480
# [80]	validation_0-rmse:2.97131
# [90]	validation_0-rmse:2.95982
# [100]	validation_0-rmse:2.95901
# [110]	validation_0-rmse:2.95676
# [120]	validation_0-rmse:2.95439
# [130]	validation_0-rmse:2.95312
# [140]	validation_0-rmse:2.94812
# [150]	validation_0-rmse:2.94333
# [160]	validation_0-rmse:2.93933
# [170]	validation_0-rmse:2.93478
# [180]	validation_0-rmse:2.93796
# [190]	validation_0-rmse:2.93483
# [200]	validation_0-rmse:2.93531
# [210]	validation_0-rmse:2.93572
# [220]	validation_0-rmse:2.93680
# [230]	validation_0-rmse:2.93479
# [240]	validation_0-rmse:2.93511
# [250]	validation_0-rmse:2.93266
# [260]	validation_0-rmse:2.93074
# [270]	validation_0-rmse:2.93154
# [280]	validation_0-rmse:2.93269
# [290]	validation_0-rmse:2.92983
# [300]	validation_0-rmse:2.92832
# [310]	validation_0-rmse:2.93137
# [320]	validation_0-rmse:2.93230
# [330]	validation_0-rmse:2.93323
# [340]	validation_0-rmse:2.93381
# Stopping. Best iteration:
# [294]	validation_0-rmse:2.92701
#
# [CA_1] Fold1: 234.82862734794617 [sec]
# [0]	validation_0-rmse:3.52110
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.30461
# [20]	validation_0-rmse:3.16647
# [30]	validation_0-rmse:3.11522
# [40]	validation_0-rmse:3.04436
# [50]	validation_0-rmse:3.00880
# [60]	validation_0-rmse:2.98643
# [70]	validation_0-rmse:2.96238
# [80]	validation_0-rmse:2.96351
# [90]	validation_0-rmse:2.96362
# [100]	validation_0-rmse:2.96595
# [110]	validation_0-rmse:2.94957
# [120]	validation_0-rmse:2.94217
# [130]	validation_0-rmse:2.93912
# [140]	validation_0-rmse:2.93788
# [150]	validation_0-rmse:2.94450
# [160]	validation_0-rmse:2.94282
# [170]	validation_0-rmse:2.94547
# Stopping. Best iteration:
# [124]	validation_0-rmse:2.93541
#
# [CA_1] Fold2: 226.0590455532074 [sec]
# [0]	validation_0-rmse:3.25855
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.09536
# [20]	validation_0-rmse:2.99263
# [30]	validation_0-rmse:2.89958
# [40]	validation_0-rmse:2.86566
# [50]	validation_0-rmse:2.83672
# [60]	validation_0-rmse:2.82294
# [70]	validation_0-rmse:2.81813
# [80]	validation_0-rmse:2.80061
# [90]	validation_0-rmse:2.80097
# [100]	validation_0-rmse:2.79779
# [110]	validation_0-rmse:2.79100
# [120]	validation_0-rmse:2.79655
# [130]	validation_0-rmse:2.80650
# [140]	validation_0-rmse:2.80926
# [150]	validation_0-rmse:2.81484
# [160]	validation_0-rmse:2.81763
# Stopping. Best iteration:
# [113]	validation_0-rmse:2.78864
#
# [CA_1] Fold3: 220.33797907829285 [sec]
# [0]	validation_0-rmse:3.51651
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.34394
# [20]	validation_0-rmse:3.25387
# [30]	validation_0-rmse:3.18119
# [40]	validation_0-rmse:3.10078
# [50]	validation_0-rmse:3.10596
# [60]	validation_0-rmse:3.08337
# [70]	validation_0-rmse:3.06499
# [80]	validation_0-rmse:3.04870
# [90]	validation_0-rmse:3.05007
# [100]	validation_0-rmse:3.04758
# [110]	validation_0-rmse:3.04051
# [120]	validation_0-rmse:3.03622
# [130]	validation_0-rmse:3.04489
# [140]	validation_0-rmse:3.04318
# [150]	validation_0-rmse:3.03606
# [160]	validation_0-rmse:3.03861
# [170]	validation_0-rmse:3.03404
# [180]	validation_0-rmse:3.03468
# [190]	validation_0-rmse:3.03355
# [200]	validation_0-rmse:3.03317
# [210]	validation_0-rmse:3.03184
# [220]	validation_0-rmse:3.03177
# [230]	validation_0-rmse:3.02957
# [240]	validation_0-rmse:3.03059
# [250]	validation_0-rmse:3.03025
# [260]	validation_0-rmse:3.03311
# [270]	validation_0-rmse:3.03202
# Stopping. Best iteration:
# [229]	validation_0-rmse:3.02925
#
# [CA_1] Fold4: 214.6498420238495 [sec]
# [0]	validation_0-rmse:3.83543
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.63162
# [20]	validation_0-rmse:3.51566
# [30]	validation_0-rmse:3.36505
# [40]	validation_0-rmse:3.31739
# [50]	validation_0-rmse:3.30915
# [60]	validation_0-rmse:3.27794
# [70]	validation_0-rmse:3.26689
# [80]	validation_0-rmse:3.29201
# [90]	validation_0-rmse:3.28981
# [100]	validation_0-rmse:3.30340
# [110]	validation_0-rmse:3.29279
# [120]	validation_0-rmse:3.29935
# Stopping. Best iteration:
# [70]	validation_0-rmse:3.26689
#
# [CA_1] Fold5: 206.2849600315094 [sec]
# [I 2020-06-26 02:24:37,322] Finished trial#0 with value: 2.98944149017334 with parameters: {'subsample': 0.6, 'colsample_bytree': 0.75, 'max_depth': 3, 'gamma': 0.009574717603977375, 'min_child_weight': 3.9928908030855896}. Best is trial#0 with value: 2.98944149017334.
# [0]	validation_0-rmse:3.56319
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.08081
# [20]	validation_0-rmse:2.96963
# [30]	validation_0-rmse:3.06943
# [40]	validation_0-rmse:3.03516
# [50]	validation_0-rmse:2.97002
# [60]	validation_0-rmse:2.97075
# [70]	validation_0-rmse:3.09671
# Stopping. Best iteration:
# [27]	validation_0-rmse:2.91635
#
# [CA_1] Fold1: 12.321747541427612 [sec]
# [0]	validation_0-rmse:3.46102
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.01411
# [20]	validation_0-rmse:2.89927
# [30]	validation_0-rmse:2.85479
# [40]	validation_0-rmse:2.77460
# [50]	validation_0-rmse:2.73390
# [60]	validation_0-rmse:2.73163
# [70]	validation_0-rmse:2.73731
# [80]	validation_0-rmse:2.74437
# [90]	validation_0-rmse:2.73907
# [100]	validation_0-rmse:2.73853
# [110]	validation_0-rmse:2.74077
# Stopping. Best iteration:
# [61]	validation_0-rmse:2.72708
#
# [CA_1] Fold2: 13.147343873977661 [sec]
# [0]	validation_0-rmse:3.19157
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.84557
# [20]	validation_0-rmse:2.77219
# [30]	validation_0-rmse:2.69431
# [40]	validation_0-rmse:2.68764
# [50]	validation_0-rmse:2.66503
# [60]	validation_0-rmse:2.67024
# [70]	validation_0-rmse:2.69023
# [80]	validation_0-rmse:2.69320
# [90]	validation_0-rmse:2.69670
# Stopping. Best iteration:
# [48]	validation_0-rmse:2.66390
#
# [CA_1] Fold3: 11.70767617225647 [sec]
# [0]	validation_0-rmse:3.45090
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.05053
# [20]	validation_0-rmse:2.96839
# [30]	validation_0-rmse:2.94629
# [40]	validation_0-rmse:2.92852
# [50]	validation_0-rmse:2.91766
# [60]	validation_0-rmse:2.91156
# [70]	validation_0-rmse:2.91361
# [80]	validation_0-rmse:2.91361
# [90]	validation_0-rmse:2.91577
# [100]	validation_0-rmse:2.90972
# [110]	validation_0-rmse:2.90320
# [120]	validation_0-rmse:2.90965
# [130]	validation_0-rmse:2.91112
# [140]	validation_0-rmse:2.92276
# [150]	validation_0-rmse:2.92359
# [160]	validation_0-rmse:2.92204
# Stopping. Best iteration:
# [117]	validation_0-rmse:2.90314
#
# [CA_1] Fold4: 13.741541862487793 [sec]
# [0]	validation_0-rmse:3.75261
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.21530
# [20]	validation_0-rmse:3.08965
# [30]	validation_0-rmse:3.14713
# [40]	validation_0-rmse:3.12708
# [50]	validation_0-rmse:3.07301
# [60]	validation_0-rmse:3.07483
# [70]	validation_0-rmse:3.07665
# Stopping. Best iteration:
# [27]	validation_0-rmse:3.02818
#
# [CA_1] Fold5: 8.964196920394897 [sec]
# [I 2020-06-26 02:25:37,380] Finished trial#1 with value: 2.8477292537689207 with parameters: {'subsample': 0.75, 'colsample_bytree': 0.65, 'max_depth': 8, 'gamma': 0.10126423306714503, 'min_child_weight': 0.41719045471175076}. Best is trial#1 with value: 2.8477292537689207.
# [0]	validation_0-rmse:3.65591
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.50106
# [20]	validation_0-rmse:3.48469
# [30]	validation_0-rmse:3.46520
# [40]	validation_0-rmse:3.46477
# [50]	validation_0-rmse:3.46525
# [60]	validation_0-rmse:3.46401
# [70]	validation_0-rmse:3.43499
# [80]	validation_0-rmse:3.42397
# [90]	validation_0-rmse:3.41211
# [100]	validation_0-rmse:3.39983
# [110]	validation_0-rmse:3.40058
# [120]	validation_0-rmse:3.38723
# [130]	validation_0-rmse:3.38343
# [140]	validation_0-rmse:3.39016
# [150]	validation_0-rmse:3.38474
# [160]	validation_0-rmse:3.37873
# [170]	validation_0-rmse:3.37439
# [180]	validation_0-rmse:3.37185
# [190]	validation_0-rmse:3.36571
# [200]	validation_0-rmse:3.36769
# [210]	validation_0-rmse:3.36615
# [220]	validation_0-rmse:3.36882
# [230]	validation_0-rmse:3.36556
# [240]	validation_0-rmse:3.36604
# [250]	validation_0-rmse:3.35997
# [260]	validation_0-rmse:3.36522
# [270]	validation_0-rmse:3.36734
# [280]	validation_0-rmse:3.37366
# [290]	validation_0-rmse:3.37391
# [300]	validation_0-rmse:3.37224
# Stopping. Best iteration:
# [254]	validation_0-rmse:3.35935
#
# [CA_1] Fold1: 13.07078504562378 [sec]
# [0]	validation_0-rmse:3.55875
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.44542
# [20]	validation_0-rmse:3.42394
# [30]	validation_0-rmse:3.36497
# [40]	validation_0-rmse:3.36487
# [50]	validation_0-rmse:3.36314
# [60]	validation_0-rmse:3.33788
# [70]	validation_0-rmse:3.29675
# [80]	validation_0-rmse:3.31137
# [90]	validation_0-rmse:3.29987
# [100]	validation_0-rmse:3.31281
# [110]	validation_0-rmse:3.31253
# [120]	validation_0-rmse:3.31081
# [130]	validation_0-rmse:3.30576
# Stopping. Best iteration:
# [84]	validation_0-rmse:3.29287
#
# [CA_1] Fold2: 9.27666187286377 [sec]
# [0]	validation_0-rmse:3.29081
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.19359
# [20]	validation_0-rmse:3.10470
# [30]	validation_0-rmse:3.00966
# [40]	validation_0-rmse:2.98687
# [50]	validation_0-rmse:2.98392
# [60]	validation_0-rmse:2.98034
# [70]	validation_0-rmse:2.97197
# [80]	validation_0-rmse:2.96746
# [90]	validation_0-rmse:2.96144
# [100]	validation_0-rmse:2.95426
# [110]	validation_0-rmse:2.94434
# [120]	validation_0-rmse:2.94280
# [130]	validation_0-rmse:2.94086
# [140]	validation_0-rmse:2.93593
# [150]	validation_0-rmse:2.92626
# [160]	validation_0-rmse:2.92936
# [170]	validation_0-rmse:2.93002
# [180]	validation_0-rmse:2.92887
# [190]	validation_0-rmse:2.92646
# [200]	validation_0-rmse:2.92471
# [210]	validation_0-rmse:2.92111
# [220]	validation_0-rmse:2.91997
# [230]	validation_0-rmse:2.92420
# [240]	validation_0-rmse:2.92502
# [250]	validation_0-rmse:2.92584
# [260]	validation_0-rmse:2.92540
# Stopping. Best iteration:
# [218]	validation_0-rmse:2.91975
#
# [CA_1] Fold3: 10.550413131713867 [sec]
# [0]	validation_0-rmse:3.55060
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.44143
# [20]	validation_0-rmse:3.41054
# [30]	validation_0-rmse:3.39325
# [40]	validation_0-rmse:3.35547
# [50]	validation_0-rmse:3.36080
# [60]	validation_0-rmse:3.35522
# [70]	validation_0-rmse:3.34895
# [80]	validation_0-rmse:3.34920
# [90]	validation_0-rmse:3.34292
# [100]	validation_0-rmse:3.33253
# [110]	validation_0-rmse:3.32840
# [120]	validation_0-rmse:3.33718
# [130]	validation_0-rmse:3.33656
# [140]	validation_0-rmse:3.34535
# [150]	validation_0-rmse:3.33270
# Stopping. Best iteration:
# [106]	validation_0-rmse:3.31863
#
# [CA_1] Fold4: 8.016284704208374 [sec]
# [0]	validation_0-rmse:3.87263
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.76504
# [20]	validation_0-rmse:3.64593
# [30]	validation_0-rmse:3.62940
# [40]	validation_0-rmse:3.65137
# [50]	validation_0-rmse:3.63611
# [60]	validation_0-rmse:3.64511
# [70]	validation_0-rmse:3.63619
# Stopping. Best iteration:
# [27]	validation_0-rmse:3.61437
#
# [CA_1] Fold5: 6.462783098220825 [sec]
# [I 2020-06-26 02:26:24,926] Finished trial#2 with value: 3.300993537902832 with parameters: {'subsample': 0.7, 'colsample_bytree': 0.95, 'max_depth': 3, 'gamma': 0.0012237520212274628, 'min_child_weight': 5.995089283534755}. Best is trial#1 with value: 2.8477292537689207.
# [0]	validation_0-rmse:3.55796
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.93080
# [20]	validation_0-rmse:2.81256
# [30]	validation_0-rmse:2.76331
# [40]	validation_0-rmse:2.83396
# [50]	validation_0-rmse:2.83392
# [60]	validation_0-rmse:2.80111
# [70]	validation_0-rmse:2.80310
# [80]	validation_0-rmse:2.80859
# Stopping. Best iteration:
# [36]	validation_0-rmse:2.74329
#
# [CA_1] Fold1: 12.559372663497925 [sec]
# [0]	validation_0-rmse:3.45941
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.85850
# [20]	validation_0-rmse:2.74128
# [30]	validation_0-rmse:2.70828
# [40]	validation_0-rmse:2.69360
# [50]	validation_0-rmse:2.70796
# [60]	validation_0-rmse:2.70330
# [70]	validation_0-rmse:2.70796
# [80]	validation_0-rmse:2.71597
# [90]	validation_0-rmse:2.71979
# Stopping. Best iteration:
# [45]	validation_0-rmse:2.68521
#
# [CA_1] Fold2: 12.14216947555542 [sec]
# [0]	validation_0-rmse:3.26719
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.69811
# [20]	validation_0-rmse:2.61519
# [30]	validation_0-rmse:2.60977
# [40]	validation_0-rmse:2.59058
# [50]	validation_0-rmse:2.59752
# [60]	validation_0-rmse:2.62034
# [70]	validation_0-rmse:2.63102
# [80]	validation_0-rmse:2.63383
# [90]	validation_0-rmse:2.63415
# Stopping. Best iteration:
# [40]	validation_0-rmse:2.59058
#
# [CA_1] Fold3: 11.226465225219727 [sec]
# [0]	validation_0-rmse:3.45501
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.89737
# [20]	validation_0-rmse:2.80085
# [30]	validation_0-rmse:2.79849
# [40]	validation_0-rmse:2.78698
# [50]	validation_0-rmse:2.81246
# [60]	validation_0-rmse:2.82588
# [70]	validation_0-rmse:2.82990
# [80]	validation_0-rmse:2.83388
# [90]	validation_0-rmse:2.84453
# Stopping. Best iteration:
# [41]	validation_0-rmse:2.78525
#
# [CA_1] Fold4: 10.251353979110718 [sec]
# [0]	validation_0-rmse:3.75275
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.17997
# [20]	validation_0-rmse:3.01857
# [30]	validation_0-rmse:2.96010
# [40]	validation_0-rmse:2.93652
# [50]	validation_0-rmse:2.94881
# [60]	validation_0-rmse:2.95027
# [70]	validation_0-rmse:2.95682
# [80]	validation_0-rmse:2.95091
# [90]	validation_0-rmse:2.95921
# Stopping. Best iteration:
# [43]	validation_0-rmse:2.93210
#
# [CA_1] Fold5: 9.45135498046875 [sec]
# [I 2020-06-26 02:27:20,728] Finished trial#3 with value: 2.7472864627838134 with parameters: {'subsample': 0.9, 'colsample_bytree': 0.8, 'max_depth': 8, 'gamma': 0.06824587435776627, 'min_child_weight': 0.2762347198535563}. Best is trial#3 with value: 2.7472864627838134.
# [0]	validation_0-rmse:3.53919
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.93312
# [20]	validation_0-rmse:2.83139
# [30]	validation_0-rmse:2.78536
# [40]	validation_0-rmse:2.75701
# [50]	validation_0-rmse:2.74958
# [60]	validation_0-rmse:2.72933
# [70]	validation_0-rmse:2.73702
# [80]	validation_0-rmse:2.74121
# [90]	validation_0-rmse:2.73540
# [100]	validation_0-rmse:2.76090
# Stopping. Best iteration:
# [57]	validation_0-rmse:2.72717
#
# [CA_1] Fold1: 11.996500730514526 [sec]
# [0]	validation_0-rmse:3.45527
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.89630
# [20]	validation_0-rmse:2.75714
# [30]	validation_0-rmse:2.76766
# [40]	validation_0-rmse:2.72542
# [50]	validation_0-rmse:2.71941
# [60]	validation_0-rmse:2.71577
# [70]	validation_0-rmse:2.71861
# [80]	validation_0-rmse:2.71541
# [90]	validation_0-rmse:2.71471
# [100]	validation_0-rmse:2.71772
# [110]	validation_0-rmse:2.71890
# [120]	validation_0-rmse:2.72242
# Stopping. Best iteration:
# [73]	validation_0-rmse:2.70872
#
# [CA_1] Fold2: 11.855543375015259 [sec]
# [0]	validation_0-rmse:3.25646
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.71020
# [20]	validation_0-rmse:2.61485
# [30]	validation_0-rmse:2.60376
# [40]	validation_0-rmse:2.59223
# [50]	validation_0-rmse:2.59437
# [60]	validation_0-rmse:2.58647
# [70]	validation_0-rmse:2.59169
# [80]	validation_0-rmse:2.59539
# [90]	validation_0-rmse:2.60340
# [100]	validation_0-rmse:2.61005
# Stopping. Best iteration:
# [57]	validation_0-rmse:2.57767
#
# [CA_1] Fold3: 10.069867849349976 [sec]
# [0]	validation_0-rmse:3.49628
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.90816
# [20]	validation_0-rmse:2.81407
# [30]	validation_0-rmse:2.92631
# [40]	validation_0-rmse:2.90925
# [50]	validation_0-rmse:2.92412
# [60]	validation_0-rmse:2.94302
# [70]	validation_0-rmse:2.96848
# Stopping. Best iteration:
# [25]	validation_0-rmse:2.81006
#
# [CA_1] Fold4: 8.492522954940796 [sec]
# [0]	validation_0-rmse:3.74610
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.19181
# [20]	validation_0-rmse:3.04677
# [30]	validation_0-rmse:2.98263
# [40]	validation_0-rmse:2.96455
# [50]	validation_0-rmse:2.96020
# [60]	validation_0-rmse:2.96978
# [70]	validation_0-rmse:2.96711
# [80]	validation_0-rmse:2.96247
# Stopping. Best iteration:
# [36]	validation_0-rmse:2.95252
#
# [CA_1] Fold5: 7.910933017730713 [sec]
# [I 2020-06-26 02:28:11,217] Finished trial#4 with value: 2.7552302837371827 with parameters: {'subsample': 0.95, 'colsample_bytree': 0.8, 'max_depth': 7, 'gamma': 2.5459289726996377e-08, 'min_child_weight': 3.018251074048458}. Best is trial#3 with value: 2.7472864627838134.
# [0]	validation_0-rmse:3.62000
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.29316
# [20]	validation_0-rmse:3.16493
# [30]	validation_0-rmse:3.05602
# [40]	validation_0-rmse:2.97544
# [50]	validation_0-rmse:2.91414
# [60]	validation_0-rmse:2.91437
# [70]	validation_0-rmse:2.90081
# [80]	validation_0-rmse:2.89107
# [90]	validation_0-rmse:2.88579
# [100]	validation_0-rmse:2.87329
# [110]	validation_0-rmse:2.86510
# [120]	validation_0-rmse:2.86691
# [130]	validation_0-rmse:2.86515
# [140]	validation_0-rmse:2.86200
# [150]	validation_0-rmse:2.86087
# [160]	validation_0-rmse:2.85986
# [170]	validation_0-rmse:2.85625
# [180]	validation_0-rmse:2.85040
# [190]	validation_0-rmse:2.85109
# [200]	validation_0-rmse:2.84535
# [210]	validation_0-rmse:2.84279
# [220]	validation_0-rmse:2.84273
# [230]	validation_0-rmse:2.83948
# [240]	validation_0-rmse:2.84022
# [250]	validation_0-rmse:2.83686
# [260]	validation_0-rmse:2.83878
# [270]	validation_0-rmse:2.84110
# [280]	validation_0-rmse:2.83974
# [290]	validation_0-rmse:2.84003
# [300]	validation_0-rmse:2.84181
# Stopping. Best iteration:
# [250]	validation_0-rmse:2.83686
#
# [CA_1] Fold1: 13.247266292572021 [sec]
# [0]	validation_0-rmse:3.52190
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.21337
# [20]	validation_0-rmse:3.09635
# [30]	validation_0-rmse:3.02324
# [40]	validation_0-rmse:2.93935
# [50]	validation_0-rmse:2.87477
# [60]	validation_0-rmse:2.85683
# [70]	validation_0-rmse:2.84498
# [80]	validation_0-rmse:2.83331
# [90]	validation_0-rmse:2.83084
# [100]	validation_0-rmse:2.82449
# [110]	validation_0-rmse:2.82920
# [120]	validation_0-rmse:2.83191
# [130]	validation_0-rmse:2.83524
# [140]	validation_0-rmse:2.83291
# Stopping. Best iteration:
# [98]	validation_0-rmse:2.82357
#
# [CA_1] Fold2: 9.615753889083862 [sec]
# [0]	validation_0-rmse:3.25937
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.02190
# [20]	validation_0-rmse:2.90579
# [30]	validation_0-rmse:2.82242
# [40]	validation_0-rmse:2.77190
# [50]	validation_0-rmse:2.73138
# [60]	validation_0-rmse:2.71633
# [70]	validation_0-rmse:2.70074
# [80]	validation_0-rmse:2.70208
# [90]	validation_0-rmse:2.69936
# [100]	validation_0-rmse:2.69942
# [110]	validation_0-rmse:2.70578
# [120]	validation_0-rmse:2.70662
# Stopping. Best iteration:
# [75]	validation_0-rmse:2.69640
#
# [CA_1] Fold3: 8.600282669067383 [sec]
# [0]	validation_0-rmse:3.51706
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.29366
# [20]	validation_0-rmse:3.17482
# [30]	validation_0-rmse:3.07753
# [40]	validation_0-rmse:3.01160
# [50]	validation_0-rmse:2.94687
# [60]	validation_0-rmse:2.92260
# [70]	validation_0-rmse:2.92169
# [80]	validation_0-rmse:2.91227
# [90]	validation_0-rmse:2.90411
# [100]	validation_0-rmse:2.90539
# [110]	validation_0-rmse:2.90582
# [120]	validation_0-rmse:2.89877
# [130]	validation_0-rmse:2.91820
# [140]	validation_0-rmse:2.92575
# [150]	validation_0-rmse:2.92763
# [160]	validation_0-rmse:2.92489
# [170]	validation_0-rmse:2.92340
# Stopping. Best iteration:
# [120]	validation_0-rmse:2.89877
#
# [CA_1] Fold4: 8.231957912445068 [sec]
# [0]	validation_0-rmse:3.83558
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.61868
# [20]	validation_0-rmse:3.42973
# [30]	validation_0-rmse:3.29152
# [40]	validation_0-rmse:3.23737
# [50]	validation_0-rmse:3.19098
# [60]	validation_0-rmse:3.18827
# [70]	validation_0-rmse:3.18545
# [80]	validation_0-rmse:3.20865
# [90]	validation_0-rmse:3.21168
# [100]	validation_0-rmse:3.23839
# [110]	validation_0-rmse:3.22974
# [120]	validation_0-rmse:3.23091
# Stopping. Best iteration:
# [76]	validation_0-rmse:3.17806
#
# [CA_1] Fold5: 6.960653305053711 [sec]
# [I 2020-06-26 02:28:58,045] Finished trial#5 with value: 2.8867347240448 with parameters: {'subsample': 0.65, 'colsample_bytree': 0.65, 'max_depth': 3, 'gamma': 1.977161370662931e-05, 'min_child_weight': 1.149641946358129}. Best is trial#3 with value: 2.7472864627838134.
# [0]	validation_0-rmse:3.57027
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.12410
# [20]	validation_0-rmse:3.00191
# [30]	validation_0-rmse:2.93247
# [40]	validation_0-rmse:2.88179
# [50]	validation_0-rmse:2.85548
# [60]	validation_0-rmse:2.83972
# [70]	validation_0-rmse:2.84172
# [80]	validation_0-rmse:2.82171
# [90]	validation_0-rmse:2.83738
# [100]	validation_0-rmse:2.83052
# [110]	validation_0-rmse:2.82450
# [120]	validation_0-rmse:2.82089
# [130]	validation_0-rmse:2.81937
# [140]	validation_0-rmse:2.83377
# [150]	validation_0-rmse:2.83551
# [160]	validation_0-rmse:2.83650
# [170]	validation_0-rmse:2.83241
# Stopping. Best iteration:
# [125]	validation_0-rmse:2.81778
#
# [CA_1] Fold1: 23.39975118637085 [sec]
# [0]	validation_0-rmse:3.46750
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.07668
# [20]	validation_0-rmse:2.91072
# [30]	validation_0-rmse:2.83036
# [40]	validation_0-rmse:2.79444
# [50]	validation_0-rmse:2.78136
# [60]	validation_0-rmse:2.78409
# [70]	validation_0-rmse:2.79547
# [80]	validation_0-rmse:2.79994
# [90]	validation_0-rmse:2.80011
# [100]	validation_0-rmse:2.80819
# Stopping. Best iteration:
# [50]	validation_0-rmse:2.78136
#
# [CA_1] Fold2: 15.701017141342163 [sec]
# [0]	validation_0-rmse:3.26950
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.87624
# [20]	validation_0-rmse:2.76375
# [30]	validation_0-rmse:2.79303
# [40]	validation_0-rmse:2.77986
# [50]	validation_0-rmse:2.75268
# [60]	validation_0-rmse:2.76886
# [70]	validation_0-rmse:2.77749
# Stopping. Best iteration:
# [25]	validation_0-rmse:2.74171
#
# [CA_1] Fold3: 12.752580165863037 [sec]
# [0]	validation_0-rmse:3.51303
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.09949
# [20]	validation_0-rmse:2.98638
# [30]	validation_0-rmse:2.92335
# [40]	validation_0-rmse:2.88293
# [50]	validation_0-rmse:2.87621
# [60]	validation_0-rmse:2.87656
# [70]	validation_0-rmse:2.88199
# [80]	validation_0-rmse:2.88375
# [90]	validation_0-rmse:2.88752
# [100]	validation_0-rmse:2.88311
# Stopping. Best iteration:
# [59]	validation_0-rmse:2.87393
#
# [CA_1] Fold4: 14.356698513031006 [sec]
# [0]	validation_0-rmse:3.76023
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.29946
# [20]	validation_0-rmse:3.18089
# [30]	validation_0-rmse:3.11926
# [40]	validation_0-rmse:3.05483
# [50]	validation_0-rmse:3.03735
# [60]	validation_0-rmse:3.04466
# [70]	validation_0-rmse:3.04138
# [80]	validation_0-rmse:3.04122
# [90]	validation_0-rmse:3.03975
# [100]	validation_0-rmse:3.04103
# Stopping. Best iteration:
# [50]	validation_0-rmse:3.03735
#
# [CA_1] Fold5: 12.490546703338623 [sec]
# [I 2020-06-26 02:30:16,912] Finished trial#6 with value: 2.8504286766052247 with parameters: {'subsample': 0.95, 'colsample_bytree': 0.7, 'max_depth': 9, 'gamma': 2.9298267227296786e-08, 'min_child_weight': 1.9264846613399864}. Best is trial#3 with value: 2.7472864627838134.
# [0]	validation_0-rmse:3.56728
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.94471
# [20]	validation_0-rmse:2.80539
# [30]	validation_0-rmse:2.77975
# [40]	validation_0-rmse:2.78101
# [50]	validation_0-rmse:2.76122
# [60]	validation_0-rmse:2.75837
# [70]	validation_0-rmse:2.76192
# [80]	validation_0-rmse:2.76457
# [90]	validation_0-rmse:2.76730
# [100]	validation_0-rmse:2.77393
# Stopping. Best iteration:
# [58]	validation_0-rmse:2.75783
#
# [CA_1] Fold1: 16.0677227973938 [sec]
# [0]	validation_0-rmse:3.46499
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.87437
# [20]	validation_0-rmse:2.75653
# [30]	validation_0-rmse:2.73095
# [40]	validation_0-rmse:2.72730
# [50]	validation_0-rmse:2.69193
# [60]	validation_0-rmse:2.69297
# [70]	validation_0-rmse:2.67922
# [80]	validation_0-rmse:2.68263
# [90]	validation_0-rmse:2.68588
# [100]	validation_0-rmse:2.68189
# [110]	validation_0-rmse:2.68425
# [120]	validation_0-rmse:2.68825
# [130]	validation_0-rmse:2.67490
# [140]	validation_0-rmse:2.67323
# [150]	validation_0-rmse:2.68397
# [160]	validation_0-rmse:2.70205
# [170]	validation_0-rmse:2.70607
# [180]	validation_0-rmse:2.70972
# [190]	validation_0-rmse:2.70686
# Stopping. Best iteration:
# [141]	validation_0-rmse:2.67027
#
# [CA_1] Fold2: 21.046027660369873 [sec]
# [0]	validation_0-rmse:3.19399
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.66448
# [20]	validation_0-rmse:2.60407
# [30]	validation_0-rmse:2.60878
# [40]	validation_0-rmse:2.75536
# [50]	validation_0-rmse:2.76783
# [60]	validation_0-rmse:2.77149
# [70]	validation_0-rmse:2.78203
# Stopping. Best iteration:
# [23]	validation_0-rmse:2.60043
#
# [CA_1] Fold3: 11.896222114562988 [sec]
# [0]	validation_0-rmse:3.45201
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.90231
# [20]	validation_0-rmse:2.79582
# [30]	validation_0-rmse:2.78199
# [40]	validation_0-rmse:2.83519
# [50]	validation_0-rmse:2.81146
# [60]	validation_0-rmse:2.82364
# [70]	validation_0-rmse:2.82842
# Stopping. Best iteration:
# [25]	validation_0-rmse:2.77189
#
# [CA_1] Fold4: 11.208799839019775 [sec]
# [0]	validation_0-rmse:3.74642
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.15357
# [20]	validation_0-rmse:3.01347
# [30]	validation_0-rmse:2.95875
# [40]	validation_0-rmse:2.92482
# [50]	validation_0-rmse:2.94382
# [60]	validation_0-rmse:2.95273
# [70]	validation_0-rmse:2.94747
# [80]	validation_0-rmse:2.94913
# [90]	validation_0-rmse:2.94863
# Stopping. Best iteration:
# [44]	validation_0-rmse:2.92053
#
# [CA_1] Fold5: 10.989871263504028 [sec]
# [I 2020-06-26 02:31:28,289] Finished trial#7 with value: 2.7441896915435793 with parameters: {'subsample': 0.7, 'colsample_bytree': 0.8, 'max_depth': 9, 'gamma': 0.005988610614565703, 'min_child_weight': 0.18546002876907908}. Best is trial#7 with value: 2.7441896915435793.
# [0]	validation_0-rmse:3.58493
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.27251
# [20]	validation_0-rmse:3.08968
# [30]	validation_0-rmse:2.95408
# [40]	validation_0-rmse:2.86924
# [50]	validation_0-rmse:2.83534
# [60]	validation_0-rmse:2.84719
# [70]	validation_0-rmse:2.83664
# [80]	validation_0-rmse:2.83569
# [90]	validation_0-rmse:2.83347
# [100]	validation_0-rmse:2.83301
# [110]	validation_0-rmse:2.90513
# [120]	validation_0-rmse:2.90028
# Stopping. Best iteration:
# [75]	validation_0-rmse:2.82215
#
# [CA_1] Fold1: 10.25098705291748 [sec]
# [0]	validation_0-rmse:3.48958
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.19218
# [20]	validation_0-rmse:3.02849
# [30]	validation_0-rmse:2.88264
# [40]	validation_0-rmse:2.82457
# [50]	validation_0-rmse:2.79166
# [60]	validation_0-rmse:2.77985
# [70]	validation_0-rmse:2.76939
# [80]	validation_0-rmse:2.77456
# [90]	validation_0-rmse:2.77800
# [100]	validation_0-rmse:2.83432
# [110]	validation_0-rmse:2.86351
# [120]	validation_0-rmse:2.86075
# Stopping. Best iteration:
# [75]	validation_0-rmse:2.76828
#
# [CA_1] Fold2: 9.504338026046753 [sec]
# [0]	validation_0-rmse:3.24171
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.94537
# [20]	validation_0-rmse:2.79506
# [30]	validation_0-rmse:2.65314
# [40]	validation_0-rmse:2.60219
# [50]	validation_0-rmse:2.59378
# [60]	validation_0-rmse:2.60197
# [70]	validation_0-rmse:2.64454
# [80]	validation_0-rmse:2.65620
# [90]	validation_0-rmse:2.66355
# [100]	validation_0-rmse:2.67391
# Stopping. Best iteration:
# [50]	validation_0-rmse:2.59378
#
# [CA_1] Fold3: 8.433314800262451 [sec]
# [0]	validation_0-rmse:3.47723
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.18199
# [20]	validation_0-rmse:3.03216
# [30]	validation_0-rmse:2.90857
# [40]	validation_0-rmse:2.83071
# [50]	validation_0-rmse:2.80737
# [60]	validation_0-rmse:2.80042
# [70]	validation_0-rmse:2.81715
# [80]	validation_0-rmse:2.82610
# [90]	validation_0-rmse:2.83399
# [100]	validation_0-rmse:2.85580
# [110]	validation_0-rmse:3.38892
# Stopping. Best iteration:
# [64]	validation_0-rmse:2.79107
#
# [CA_1] Fold4: 7.820188999176025 [sec]
# [0]	validation_0-rmse:3.78818
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.52121
# [20]	validation_0-rmse:3.32939
# [30]	validation_0-rmse:3.15179
# [40]	validation_0-rmse:3.08568
# [50]	validation_0-rmse:3.03921
# [60]	validation_0-rmse:3.00637
# [70]	validation_0-rmse:2.95229
# [80]	validation_0-rmse:2.95552
# [90]	validation_0-rmse:2.95220
# [100]	validation_0-rmse:2.97372
# [110]	validation_0-rmse:3.36177
# Stopping. Best iteration:
# [64]	validation_0-rmse:2.94093
#
# [CA_1] Fold5: 7.0589306354522705 [sec]
# [I 2020-06-26 02:32:11,527] Finished trial#8 with value: 2.783242034912109 with parameters: {'subsample': 0.9, 'colsample_bytree': 0.65, 'max_depth': 4, 'gamma': 5.617579233970938e-08, 'min_child_weight': 0.45081730874181825}. Best is trial#7 with value: 2.7441896915435793.
# [0]	validation_0-rmse:3.54104
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.15851
# [20]	validation_0-rmse:3.00215
# [30]	validation_0-rmse:3.01611
# [40]	validation_0-rmse:2.95503
# [50]	validation_0-rmse:2.90605
# [60]	validation_0-rmse:2.90763
# [70]	validation_0-rmse:2.95615
# [80]	validation_0-rmse:2.95657
# [90]	validation_0-rmse:2.96374
# [100]	validation_0-rmse:2.96188
# Stopping. Best iteration:
# [50]	validation_0-rmse:2.90605
#
# [CA_1] Fold1: 11.597128629684448 [sec]
# [0]	validation_0-rmse:3.45287
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.06526
# [20]	validation_0-rmse:2.93461
# [30]	validation_0-rmse:2.83076
# [40]	validation_0-rmse:2.76583
# [50]	validation_0-rmse:2.74895
# [60]	validation_0-rmse:2.75404
# [70]	validation_0-rmse:2.76992
# [80]	validation_0-rmse:2.77419
# [90]	validation_0-rmse:2.77283
# [100]	validation_0-rmse:2.77646
# Stopping. Best iteration:
# [50]	validation_0-rmse:2.74895
#
# [CA_1] Fold2: 10.814399242401123 [sec]
# [0]	validation_0-rmse:3.18838
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.84956
# [20]	validation_0-rmse:2.75501
# [30]	validation_0-rmse:2.65074
# [40]	validation_0-rmse:2.65586
# [50]	validation_0-rmse:2.71083
# [60]	validation_0-rmse:2.72742
# [70]	validation_0-rmse:2.74128
# Stopping. Best iteration:
# [28]	validation_0-rmse:2.64488
#
# [CA_1] Fold3: 9.445503950119019 [sec]
# [0]	validation_0-rmse:3.44340
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.06539
# [20]	validation_0-rmse:2.96201
# [30]	validation_0-rmse:2.93920
# [40]	validation_0-rmse:2.95578
# [50]	validation_0-rmse:2.94108
# [60]	validation_0-rmse:2.94748
# [70]	validation_0-rmse:2.95421
# Stopping. Best iteration:
# [27]	validation_0-rmse:2.92811
#
# [CA_1] Fold4: 8.61991024017334 [sec]
# [0]	validation_0-rmse:3.74870
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.32439
# [20]	validation_0-rmse:3.15433
# [30]	validation_0-rmse:3.06182
# [40]	validation_0-rmse:2.99832
# [50]	validation_0-rmse:2.96491
# [60]	validation_0-rmse:2.96298
# [70]	validation_0-rmse:2.96942
# [80]	validation_0-rmse:2.97018
# [90]	validation_0-rmse:2.97684
# [100]	validation_0-rmse:2.97926
# [110]	validation_0-rmse:2.97747
# Stopping. Best iteration:
# [60]	validation_0-rmse:2.96298
#
# [CA_1] Fold5: 8.559445142745972 [sec]
# [I 2020-06-26 02:33:00,727] Finished trial#9 with value: 2.8381920337677 with parameters: {'subsample': 0.75, 'colsample_bytree': 0.75, 'max_depth': 7, 'gamma': 0.004059441398123775, 'min_child_weight': 1.9151138049240795}. Best is trial#7 with value: 2.7441896915435793.
# [0]	validation_0-rmse:3.56533
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.12163
# [20]	validation_0-rmse:3.01515
# [30]	validation_0-rmse:3.02029
# [40]	validation_0-rmse:3.13395
# [50]	validation_0-rmse:3.11880
# [60]	validation_0-rmse:3.11684
# [70]	validation_0-rmse:3.11362
# Stopping. Best iteration:
# [26]	validation_0-rmse:2.99273
#
# [CA_1] Fold1: 9.321884632110596 [sec]
# [0]	validation_0-rmse:3.45364
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.06023
# [20]	validation_0-rmse:3.00285
# [30]	validation_0-rmse:2.98948
# [40]	validation_0-rmse:3.30564
# [50]	validation_0-rmse:3.29034
# [60]	validation_0-rmse:3.29651
# [70]	validation_0-rmse:3.30032
# Stopping. Best iteration:
# [27]	validation_0-rmse:2.96869
#
# [CA_1] Fold2: 8.798340559005737 [sec]
# [0]	validation_0-rmse:3.21471
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.85792
# [20]	validation_0-rmse:2.81571
# [30]	validation_0-rmse:2.79596
# [40]	validation_0-rmse:2.78549
# [50]	validation_0-rmse:2.78584
# [60]	validation_0-rmse:2.76770
# [70]	validation_0-rmse:2.76849
# [80]	validation_0-rmse:2.77243
# [90]	validation_0-rmse:2.78669
# [100]	validation_0-rmse:2.78740
# [110]	validation_0-rmse:2.79348
# Stopping. Best iteration:
# [64]	validation_0-rmse:2.76549
#
# [CA_1] Fold3: 8.927304983139038 [sec]
# [0]	validation_0-rmse:3.46817
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.07027
# [20]	validation_0-rmse:3.02428
# [30]	validation_0-rmse:3.01436
# [40]	validation_0-rmse:3.00709
# [50]	validation_0-rmse:2.99935
# [60]	validation_0-rmse:2.99197
# [70]	validation_0-rmse:3.00116
# [80]	validation_0-rmse:3.00598
# [90]	validation_0-rmse:3.02157
# [100]	validation_0-rmse:3.02173
# [110]	validation_0-rmse:3.03314
# Stopping. Best iteration:
# [61]	validation_0-rmse:2.99142
#
# [CA_1] Fold4: 7.969293594360352 [sec]
# [0]	validation_0-rmse:3.78105
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.39246
# [20]	validation_0-rmse:3.26385
# [30]	validation_0-rmse:3.22415
# [40]	validation_0-rmse:3.23416
# [50]	validation_0-rmse:3.22476
# [60]	validation_0-rmse:3.20970
# [70]	validation_0-rmse:3.17429
# [80]	validation_0-rmse:3.16791
# [90]	validation_0-rmse:3.16104
# [100]	validation_0-rmse:3.13822
# [110]	validation_0-rmse:3.12472
# [120]	validation_0-rmse:3.11399
# [130]	validation_0-rmse:3.10410
# [140]	validation_0-rmse:3.10664
# [150]	validation_0-rmse:3.10546
# [160]	validation_0-rmse:3.11314
# [170]	validation_0-rmse:3.11758
# Stopping. Best iteration:
# [129]	validation_0-rmse:3.10389
#
# [CA_1] Fold5: 8.151654243469238 [sec]
# [I 2020-06-26 02:33:44,084] Finished trial#10 with value: 2.9644431591033937 with parameters: {'subsample': 0.85, 'colsample_bytree': 0.9, 'max_depth': 5, 'gamma': 1.696546309039217e-05, 'min_child_weight': 0.10750412249238124}. Best is trial#7 with value: 2.7441896915435793.
# [0]	validation_0-rmse:3.56820
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.02156
# [20]	validation_0-rmse:2.86612
# [30]	validation_0-rmse:2.80657
# [40]	validation_0-rmse:2.78265
# [50]	validation_0-rmse:2.76855
# [60]	validation_0-rmse:2.76452
# [70]	validation_0-rmse:2.76612
# [80]	validation_0-rmse:2.77057
# [90]	validation_0-rmse:2.77820
# [100]	validation_0-rmse:2.78682
# [110]	validation_0-rmse:2.78812
# Stopping. Best iteration:
# [68]	validation_0-rmse:2.76094
#
# [CA_1] Fold1: 17.10279107093811 [sec]
# [0]	validation_0-rmse:3.46373
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.97427
# [20]	validation_0-rmse:2.83303
# [30]	validation_0-rmse:2.77879
# [40]	validation_0-rmse:2.76051
# [50]	validation_0-rmse:2.75739
# [60]	validation_0-rmse:2.74977
# [70]	validation_0-rmse:2.75061
# [80]	validation_0-rmse:2.75641
# [90]	validation_0-rmse:2.75873
# [100]	validation_0-rmse:2.75599
# [110]	validation_0-rmse:2.75517
# Stopping. Best iteration:
# [64]	validation_0-rmse:2.74713
#
# [CA_1] Fold2: 15.304141283035278 [sec]
# [0]	validation_0-rmse:3.19998
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.72781
# [20]	validation_0-rmse:2.66876
# [30]	validation_0-rmse:2.65926
# [40]	validation_0-rmse:2.68380
# [50]	validation_0-rmse:2.69447
# [60]	validation_0-rmse:2.69823
# [70]	validation_0-rmse:2.70046
# Stopping. Best iteration:
# [28]	validation_0-rmse:2.65778
#
# [CA_1] Fold3: 12.380769491195679 [sec]
# [0]	validation_0-rmse:3.46086
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.96031
# [20]	validation_0-rmse:2.87640
# [30]	validation_0-rmse:2.85534
# [40]	validation_0-rmse:2.80377
# [50]	validation_0-rmse:2.84847
# [60]	validation_0-rmse:2.84861
# [70]	validation_0-rmse:2.85532
# [80]	validation_0-rmse:2.85200
# [90]	validation_0-rmse:2.85187
# Stopping. Best iteration:
# [45]	validation_0-rmse:2.80221
#
# [CA_1] Fold4: 12.380508422851562 [sec]
# [0]	validation_0-rmse:3.75135
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.27337
# [20]	validation_0-rmse:3.13294
# [30]	validation_0-rmse:3.07018
# [40]	validation_0-rmse:3.03054
# [50]	validation_0-rmse:3.02302
# [60]	validation_0-rmse:3.01507
# [70]	validation_0-rmse:3.01184
# [80]	validation_0-rmse:2.99685
# [90]	validation_0-rmse:2.99633
# [100]	validation_0-rmse:2.99225
# [110]	validation_0-rmse:2.98794
# [120]	validation_0-rmse:2.98804
# [130]	validation_0-rmse:2.99097
# [140]	validation_0-rmse:2.99284
# [150]	validation_0-rmse:2.99503
# Stopping. Best iteration:
# [108]	validation_0-rmse:2.98757
#
# [CA_1] Fold5: 13.843502759933472 [sec]
# [I 2020-06-26 02:34:55,265] Finished trial#11 with value: 2.7911256313323975 with parameters: {'subsample': 0.85, 'colsample_bytree': 0.85, 'max_depth': 9, 'gamma': 0.46348028158627974, 'min_child_weight': 0.1046014198492666}. Best is trial#7 with value: 2.7441896915435793.
# [0]	validation_0-rmse:3.55780
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.00637
# [20]	validation_0-rmse:2.85996
# [30]	validation_0-rmse:2.80103
# [40]	validation_0-rmse:2.73311
# [50]	validation_0-rmse:2.77953
# [60]	validation_0-rmse:2.78185
# [70]	validation_0-rmse:2.78779
# [80]	validation_0-rmse:2.79082
# [90]	validation_0-rmse:2.79322
# Stopping. Best iteration:
# [45]	validation_0-rmse:2.72450
#
# [CA_1] Fold1: 12.74084186553955 [sec]
# [0]	validation_0-rmse:3.45899
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.92863
# [20]	validation_0-rmse:2.79315
# [30]	validation_0-rmse:2.75541
# [40]	validation_0-rmse:2.87618
# [50]	validation_0-rmse:2.86220
# [60]	validation_0-rmse:2.89059
# [70]	validation_0-rmse:2.89330
# [80]	validation_0-rmse:2.89616
# Stopping. Best iteration:
# [35]	validation_0-rmse:2.74884
#
# [CA_1] Fold2: 11.406940460205078 [sec]
# [0]	validation_0-rmse:3.19507
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.74615
# [20]	validation_0-rmse:2.65032
# [30]	validation_0-rmse:2.63064
# [40]	validation_0-rmse:2.72133
# [50]	validation_0-rmse:2.72471
# [60]	validation_0-rmse:2.72278
# [70]	validation_0-rmse:2.72777
# [80]	validation_0-rmse:2.73716
# Stopping. Best iteration:
# [30]	validation_0-rmse:2.63064
#
# [CA_1] Fold3: 10.576685905456543 [sec]
# [0]	validation_0-rmse:3.45468
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.93761
# [20]	validation_0-rmse:2.84288
# [30]	validation_0-rmse:2.82308
# [40]	validation_0-rmse:2.82331
# [50]	validation_0-rmse:2.81970
# [60]	validation_0-rmse:2.82444
# [70]	validation_0-rmse:2.82342
# [80]	validation_0-rmse:2.82389
# [90]	validation_0-rmse:2.83104
# [100]	validation_0-rmse:2.83453
# Stopping. Best iteration:
# [57]	validation_0-rmse:2.81521
#
# [CA_1] Fold4: 10.833945274353027 [sec]
# [0]	validation_0-rmse:3.75002
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.25508
# [20]	validation_0-rmse:3.10087
# [30]	validation_0-rmse:3.03798
# [40]	validation_0-rmse:3.01836
# [50]	validation_0-rmse:3.03830
# [60]	validation_0-rmse:3.04528
# [70]	validation_0-rmse:3.03892
# [80]	validation_0-rmse:3.03501
# [90]	validation_0-rmse:3.03508
# Stopping. Best iteration:
# [44]	validation_0-rmse:3.01018
#
# [CA_1] Fold5: 9.329548358917236 [sec]
# [I 2020-06-26 02:35:50,325] Finished trial#12 with value: 2.785873365402222 with parameters: {'subsample': 0.8, 'colsample_bytree': 0.85, 'max_depth': 8, 'gamma': 0.0763383250001573, 'min_child_weight': 0.25729327782516004}. Best is trial#7 with value: 2.7441896915435793.
# [0]	validation_0-rmse:3.56322
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.96509
# [20]	validation_0-rmse:2.80194
# [30]	validation_0-rmse:2.76244
# [40]	validation_0-rmse:2.85731
# [50]	validation_0-rmse:2.83878
# [60]	validation_0-rmse:2.83552
# [70]	validation_0-rmse:2.83497
# [80]	validation_0-rmse:2.83300
# Stopping. Best iteration:
# [36]	validation_0-rmse:2.74448
#
# [CA_1] Fold1: 14.409322023391724 [sec]
# [0]	validation_0-rmse:3.47221
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.90233
# [20]	validation_0-rmse:2.76189
# [30]	validation_0-rmse:2.72845
# [40]	validation_0-rmse:2.71766
# [50]	validation_0-rmse:2.71022
# [60]	validation_0-rmse:2.70798
# [70]	validation_0-rmse:2.71206
# [80]	validation_0-rmse:2.71586
# [90]	validation_0-rmse:2.71970
# [100]	validation_0-rmse:2.71559
# [110]	validation_0-rmse:2.71829
# Stopping. Best iteration:
# [61]	validation_0-rmse:2.70602
#
# [CA_1] Fold2: 14.683600902557373 [sec]
# [0]	validation_0-rmse:3.20167
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.67276
# [20]	validation_0-rmse:2.61158
# [30]	validation_0-rmse:2.62735
# [40]	validation_0-rmse:2.64002
# [50]	validation_0-rmse:2.65702
# [60]	validation_0-rmse:2.66542
# [70]	validation_0-rmse:2.67433
# Stopping. Best iteration:
# [22]	validation_0-rmse:2.61045
#
# [CA_1] Fold3: 11.806183576583862 [sec]
# [0]	validation_0-rmse:3.45182
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.88978
# [20]	validation_0-rmse:2.78287
# [30]	validation_0-rmse:2.77580
# [40]	validation_0-rmse:2.77421
# [50]	validation_0-rmse:2.81786
# [60]	validation_0-rmse:2.84466
# [70]	validation_0-rmse:2.84631
# Stopping. Best iteration:
# [25]	validation_0-rmse:2.76721
#
# [CA_1] Fold4: 11.05324411392212 [sec]
# [0]	validation_0-rmse:3.74951
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.16045
# [20]	validation_0-rmse:3.00116
# [30]	validation_0-rmse:2.95780
# [40]	validation_0-rmse:2.92717
# [50]	validation_0-rmse:2.92902
# [60]	validation_0-rmse:2.93041
# [70]	validation_0-rmse:2.92887
# [80]	validation_0-rmse:2.93415
# [90]	validation_0-rmse:2.92957
# Stopping. Best iteration:
# [43]	validation_0-rmse:2.92176
#
# [CA_1] Fold5: 10.672221422195435 [sec]
# [I 2020-06-26 02:36:53,122] Finished trial#13 with value: 2.749981927871704 with parameters: {'subsample': 0.65, 'colsample_bytree': 0.8, 'max_depth': 9, 'gamma': 0.00039869042492891193, 'min_child_weight': 0.20555117063960102}. Best is trial#7 with value: 2.7441896915435793.
# [0]	validation_0-rmse:3.56254
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.99817
# [20]	validation_0-rmse:2.84043
# [30]	validation_0-rmse:2.77821
# [40]	validation_0-rmse:2.73360
# [50]	validation_0-rmse:2.73358
# [60]	validation_0-rmse:2.73802
# [70]	validation_0-rmse:2.74163
# [80]	validation_0-rmse:2.74686
# [90]	validation_0-rmse:2.75152
# Stopping. Best iteration:
# [48]	validation_0-rmse:2.73132
#
# [CA_1] Fold1: 12.70985460281372 [sec]
# [0]	validation_0-rmse:3.45969
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.91167
# [20]	validation_0-rmse:2.78073
# [30]	validation_0-rmse:2.74508
# [40]	validation_0-rmse:2.85511
# [50]	validation_0-rmse:2.84819
# [60]	validation_0-rmse:2.86153
# [70]	validation_0-rmse:2.86780
# [80]	validation_0-rmse:2.86875
# Stopping. Best iteration:
# [36]	validation_0-rmse:2.73511
#
# [CA_1] Fold2: 11.448423385620117 [sec]
# [0]	validation_0-rmse:3.18880
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.71917
# [20]	validation_0-rmse:2.64658
# [30]	validation_0-rmse:2.63327
# [40]	validation_0-rmse:2.63940
# [50]	validation_0-rmse:2.64113
# [60]	validation_0-rmse:2.64864
# [70]	validation_0-rmse:2.65148
# [80]	validation_0-rmse:2.65400
# Stopping. Best iteration:
# [31]	validation_0-rmse:2.63281
#
# [CA_1] Fold3: 10.51465392112732 [sec]
# [0]	validation_0-rmse:3.44595
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.93238
# [20]	validation_0-rmse:2.81589
# [30]	validation_0-rmse:2.78940
# [40]	validation_0-rmse:2.79780
# [50]	validation_0-rmse:2.79474
# [60]	validation_0-rmse:2.79582
# [70]	validation_0-rmse:2.79540
# [80]	validation_0-rmse:2.79335
# Stopping. Best iteration:
# [32]	validation_0-rmse:2.78906
#
# [CA_1] Fold4: 9.699655771255493 [sec]
# [0]	validation_0-rmse:3.74497
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.25248
# [20]	validation_0-rmse:3.04889
# [30]	validation_0-rmse:2.96039
# [40]	validation_0-rmse:2.93781
# [50]	validation_0-rmse:2.92178
# [60]	validation_0-rmse:2.91560
# [70]	validation_0-rmse:2.91389
# [80]	validation_0-rmse:2.89950
# [90]	validation_0-rmse:2.90642
# [100]	validation_0-rmse:2.90556
# [110]	validation_0-rmse:2.90213
# [120]	validation_0-rmse:2.89843
# Stopping. Best iteration:
# [78]	validation_0-rmse:2.89814
#
# [CA_1] Fold5: 10.295160055160522 [sec]
# [I 2020-06-26 02:37:47,966] Finished trial#14 with value: 2.757289457321167 with parameters: {'subsample': 0.7, 'colsample_bytree': 0.85, 'max_depth': 8, 'gamma': 0.5249071793251072, 'min_child_weight': 0.18506477606857807}. Best is trial#7 with value: 2.7441896915435793.
# [0]	validation_0-rmse:3.56546
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:3.03650
# [20]	validation_0-rmse:2.93402
# [30]	validation_0-rmse:2.88558
# [40]	validation_0-rmse:2.84456
# [50]	validation_0-rmse:2.83653
# [60]	validation_0-rmse:2.83322
# [70]	validation_0-rmse:2.81277
# [80]	validation_0-rmse:2.80677
# [90]	validation_0-rmse:2.80849
# [100]	validation_0-rmse:2.81235
# [110]	validation_0-rmse:2.80686
# [120]	validation_0-rmse:2.81306
# Stopping. Best iteration:
# [75]	validation_0-rmse:2.80483
#
# [CA_1] Fold1: 11.095033168792725 [sec]
# [0]	validation_0-rmse:3.46852
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.95858
# [20]	validation_0-rmse:2.92147
# [30]	validation_0-rmse:2.90817
# [40]	validation_0-rmse:2.89130
# [50]	validation_0-rmse:2.86265
# [60]	validation_0-rmse:2.86818
# [70]	validation_0-rmse:2.87568
# [80]	validation_0-rmse:2.87587
# [90]	validation_0-rmse:2.86736
# [100]	validation_0-rmse:2.86875
# [110]	validation_0-rmse:2.85924
# [120]	validation_0-rmse:2.84067
# [130]	validation_0-rmse:2.82800
# [140]	validation_0-rmse:2.82684
# [150]	validation_0-rmse:2.83031
# [160]	validation_0-rmse:2.82601
# [170]	validation_0-rmse:2.82125
# [180]	validation_0-rmse:2.83053
# [190]	validation_0-rmse:2.83339
# [200]	validation_0-rmse:2.84155
# [210]	validation_0-rmse:2.84248
# [220]	validation_0-rmse:2.84401
# Stopping. Best iteration:
# [170]	validation_0-rmse:2.82125
#
# [CA_1] Fold2: 12.719563722610474 [sec]
# [0]	validation_0-rmse:3.19801
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.73770
# [20]	validation_0-rmse:2.69906
# [30]	validation_0-rmse:2.67463
# [40]	validation_0-rmse:2.66635
# [50]	validation_0-rmse:2.66102
# [60]	validation_0-rmse:2.66455
# [70]	validation_0-rmse:2.66619
# [80]	validation_0-rmse:2.66784
# [90]	validation_0-rmse:2.67315
# [100]	validation_0-rmse:2.67082
# Stopping. Best iteration:
# [52]	validation_0-rmse:2.65941
#
# [CA_1] Fold3: 9.156984567642212 [sec]
# [0]	validation_0-rmse:3.44976
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.98705
# [20]	validation_0-rmse:2.93224
# [30]	validation_0-rmse:2.89112
# [40]	validation_0-rmse:2.88053
# [50]	validation_0-rmse:2.87867
# ...
# [0]	validation_0-rmse:3.00811
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.58756
# [20]	validation_0-rmse:2.42015
# [30]	validation_0-rmse:2.37532
# [40]	validation_0-rmse:2.37739
# [50]	validation_0-rmse:2.36899
# [60]	validation_0-rmse:2.40921
# [70]	validation_0-rmse:2.41856
# [80]	validation_0-rmse:2.41337
# Stopping. Best iteration:
# [36]	validation_0-rmse:2.36449
#
# [TX_1] Fold1: 10.22133469581604 [sec]
# [0]	validation_0-rmse:2.92489
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.51961
# [20]	validation_0-rmse:2.39423
# [30]	validation_0-rmse:2.43472
# [40]	validation_0-rmse:2.41602
# [50]	validation_0-rmse:2.40402
# [60]	validation_0-rmse:2.41220
# [70]	validation_0-rmse:2.42667
# Stopping. Best iteration:
# [25]	validation_0-rmse:2.36255
#
# [TX_1] Fold2: 9.127062559127808 [sec]
# [0]	validation_0-rmse:2.66373
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.34535
# [20]	validation_0-rmse:2.28217
# [30]	validation_0-rmse:2.26700
# [40]	validation_0-rmse:2.26398
# [50]	validation_0-rmse:2.27066
# [60]	validation_0-rmse:2.35904
# [70]	validation_0-rmse:2.35278
# Stopping. Best iteration:
# [27]	validation_0-rmse:2.24005
#
# [TX_1] Fold3: 8.600911617279053 [sec]
# [0]	validation_0-rmse:2.70310
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.36212
# [20]	validation_0-rmse:2.27918
# [30]	validation_0-rmse:2.24369
# [40]	validation_0-rmse:2.23512
# [50]	validation_0-rmse:2.24428
# [60]	validation_0-rmse:2.29283
# [70]	validation_0-rmse:2.29608
# [80]	validation_0-rmse:2.30163
# Stopping. Best iteration:
# [35]	validation_0-rmse:2.23409
#
# [TX_1] Fold4: 8.046009063720703 [sec]
# [0]	validation_0-rmse:2.85938
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.45099
# [20]	validation_0-rmse:2.35190
# [30]	validation_0-rmse:2.30040
# [40]	validation_0-rmse:2.31288
# [50]	validation_0-rmse:2.31693
# [60]	validation_0-rmse:2.32349
# [70]	validation_0-rmse:2.31977
# [80]	validation_0-rmse:2.32884
# Stopping. Best iteration:
# [36]	validation_0-rmse:2.29381
#
# [TX_1] Fold5: 7.2850501537323 [sec]
# [I 2020-06-26 06:57:59,740] Finished trial#64 with value: 2.2989974498748778 with parameters: {'subsample': 0.65, 'colsample_bytree': 0.8, 'max_depth': 6, 'gamma': 0.010667764059089774, 'min_child_weight': 0.2824963236089183}. Best is trial#11 with value: 2.254919099807739.
# [0]	validation_0-rmse:3.00862
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.71909
# [20]	validation_0-rmse:2.59946
# [30]	validation_0-rmse:2.49298
# [40]	validation_0-rmse:2.45223
# [50]	validation_0-rmse:2.45178
# [60]	validation_0-rmse:2.44660
# [70]	validation_0-rmse:2.44482
# [80]	validation_0-rmse:2.44662
# [90]	validation_0-rmse:2.45303
# Stopping. Best iteration:
# [44]	validation_0-rmse:2.44036
#
# [TX_1] Fold1: 11.33847689628601 [sec]
# [0]	validation_0-rmse:2.92407
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.66389
# [20]	validation_0-rmse:2.55488
# [30]	validation_0-rmse:2.48815
# [40]	validation_0-rmse:2.46465
# [50]	validation_0-rmse:2.43421
# [60]	validation_0-rmse:2.44558
# [70]	validation_0-rmse:2.44740
# [80]	validation_0-rmse:2.44647
# [90]	validation_0-rmse:2.45917
# [100]	validation_0-rmse:2.44420
# Stopping. Best iteration:
# [51]	validation_0-rmse:2.43377
#
# [TX_1] Fold2: 10.713835954666138 [sec]
# [0]	validation_0-rmse:2.65921
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.45176
# [20]	validation_0-rmse:2.36541
# [30]	validation_0-rmse:2.30803
# [40]	validation_0-rmse:2.29441
# [50]	validation_0-rmse:2.29907
# [60]	validation_0-rmse:2.30371
# [70]	validation_0-rmse:2.30984
# [80]	validation_0-rmse:2.30774
# [90]	validation_0-rmse:2.31120
# Stopping. Best iteration:
# [45]	validation_0-rmse:2.28918
#
# [TX_1] Fold3: 9.809903383255005 [sec]
# [0]	validation_0-rmse:2.69949
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.47443
# [20]	validation_0-rmse:2.37388
# [30]	validation_0-rmse:2.29860
# [40]	validation_0-rmse:2.27063
# [50]	validation_0-rmse:2.25201
# [60]	validation_0-rmse:2.25576
# [70]	validation_0-rmse:2.26592
# [80]	validation_0-rmse:2.27298
# [90]	validation_0-rmse:2.27736
# Stopping. Best iteration:
# [49]	validation_0-rmse:2.25145
#
# [TX_1] Fold4: 9.120097160339355 [sec]
# [0]	validation_0-rmse:2.86147
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.61257
# [20]	validation_0-rmse:2.50131
# [30]	validation_0-rmse:2.44814
# [40]	validation_0-rmse:2.43983
# [50]	validation_0-rmse:2.43462
# [60]	validation_0-rmse:2.43514
# [70]	validation_0-rmse:2.47202
# [80]	validation_0-rmse:2.48082
# [90]	validation_0-rmse:2.48575
# Stopping. Best iteration:
# [47]	validation_0-rmse:2.43190
#
# [TX_1] Fold5: 8.290432691574097 [sec]
# [I 2020-06-26 06:58:49,192] Finished trial#65 with value: 2.3693344593048096 with parameters: {'subsample': 0.7, 'colsample_bytree': 0.75, 'max_depth': 7, 'gamma': 0.0002531461625841007, 'min_child_weight': 0.5507591670115787}. Best is trial#11 with value: 2.254919099807739.
# [0]	validation_0-rmse:3.00962
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.72519
# [20]	validation_0-rmse:2.53508
# [30]	validation_0-rmse:2.47276
# [40]	validation_0-rmse:2.42986
# [50]	validation_0-rmse:2.42135
# [60]	validation_0-rmse:2.41790
# [70]	validation_0-rmse:2.42738
# [80]	validation_0-rmse:2.43517
# [90]	validation_0-rmse:2.43562
# [100]	validation_0-rmse:2.43396
# Stopping. Best iteration:
# [56]	validation_0-rmse:2.41604
#
# [TX_1] Fold1: 11.86098337173462 [sec]
# [0]	validation_0-rmse:2.92273
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.66531
# [20]	validation_0-rmse:2.52871
# [30]	validation_0-rmse:2.45274
# [40]	validation_0-rmse:2.42916
# [50]	validation_0-rmse:2.40798
# [60]	validation_0-rmse:2.40258
# [70]	validation_0-rmse:2.40401
# [80]	validation_0-rmse:2.40132
# [90]	validation_0-rmse:2.40457
# [100]	validation_0-rmse:2.41178
# [110]	validation_0-rmse:2.39613
# [120]	validation_0-rmse:2.39985
# [130]	validation_0-rmse:2.40112
# [140]	validation_0-rmse:2.40578
# [150]	validation_0-rmse:2.40728
# [160]	validation_0-rmse:2.40819
# Stopping. Best iteration:
# [111]	validation_0-rmse:2.39597
#
# [TX_1] Fold2: 12.52210521697998 [sec]
# [0]	validation_0-rmse:2.66328
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.45908
# [20]	validation_0-rmse:2.34779
# [30]	validation_0-rmse:2.40676
# [40]	validation_0-rmse:2.47020
# [50]	validation_0-rmse:2.46265
# [60]	validation_0-rmse:2.47118
# [70]	validation_0-rmse:2.48843
# Stopping. Best iteration:
# [25]	validation_0-rmse:2.31084
#
# [TX_1] Fold3: 9.258867502212524 [sec]
# [0]	validation_0-rmse:2.70009
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.48177
# [20]	validation_0-rmse:2.37794
# [30]	validation_0-rmse:2.28881
# [40]	validation_0-rmse:2.25215
# [50]	validation_0-rmse:2.24975
# [60]	validation_0-rmse:2.25410
# [70]	validation_0-rmse:2.25678
# [80]	validation_0-rmse:2.25487
# [90]	validation_0-rmse:2.25969
# Stopping. Best iteration:
# [45]	validation_0-rmse:2.24257
#
# [TX_1] Fold4: 8.987255573272705 [sec]
# [0]	validation_0-rmse:2.85853
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.61813
# [20]	validation_0-rmse:2.50259
# [30]	validation_0-rmse:2.61523
# [40]	validation_0-rmse:2.57203
# [50]	validation_0-rmse:2.54784
# [60]	validation_0-rmse:2.54896
# [70]	validation_0-rmse:2.55511
# Stopping. Best iteration:
# [25]	validation_0-rmse:2.46688
#
# [TX_1] Fold5: 7.684554100036621 [sec]
# [I 2020-06-26 06:59:39,685] Finished trial#66 with value: 2.3664608001708984 with parameters: {'subsample': 0.6, 'colsample_bytree': 0.75, 'max_depth': 7, 'gamma': 0.028633304556825848, 'min_child_weight': 0.3194258125885254}. Best is trial#11 with value: 2.254919099807739.
# [0]	validation_0-rmse:3.06502
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.78957
# [20]	validation_0-rmse:2.63056
# [30]	validation_0-rmse:2.73591
# [40]	validation_0-rmse:2.72410
# [50]	validation_0-rmse:2.71072
# [60]	validation_0-rmse:2.70007
# [70]	validation_0-rmse:2.67132
# Stopping. Best iteration:
# [26]	validation_0-rmse:2.59130
#
# [TX_1] Fold1: 9.198582649230957 [sec]
# [0]	validation_0-rmse:2.97396
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.70185
# [20]	validation_0-rmse:2.54105
# [30]	validation_0-rmse:2.56982
# [40]	validation_0-rmse:2.56496
# [50]	validation_0-rmse:2.58541
# [60]	validation_0-rmse:2.59116
# [70]	validation_0-rmse:2.59634
# Stopping. Best iteration:
# [27]	validation_0-rmse:2.49403
#
# [TX_1] Fold2: 8.534126996994019 [sec]
# [0]	validation_0-rmse:2.71595
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.44056
# [20]	validation_0-rmse:2.33122
# [30]	validation_0-rmse:2.23538
# [40]	validation_0-rmse:2.21726
# [50]	validation_0-rmse:2.21174
# [60]	validation_0-rmse:2.21330
# [70]	validation_0-rmse:2.21231
# [80]	validation_0-rmse:2.21904
# [90]	validation_0-rmse:2.23683
# Stopping. Best iteration:
# [49]	validation_0-rmse:2.20856
#
# [TX_1] Fold3: 8.327642440795898 [sec]
# [0]	validation_0-rmse:2.75322
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.51621
# [20]	validation_0-rmse:2.36227
# [30]	validation_0-rmse:2.28978
# [40]	validation_0-rmse:2.26786
# [50]	validation_0-rmse:2.26009
# [60]	validation_0-rmse:2.25226
# [70]	validation_0-rmse:2.25554
# [80]	validation_0-rmse:2.26675
# [90]	validation_0-rmse:2.27440
# [100]	validation_0-rmse:2.27846
# Stopping. Best iteration:
# [54]	validation_0-rmse:2.24549
#
# [TX_1] Fold4: 7.70629358291626 [sec]
# [0]	validation_0-rmse:2.93080
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.67075
# [20]	validation_0-rmse:2.53959
# [30]	validation_0-rmse:2.41305
# [40]	validation_0-rmse:2.33651
# [50]	validation_0-rmse:2.37459
# [60]	validation_0-rmse:2.39005
# [70]	validation_0-rmse:2.38604
# [80]	validation_0-rmse:2.40070
# [90]	validation_0-rmse:2.42588
# Stopping. Best iteration:
# [42]	validation_0-rmse:2.33475
#
# [TX_1] Fold5: 6.7512078285217285 [sec]
# [I 2020-06-26 07:00:20,385] Finished trial#67 with value: 2.3748241424560548 with parameters: {'subsample': 0.65, 'colsample_bytree': 0.8, 'max_depth': 4, 'gamma': 0.002291039102946029, 'min_child_weight': 0.24241088331672322}. Best is trial#11 with value: 2.254919099807739.
# [0]	validation_0-rmse:3.00695
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.59526
# [20]	validation_0-rmse:2.47341
# [30]	validation_0-rmse:2.41922
# [40]	validation_0-rmse:2.39092
# [50]	validation_0-rmse:2.38436
# [60]	validation_0-rmse:2.37798
# [70]	validation_0-rmse:2.37725
# [80]	validation_0-rmse:2.37577
# [90]	validation_0-rmse:2.37764
# [100]	validation_0-rmse:2.38091
# [110]	validation_0-rmse:2.37932
# [120]	validation_0-rmse:2.38116
# Stopping. Best iteration:
# [79]	validation_0-rmse:2.37470
#
# [TX_1] Fold1: 14.051658630371094 [sec]
# [0]	validation_0-rmse:2.92761
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.53028
# [20]	validation_0-rmse:2.42366
# [30]	validation_0-rmse:2.36486
# [40]	validation_0-rmse:2.33451
# [50]	validation_0-rmse:2.33079
# [60]	validation_0-rmse:2.32867
# [70]	validation_0-rmse:2.32440
# [80]	validation_0-rmse:2.33202
# [90]	validation_0-rmse:2.32002
# [100]	validation_0-rmse:2.32588
# [110]	validation_0-rmse:2.32877
# [120]	validation_0-rmse:2.33288
# [130]	validation_0-rmse:2.33283
# [140]	validation_0-rmse:2.33579
# Stopping. Best iteration:
# [94]	validation_0-rmse:2.31773
#
# [TX_1] Fold2: 13.543611288070679 [sec]
# [0]	validation_0-rmse:2.66356
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.35689
# [20]	validation_0-rmse:2.30613
# [30]	validation_0-rmse:2.28645
# [40]	validation_0-rmse:2.35335
# [50]	validation_0-rmse:2.36070
# [60]	validation_0-rmse:2.39621
# [70]	validation_0-rmse:2.39955
# [80]	validation_0-rmse:2.40358
# Stopping. Best iteration:
# [36]	validation_0-rmse:2.27685
#
# [TX_1] Fold3: 10.336146593093872 [sec]
# [0]	validation_0-rmse:2.69912
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.38751
# [20]	validation_0-rmse:2.33715
# [30]	validation_0-rmse:2.31841
# [40]	validation_0-rmse:2.33273
# [50]	validation_0-rmse:2.35888
# [60]	validation_0-rmse:2.37635
# [70]	validation_0-rmse:2.38787
# [80]	validation_0-rmse:2.39276
# Stopping. Best iteration:
# [33]	validation_0-rmse:2.31763
#
# [TX_1] Fold4: 9.549280881881714 [sec]
# [0]	validation_0-rmse:2.86867
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.49135
# [20]	validation_0-rmse:2.39867
# [30]	validation_0-rmse:2.38718
# [40]	validation_0-rmse:2.38248
# [50]	validation_0-rmse:2.38513
# [60]	validation_0-rmse:2.38265
# [70]	validation_0-rmse:2.38492
# [80]	validation_0-rmse:2.38616
# [90]	validation_0-rmse:2.38601
# [100]	validation_0-rmse:2.39601
# Stopping. Best iteration:
# [58]	validation_0-rmse:2.37848
#
# [TX_1] Fold5: 9.328498125076294 [sec]
# [I 2020-06-26 07:01:17,380] Finished trial#68 with value: 2.333078145980835 with parameters: {'subsample': 0.6, 'colsample_bytree': 0.85, 'max_depth': 8, 'gamma': 0.0164313866550376, 'min_child_weight': 0.4447443439299652}. Best is trial#11 with value: 2.254919099807739.
# [0]	validation_0-rmse:3.00861
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.54718
# [20]	validation_0-rmse:2.41234
# [30]	validation_0-rmse:2.37640
# [40]	validation_0-rmse:2.39280
# [50]	validation_0-rmse:2.39194
# [60]	validation_0-rmse:2.44814
# [70]	validation_0-rmse:2.45039
# [80]	validation_0-rmse:2.45692
# Stopping. Best iteration:
# [36]	validation_0-rmse:2.36073
#
# [TX_1] Fold1: 10.932277202606201 [sec]
# [0]	validation_0-rmse:2.92383
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.50015
# [20]	validation_0-rmse:2.38231
# [30]	validation_0-rmse:2.32495
# [40]	validation_0-rmse:2.34440
# [50]	validation_0-rmse:2.34702
# [60]	validation_0-rmse:2.33550
# [70]	validation_0-rmse:2.33352
# [80]	validation_0-rmse:2.33622
# Stopping. Best iteration:
# [36]	validation_0-rmse:2.29888
#
# [TX_1] Fold2: 10.089828491210938 [sec]
# [0]	validation_0-rmse:2.66337
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.33339
# [20]	validation_0-rmse:2.27136
# [30]	validation_0-rmse:2.24596
# [40]	validation_0-rmse:2.26039
# [50]	validation_0-rmse:2.27898
# [60]	validation_0-rmse:2.27599
# [70]	validation_0-rmse:2.28913
# [80]	validation_0-rmse:2.29424
# Stopping. Best iteration:
# [36]	validation_0-rmse:2.24358
#
# [TX_1] Fold3: 9.391271591186523 [sec]
# [0]	validation_0-rmse:2.69992
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.34974
# [20]	validation_0-rmse:2.27722
# [30]	validation_0-rmse:2.24878
# [40]	validation_0-rmse:2.23548
# [50]	validation_0-rmse:2.23925
# [60]	validation_0-rmse:2.25993
# [70]	validation_0-rmse:2.26819
# [80]	validation_0-rmse:2.26723
# [90]	validation_0-rmse:2.28460
# Stopping. Best iteration:
# [44]	validation_0-rmse:2.23118
#
# [TX_1] Fold4: 8.943487167358398 [sec]
# [0]	validation_0-rmse:2.85657
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10]	validation_0-rmse:2.43611
# [20]	validation_0-rmse:2.32914
# [30]	validation_0-rmse:2.29616
# [40]	validation_0-rmse:2.29887
# [50]	validation_0-rmse:2.28564
# [60]	validation_0-rmse:2.30084
# [70]	validation_0-rmse:2.30669
# [80]	validation_0-rmse:2.30997
# [90]	validation_0-rmse:2.31681
# Stopping. Best iteration:
# [47]	validation_0-rmse:2.28314
#
# [TX_1] Fold5: 8.138106346130371 [sec]
# [I 2020-06-26 07:02:05,057] Finished trial#69 with value: 2.2834998607635497 with parameters: {'subsample': 0.65, 'colsample_bytree': 0.8, 'max_depth': 7, 'gamma': 0.0007918825646029508, 'min_child_weight': 0.18779626962779294}. Best is trial#11 with value: 2.254919099807739.
# 100%|████████████████████████████████████████████████████████████████████████████████| 5/5 [4:55:50<00:00, 3550.02s/it]

# %%
# del df
# gc.collect()
# Out:
# 22

# %% [markdown]
# ## Train & Predict by best model (function)

# %%
# def xgboost_by_bestparam_for_valid(df, store, best_params, valid_preds):
#     print('##################### Traing4ValidByBestParam START: {0} #####################'.format(d_store_id[store]))
#     print('Best Parameters of store {0} model: {1}'.format(d_store_id[store], best_params))
    
#     # prepare data set
#     df_store = df[df['store_id'] == store]
#     X_train = df_store[df_store['d'] < VALID_FIRST_DAY].drop('sold', axis=1)
#     y_train = df_store[df_store['d'] < VALID_FIRST_DAY]['sold']
# #     X_train = df_store[(df_store['d'] >= TRAIN_FIRST_DAY) & (df_store['d'] < VALID_FIRST_DAY)].drop('sold', axis=1)
# #     y_train = df_store[(df_store['d'] >= TRAIN_FIRST_DAY) & (df_store['d'] < VALID_FIRST_DAY)]['sold']
#     X_valid = df_store[(df_store['d'] >= VALID_FIRST_DAY) & (df_store['d'] <= VALID_LAST_DAY)].drop('sold', axis=1)
    
#     # train XGBoost by using best_params
#     model = xgb.XGBRegressor(**best_params)
#     model.fit(X_train, y_train, eval_metric='rmse')
    
#     # save model for validation
# #     modelfile = 'BestModel4valid_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.pkl'
#     modelfile = 'BestModel4valid_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'_lag'+str(max(lags))+'.pkl'
# #     modelfile = 'BestModel4valid_TrainFirstDay'+str(TRAIN_FIRST_DAY)+'_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.pkl'
#     with open(os.path.join('result', 'best_model', modelfile), 'wb') as f:
#         pickle.dump(model, f)
    
#     # predict for valid
#     valid_preds[X_valid.index] = model.predict(X_valid)
#     del df_store, X_train, y_train, X_valid, model
#     gc.collect()

# %%
# def xgboost_by_bestparam_for_test(df, store, best_params, eval_preds):
#     print('##################### Traing4TestByBestParam START: {0} #####################'.format(d_store_id[store]))
    
#     # prepare data set
#     df_store = df[df['store_id'] == store]
#     X_train = df_store[df_store['d'] <= VALID_LAST_DAY].drop('sold', axis=1)
#     y_train = df_store[df_store['d'] <= VALID_LAST_DAY]['sold']
# #     X_train = df_store[(df_store['d'] >= TRAIN_FIRST_DAY) & (df_store['d'] <= VALID_LAST_DAY)].drop('sold', axis=1)
# #     y_train = df_store[(df_store['d'] >= TRAIN_FIRST_DAY) & (df_store['d'] <= VALID_LAST_DAY)]['sold']
#     X_test = df_store[df_store['d'] > VALID_LAST_DAY].drop('sold', axis=1)
    
#     # train XGBoost by using best_params
#     model = xgb.XGBRegressor(**best_params)
#     model.fit(X_train, y_train, eval_metric='rmse')
        
#     # predict for test
#     eval_preds[X_test.index] = model.predict(X_test)
    
#     # save model for test
# #     modelfile = 'BestModel4test_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.pkl'
#     modelfile = 'BestModel4test_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'_lag'+str(max(lags))+'.pkl'
# #     modelfile = 'BestModel4test_TrainFirstDay'+str(TRAIN_FIRST_DAY)+'_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.pkl'
#     with open(os.path.join('result', 'best_model', modelfile), 'wb') as f:
#         pickle.dump(model, f)
    
#     del df_store, X_train, y_train, X_test, model
#     gc.collect()

# %% [markdown]
# ## Train & Predict by best model

# %%
# # train & predict (best model)
# # df_all = pd.read_pickle(os.path.join(data_dir, 'data_all.pkl'))
# df_all = pd.read_pickle(os.path.join(data_dir, 'data_all_lag'+str(max(lags))+'.pkl'))

# valid = df_all[(df_all['d'] >= VALID_FIRST_DAY) & (df_all['d'] <= VALID_LAST_DAY)][['id','d','sold']]
# test = df_all[df_all['d'] > VALID_LAST_DAY][['id','d','sold']]
# valid_preds = valid['sold']
# eval_preds = test['sold']

# for store in tqdm(stores):
#     # read best param selected by CV
# #     bestparam_filename = 'BestParamsSelectedByCV_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.pkl'
#     bestparam_filename = 'BestParamsSelectedByCV_'+d_store_id[store]+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'_lag'+str(max(lags))+'.pkl'
#     with open(os.path.join('result', 'best_param_cv', bestparam_filename), 'rb') as f:
#         best_params = pickle.load(f)

#     # add other params
#     best_params['objective'] = 'reg:squarederror'
#     best_params['n_estimators'] = 1000
#     best_params['learning_rate'] = 0.1
#     best_params['tree_method'] = 'gpu_hist'
    
#     # best model for valid
#     xgboost_by_bestparam_for_valid(df_all, store, best_params, valid_preds)
    
#     # best model for test
#     xgboost_by_bestparam_for_test(df_all, store, best_params, eval_preds)
# Out:
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
# ##################### Traing4ValidByBestParam START: CA_1 #####################
# Best Parameters of store CA_1 model: {'subsample': 0.75, 'colsample_bytree': 0.65, 'max_depth': 6, 'gamma': 1.1821859985744301e-06, 'min_child_weight': 4.7766289583667785, 'objective': 'reg:squarederror', 'n_estimators': 1000, 'learning_rate': 0.1, 'tree_method': 'gpu_hist'}
# ##################### Traing4TestByBestParam START: CA_1 #####################
#  10%|████████▎                                                                          | 1/10 [00:42<06:22, 42.50s/it]
# ##################### Traing4ValidByBestParam START: CA_2 #####################
# Best Parameters of store CA_2 model: {'subsample': 0.9, 'colsample_bytree': 0.6, 'max_depth': 7, 'gamma': 4.7318952072962104e-05, 'min_child_weight': 0.29807473699000614, 'objective': 'reg:squarederror', 'n_estimators': 1000, 'learning_rate': 0.1, 'tree_method': 'gpu_hist'}
# ##################### Traing4TestByBestParam START: CA_2 #####################
#  20%|████████████████▌                                                                  | 2/10 [01:43<06:24, 48.11s/it]
# ##################### Traing4ValidByBestParam START: CA_3 #####################
# Best Parameters of store CA_3 model: {'subsample': 0.7, 'colsample_bytree': 0.65, 'max_depth': 6, 'gamma': 1.583774259519068e-05, 'min_child_weight': 1.3785013051417276, 'objective': 'reg:squarederror', 'n_estimators': 1000, 'learning_rate': 0.1, 'tree_method': 'gpu_hist'}
# ##################### Traing4TestByBestParam START: CA_3 #####################
#  30%|████████████████████████▉                                                          | 3/10 [02:26<05:25, 46.44s/it]
# ##################### Traing4ValidByBestParam START: CA_4 #####################
# Best Parameters of store CA_4 model: {'subsample': 0.8, 'colsample_bytree': 0.65, 'max_depth': 4, 'gamma': 2.0475260701397332e-05, 'min_child_weight': 0.12341364839488726, 'objective': 'reg:squarederror', 'n_estimators': 1000, 'learning_rate': 0.1, 'tree_method': 'gpu_hist'}
# ##################### Traing4TestByBestParam START: CA_4 #####################
#  40%|█████████████████████████████████▏                                                 | 4/10 [02:59<04:14, 42.36s/it]
# ##################### Traing4ValidByBestParam START: TX_1 #####################
# Best Parameters of store TX_1 model: {'subsample': 0.75, 'colsample_bytree': 0.65, 'max_depth': 5, 'gamma': 2.0653844662510943e-08, 'min_child_weight': 0.7477804366990574, 'objective': 'reg:squarederror', 'n_estimators': 1000, 'learning_rate': 0.1, 'tree_method': 'gpu_hist'}
# ##################### Traing4TestByBestParam START: TX_1 #####################
#  50%|█████████████████████████████████████████▌                                         | 5/10 [03:34<03:21, 40.21s/it]
# ##################### Traing4ValidByBestParam START: TX_2 #####################
# Best Parameters of store TX_2 model: {'subsample': 0.9, 'colsample_bytree': 0.65, 'max_depth': 7, 'gamma': 4.963410152322898e-05, 'min_child_weight': 0.8512182719597868, 'objective': 'reg:squarederror', 'n_estimators': 1000, 'learning_rate': 0.1, 'tree_method': 'gpu_hist'}
# ##################### Traing4TestByBestParam START: TX_2 #####################
#  60%|█████████████████████████████████████████████████▊                                 | 6/10 [04:33<03:03, 45.90s/it]
# ##################### Traing4ValidByBestParam START: TX_3 #####################
# Best Parameters of store TX_3 model: {'subsample': 0.85, 'colsample_bytree': 0.6, 'max_depth': 8, 'gamma': 0.0015550997330305424, 'min_child_weight': 2.85469971317187, 'objective': 'reg:squarederror', 'n_estimators': 1000, 'learning_rate': 0.1, 'tree_method': 'gpu_hist'}
# ##################### Traing4TestByBestParam START: TX_3 #####################
#  70%|██████████████████████████████████████████████████████████                         | 7/10 [05:52<02:47, 55.90s/it]
# ##################### Traing4ValidByBestParam START: WI_1 #####################
# Best Parameters of store WI_1 model: {'subsample': 0.75, 'colsample_bytree': 0.65, 'max_depth': 7, 'gamma': 0.992320395454035, 'min_child_weight': 0.43852730330918643, 'objective': 'reg:squarederror', 'n_estimators': 1000, 'learning_rate': 0.1, 'tree_method': 'gpu_hist'}
# ##################### Traing4TestByBestParam START: WI_1 #####################
#  80%|██████████████████████████████████████████████████████████████████▍                | 8/10 [06:32<01:42, 51.20s/it]
# ##################### Traing4ValidByBestParam START: WI_2 #####################
# Best Parameters of store WI_2 model: {'subsample': 0.65, 'colsample_bytree': 0.7, 'max_depth': 6, 'gamma': 0.0006378091089322041, 'min_child_weight': 0.28595811829890777, 'objective': 'reg:squarederror', 'n_estimators': 1000, 'learning_rate': 0.1, 'tree_method': 'gpu_hist'}
# ##################### Traing4TestByBestParam START: WI_2 #####################
#  90%|██████████████████████████████████████████████████████████████████████████▋        | 9/10 [07:14<00:48, 48.35s/it]
# ##################### Traing4ValidByBestParam START: WI_3 #####################
# Best Parameters of store WI_3 model: {'subsample': 0.95, 'colsample_bytree': 0.65, 'max_depth': 5, 'gamma': 0.2630793523915515, 'min_child_weight': 0.514078102493801, 'objective': 'reg:squarederror', 'n_estimators': 1000, 'learning_rate': 0.1, 'tree_method': 'gpu_hist'}
# ##################### Traing4TestByBestParam START: WI_3 #####################
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [07:52<00:00, 47.21s/it]

# %%
# # save valid_preds
# # valid_preds_filename = 'ValidPreds_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.pkl'
# valid_preds_filename = 'ValidPreds_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'_lag'+str(max(lags))+'.pkl'
# # valid_preds_filename = 'ValidPreds_TrainFirstDay'+str(TRAIN_FIRST_DAY)+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.pkl'
# with open(os.path.join('result', 'preds', valid_preds_filename), 'wb') as f:
#     pickle.dump(valid_preds, f)
    
# # save test_preds
# # eval_preds_filename = 'EvalPreds_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.pkl'
# eval_preds_filename = 'EvalPreds_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'_lag'+str(max(lags))+'.pkl'
# # eval_preds_filename = 'EvalPreds_TrainFirstDay'+str(TRAIN_FIRST_DAY)+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.pkl'
# with open(os.path.join('result', 'preds', eval_preds_filename), 'wb') as f:
#     pickle.dump(eval_preds, f)

# %%
# del df_all
# gc.collect()
# Out:
# 44

# %% [markdown]
# # Make submission

# %%
# #Set actual equal to false if you want to top in the public leaderboard :P
# actual = True
# if actual == False:
#     #Get the validation results(We already have them as less than one month left for competition to end)
#     validation = sales[['id']+['d_' + str(i) for i in range(1914,1942)]]
#     validation['id']=pd.read_csv(os.path.join(rawdata_dir, 'sales_train_validation.csv')).id
#     validation.columns=['id'] + ['F' + str(i + 1) for i in range(28)]
# else:
#     #Get the actual validation results
#     valid['sold'] = valid_preds
#     validation = valid[['id','d','sold']]
#     validation = pd.pivot(validation, index='id', columns='d', values='sold').reset_index()
#     validation.columns=['id'] + ['F' + str(i + 1) for i in range(28)]
#     validation.id = validation.id.map(d_id).str.replace('evaluation','validation')

# #Get the evaluation results
# test['sold'] = eval_preds
# evaluation = test[['id','d','sold']]
# evaluation = pd.pivot(evaluation, index='id', columns='d', values='sold').reset_index()
# evaluation.columns=['id'] + ['F' + str(i + 1) for i in range(28)]
# #Remap the category id to their respective categories
# evaluation.id = evaluation.id.map(d_id)

# #Prepare the submission
# submit = pd.concat([validation,evaluation]).reset_index(drop=True)

# # isNegative2Zero = True
# if isNegative2Zero:
#     submit = submit.set_index("id", drop=True)
#     submit[submit < 0] = 0
#     submit = submit.reset_index()

# # submit_file = 'xgboost_cv_UseValidPredsIs'+str(actual)+'_Negative2ZeroIs'+str(isNegative2Zero)+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.csv'
# submit_file = 'xgboost_cv_UseValidPredsIs'+str(actual)+'_Negative2ZeroIs'+str(isNegative2Zero)+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'_lag'+str(max(lags))+'.csv'
# # submit_file = 'xgboost_cv_TrainFirstDay'+str(TRAIN_FIRST_DAY)+'_UseValidPredsIs'+str(actual)+'_Negative2ZeroIs'+str(isNegative2Zero)+'_foldday'+str(NUM_FOLD_DAYS)+'_useday'+str(NUM_USE_DAY)+'.csv'
# submit.to_csv(os.path.join('submission_point', submit_file), index=False)
